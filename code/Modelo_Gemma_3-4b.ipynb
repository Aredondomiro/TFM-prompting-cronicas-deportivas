# %% [markdown]
# CONFIGURACIÓN INICIAL

# %%
import pandas as pd
from openai import OpenAI
import nltk
nltk.download('punkt_tab', quiet=True)
nltk.download('punkt', quiet=True)

# Cliente LM Studio (Gemma)
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"  # cadena ficticia, solo para cumplir la interfaz
)

print("✅ CLIENTE LM STUDIO CONECTADO - Gemma lista")
# Out:
# ✅ CLIENTE LM STUDIO CONECTADO - Gemma lista

# %%
# CELDA DE COMPROBACIÓN: listar modelos disponibles vía API local

modelos = client.models.list()
modelos_id = [model.id for model in modelos.data]

for mid in modelos_id:
    print(mid)
# Out:
# google/gemma-3-4b

# %% [markdown]
# TÉCNICAS- MODELO GEMMA - 3 - 4B
# FICHA 1
# ZERO SHOT

# %%
# FICHA 1 | Gemma | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha1 = """ID_PARTIDO: UCL_2024_FINAL
Competición: UEFA Champions League
Temporada: 2023/2024
Fase: Final
Fecha: 01/06/2024
Hora: 20:00 (UTC+1)
Estadio: Wembley Stadium, Londres
Asistencia: 86,212
Árbitro: Slavko Vinčić
Equipo 1: Borussia Dortmund
Equipo 2: Real Madrid
Entrenador Borussia Dortmund: Edin Terzić
Entrenador Real Madrid: Carlo Ancelotti
Alineación Borussia Dortmund:
Kobel; Ryerson, Hummels, Schlotterbeck, Maatsen; Can, Brandt, Sabitzer; Adeyemi, Füllkrug, Sancho
Alineación Real Madrid:
Courtois; Carvajal, Rüdiger, Nacho; Mendy; Camavinga, Valverde, Kroos; Bellingham; Rodrygo, Vinícius Júnior
Resultado final: Borussia Dortmund 0 – 2 Real Madrid
Resultado al descanso: 0 – 0
Goles:
74' Dani Carvajal (Real Madrid), gol
83' Vinícius Júnior (Real Madrid), gol
Tarjetas amarillas Borussia Dortmund:
40' Nico Schlotterbeck
43' Marcel Sabitzer
79' Mats Hummels
Tarjetas amarillas Real Madrid:
35' Vinícius Júnior
Sustituciones Borussia Dortmund:
72' Marco Reus por Karim Adeyemi
80' Donyell Malen por Emre Can
80' Sébastien Haller por Julian Brandt
87' Jamie Bynoe-Gittens por Jadon Sancho
Sustituciones Real Madrid:
85' Luka Modrić por Toni Kroos
85' Joselu por Jude Bellingham
90' Éder Militão por Rodrygo
90+4' Lucas Vázquez por Vinícius Júnior
Eventos registrados:
21' Ocasión de gol Borussia Dortmund: remate de Karim Adeyemi bloqueado
23' Remate de Niclas Füllkrug al poste
Final del partido: gol de Borussia Dortmund anulado por fuera de juego
Estadísticas totales:
Posesión (%): 46 – 54
Tiros: 13 – 13
Tiros a puerta: 3 – 6
Córners: 9 – 8
Faltas: 12 – 8
Fueras de juego: 1 – 0
Estadísticas por partes:
Primera parte: posesión 40 – 60, tiros 8 – 2, córners 5 – 1
Segunda parte: posesión 54 – 46, tiros 5 – 11, córners 4 – 7
Estadísticas avanzadas:
xG: 1.86 – 1.15
Jugador del partido: Dani Carvajal"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha1}"

response = client.chat.completions.create(
    model="google/gemma-3-4b",  # ✅ COMA AÑADIDA
    messages=[{"role": "user", "content": prompt_config1}],  # ✅ COMA AÑADIDA
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 1 (Gemma | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 1 – CONFIG 1 (Gemma | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# ## El Real Madrid se corona en Wembley y destroza al Dortmund con un golito de Carvajal y la velocidad de Vinícius
#
# **Londres, 1 de junio de 2024 -** La noche de Wembley fue para el Real Madrid. Tras una final tensa, llena de alternativas y momentos de nerviosismo, los merengues se alzaron con la décima Champions League de su historia, derrotando al Borussia Dortmund por 2-0 en un partido que, a pesar del dominio alemán en posesión, terminó siendo dominado por la solidez defensiva y el talento individual blanco.
#
# Desde el pitido inicial, el Dortmund salió con una presión asfixiante, buscando desestabilizar la defensa madridista. La intensidad de los alemanes era palpable, pero el Real Madrid, bajo la batuta experta de Carlo Ancelotti, se mantuvo firme, defendiendo con uñas y dientes su portería. El primer periodo transcurrió en un ritmo frenético, con ocasiones para ambos equipos, aunque sin que ninguno lograra romper la igualada. La más clara del Dortmund llegó en el minuto 21, cuando Karim Adeyemi remató a puerta bloqueado por una defensa madridista bien plantada.
#
# **Carvajal, la clave en la primera parte**
#
# La segunda mitad comenzó con un ritmo más lento, pero con la amenaza constante del Borussia. Sin embargo, en el minuto 74, llegó el gol que cambiaría el rumbo del partido. Dani Carvajal, con un remate imparable desde fuera del área, sorprendió a Kobel y abrió el marcador para el Real Madrid. El estadio se inyectó de pasión blanca, mientras que el Dortmund se veía cada vez más desmoralizado.
#
# El gol despertó al Real Madrid, que continuó buscando la portería alemana. Y en el minuto 83, Vinícius Júnior, con su velocidad y desborde habitual, culminó una jugada individual para marcar el segundo gol del partido. El brasileño, visiblemente cansado pero implacable, se deshizo de Ryerson y, tras un regate, colocó el balón en la red, sellando la victoria madridista.
#
# **Un Dortmund que no encontró su ritmo**
#
# El Borussia Dortmund, a pesar de controlar la posesión durante gran parte del partido, no logró traducir su dominio en goles. Su falta de eficacia en ataque y la solidez defensiva del Real Madrid fueron los principales factores que determinaron el resultado final. Las sustituciones realizadas por Edin Terzić en el minuto 80, con Reus, Malen y Haller, no lograron cambiar el rumbo del partido.
#
# **Análisis estadístico:**
#
# La posesión del balón fue mayoritaria para el Dortmund (54% frente al 46% del Real Madrid), pero la xG (esperada de goles) favoreció a los blancos (1.86 frente a 1.15). Los tiros a puerta también fueron más efectivos para el Real Madrid (6 frente a 3).
#
# **Jugador del partido:** Dani Carvajal, por su gol y su labor defensiva incansable. El veterano lateral derecho demostró que aún tiene mucho fútbol en las piernas y fue fundamental para la victoria madridista.
#
# **Cambios estratégicos:** Ancelotti movió el banquillo en el minuto 85, incorporando a Modrić y Joselu para reforzar el centro del campo y la delantera, mientras que Terzić introdujo a Militão, Lucas Vázquez y Vinícius Júnior en los últimos minutos.
#
# **El Real Madrid se corona campeón de Europa, consolidándose como una de las grandes potencias del fútbol mundial.** La victoria en Wembley es un triunfo para Carlo Ancelotti y su equipo, que ha demostrado ser capaz de superar cualquier obstáculo para alcanzar sus objetivos.

# %%
# FICHA 1 | Gemma | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha1}""".format(ficha1=ficha1)

response = client.chat.completions.create(
    model="google/gemma-3-1b",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=1500
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 1 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El Real Madrid se corona en Wembley y destroza al Dortmund con un golito de Carvajal y la velocidad de Vinícius
#
# **Londres, 1 de junio de 2024 -** La noche londinense fue para el Real Madrid. Tras una final europea cargada de tensión, drama y ocasiones, los merengues se coronaron campeones de la Champions League por sexta vez en su historia, derrotando al Borussia Dortmund por 2-0 en un Wembley que vibró con la victoria blanca. Un partido que, a pesar del dominio territorial del Dortmund, demostró una vez más la solidez defensiva y el talento individual del Real Madrid, liderado por un Dani Carvajal impecable y la velocidad descontrolada de Vinícius Júnior.
#
# Desde el pitido inicial, el Dortmund salió con la intención de asediar la portería de Courtois. La intensidad del equipo alemán era palpable, pero el Real Madrid, bajo la batuta de Ancelotti, se mostró sólido en defensa y paciente en su juego. El primer tiempo transcurrió con un ritmo frenético, lleno de duelos y ocasiones para ambos equipos. El Dortmund tuvo claras oportunidades, como el remate de Adeyemi que fue bloqueado por Kobel o el disparo de Füllkrug al poste, pero la defensa blanca se mantuvo firme. La polémica llegó en el 21’ con un gol anulado a Adeyemí por fuera de juego, evidenciando la arbitridad y la dificultad para separar las ocasiones claras de los errores.
#
# La segunda mitad fue un ejercicio de paciencia y contundencia por parte del Real Madrid. El Dortmund, aunque seguía presionando, parecía cansado y el Real Madrid comenzó a controlar el ritmo del partido. Y entonces llegó el momento decisivo: en el minuto 74’, Dani Carvajal, con un remate imparable desde fuera del área, abrió el marcador. Un gol que desató la euforia en la grada blanca y puso las bases de la victoria.
#
# Pero el Real Madrid no se conformó. La velocidad de Vinícius Júnior fue una constante amenaza para la defensa alemana. Y finalmente, en el 83’, el brasileño culminó una jugada individual con un gol que selló la clasificación. El estadio explotó en júbilo mientras Vinícius Júnior celebraba su tanto y la Copa Champions se acercaba a las manos de los merengues.
#
# El Dortmund intentó reaccionar, pero el Real Madrid, con cambios estratégicos y una defensa impecable, logró mantener la ventaja hasta el pitido final. La sustitución de Kroos por Modrić y Bellingham por Joselu en el 85’ reflejó la intención del equipo blanco de controlar los últimos minutos y asegurar la victoria.
#
# **Análisis:** El Real Madrid demostró ser un rival más sólido y efectivo que el Borussia Dortmund, especialmente en fases finales. La experiencia de Ancelotti, la solidez defensiva y el talento individual de jugadores como Carvajal, Vinícius Júnior y Bellingham fueron claves para la victoria. El Dortmund, por su parte, mostró una gran intensidad pero careció de contundencia en ataque y sufrió las consecuencias.
#
# **Jugador del partido:** Dani Carvajal. Un muro infranqueable en defensa que no solo defendió con uñas y dientes, sino que también se unió al ataque con un golazo que cambió el rumbo del partido.
#
# **En resumen, una noche histórica para el Real Madrid, que se corona como campeón de Europa y demuestra, una vez más, su grandeza.**

# %%
#FICHA 1 | Gemma | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)
prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha1}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=1500
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Real Madrid se corona en Wembley tras un final de infarto contra el Dortmund, con Carvajal como héroe
#
# **Londres, 1 de junio de 2024 –** Un estadio repleto de 86.212 espectadores presenció una final de Champions League cargada de tensión y emoción, que finalmente se decantó a favor del Real Madrid por un contundente 2-0, con un gol de Dani Carvajal en el minuto 74 y la estocada final de Vinícius Júnior en el 83. El Borussia Dortmund, que demostró ser un rival digno hasta los últimos minutos, se vio superado por la experiencia y la efectividad del conjunto blanco, liderado desde el banquillo por Carlo Ancelotti.
#
# La primera mitad fue un ejercicio de equilibrio táctico, con ambos equipos mostrando una sólida defensa y buscando espacios en ataque. El Dortmund, impulsado por la afición local, generó las primeras ocasiones, como el remate de Karim Adeyemi al poste en el minuto 21, que se estrelló en la madera, y el disparo peligroso de Niclas Füllkrug al poste en el 23. Sin embargo, la defensa del Real Madrid, con Carvajal liderando la línea defensiva, se mantuvo firme. El partido se desarrolló con un ritmo pausado, sin excesos de juego ofensivo y con constantes interrupciones por faltas.
#
# El Borussia Dortmund, que buscaba imponer su estilo de juego basado en la posesión, vio cómo el Real Madrid, bajo las órdenes de Ancelotti, se organizaba con solidez y aprovechaba los espacios. La primera tarjeta amarilla del partido fue para Vinícius Júnior en el minuto 35, por una entrada dura sobre Hummels, mientras que Nico Schlotterbeck recibió su amonestación en el minuto 40 por un mano a tierra dentro del área.
#
# La segunda mitad comenzó con la intensidad que se esperaba de una final de Champions League. El Real Madrid salió con más ambición y encontró el primer gol en el minuto 74, gracias a Dani Carvajal, quien aprovechó un centro medido para batir a Kobel. El gol desató la euforia del banquillo blanco y elevó el ánimo de los jugadores.
#
# El Dortmund, sin embargo, no se rindió y siguió presionando buscando el empate. En el minuto 83, Vinícius Júnior, que había entrado en juego minutos antes, culminó una contra con un disparo imparable que se coló por la escuadra. El gol selló la victoria del Real Madrid y desató la celebración de los jugadores y aficionados madridistas.
#
# El partido también tuvo su momento polémico: en el minuto 21, un remate de Adeyemi fue anulado por fuera de juego, lo que generó debate entre los asistentes al partido. Las estadísticas confirmaron la superioridad del Real Madrid en posesión (54% frente al 46%), tiros a puerta (6 frente a 3) y xG (1.15 frente a 1.86), aunque ambos equipos igualaron en número de disparos totales (13).
#
# El jugador del partido, según la valoración de los expertos, fue Dani Carvajal, quien no solo marcó un gol crucial sino que también se mostró sólido en defensa y ofreció alternativas en el juego. El Real Madrid, con esta victoria, suma su 15ª Champions League a su palmarés, consolidándose como el club más laureado del mundo en la competición. Para el Borussia Dortmund, es una derrota dolorosa que deja un sabor amargo tras una temporada histórica.
#
#
# 📊 Palabras: 537

# %%
#FICHA 1 | Gemma | Zero-shot | CON ROL | CON RESTRICCIONES
prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha1}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos (74' Carvajal, 83' Vinicius), xG (1.86-1.15), Jugador del partido (Carvajal)"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## El Real Madrid se corona en Wembley y silencia al Dortmund con un golito y una estocada final
#
# **Por [Tu Nombre], periodista deportivo de AS/Marca**
#
# Wembley, Londres – La noche europea se tiñó de blanco. El Real Madrid, con la garra implacable que le ha caracterizado esta temporada, se coronó campeón de la Champions League al derrotar al Borussia Dortmund por 2-0 en una final cargada de tensión y emoción. Un partido que, a pesar del dominio posesional del Dortmund, terminó siendo un claro triunfo para el equipo blanco, liderado por una defensa férrea y un ataque letal.
#
# **Entrada impactante: La estrategia de Ancelotti y la sorpresa inicial**
#
# Carlo Ancelotti, con su habitual pragmatismo, optó por una alineación que priorizaba la solidez defensiva y la contundencia en el centro del campo. El Real Madrid no buscó dominar desde el pitido inicial, sino que se organizó con inteligencia, esperando pacientemente la oportunidad de explotar los espacios y la velocidad de sus delanteros. La sorpresa, sin embargo, llegó temprano. En el minuto 21, Karim Adeyemi, con un remate potente, se encontró con una defensa del Dortmund que, aunque atenta, no logró bloquear el disparo. El gol fue anulado por fuera de juego, evidenciando la meticulosa preparación del VAR y la vigilancia constante del árbitro.
#
# **Desarrollo cronológico: Un primer tiempo igualado y un segundo tiempo decisivo**
#
# El primer tiempo transcurrió en un ritmo moderado, con ambos equipos buscando su espacio en el campo. El Dortmund, impulsado por la afición local, intentó imponer su juego de posesión, pero el Real Madrid se mostró sólido en defensa y efectivo en las transiciones. La insistencia del Dortmund generó algunas ocasiones claras, como el remate de Füllkrug al poste en el minuto 23, que demostró la peligrosidad que podía representar el ataque alemán. Sin embargo, la contundencia del Real Madrid no se veía reflejada en el marcador, y el descanso llegó sin goles.
#
# La segunda mitad fue un punto de inflexión. El Real Madrid salió con una intensidad renovada, presionando alto y buscando aprovechar los errores del Dortmund. Y su insistencia tuvo frutos en el minuto 74. Dani Carvajal, tras un centro medido de Vinícius Júnior, aprovechó un hueco en la defensa alemana para marcar el primer gol del partido. El estadio se sumió en un rugido ensordecedor, celebrando la primera ventaja del Real Madrid.
#
# El Dortmund, desmoralizado por el gol, intentó reaccionar, pero el Real Madrid supo defenderse con uñas y dientes. En el minuto 83, Vinícius Júnior, tras una jugada individual brillante, se deshizo de sus marcadores y definió con sangre fría para sentenciar la final. El gol, que parecía sellar la victoria, no llegó sin incidentes: Vinícius Jr fue amonestado por un agarrón previo al gol, pero el árbitro mantuvo su decisión.
#
# Los últimos minutos fueron de nerviosismo, con el Dortmund buscando desesperadamente el empate. Sin embargo, la defensa del Real Madrid, liderada por una impecable actuación de Carvajal, se mantuvo firme. En los descuentos, Ancelotti realizó algunos cambios tácticos para asegurar la victoria, y Éder Militão entró en el campo para reforzar la línea defensiva.
#
# **Cierre reflexivo: El dominio estadístico y el premio a la constancia**
#
# El Real Madrid dominó el partido en posesión (54% frente al 46%), pero el Borussia Dortmund logró generar más oportunidades de gol, con un xG de 1.86 contra 1.15 del equipo blanco. La solidez defensiva y la efectividad en los momentos clave fueron las claves del triunfo del Real Madrid. Dani Carvajal fue nombrado Jugador del Partido por su actuación destacada, demostrando que a veces, la experiencia y la determinación son más importantes que el talento puro.
#
# Este título consolida al Real Madrid como una de las leyendas de la Champions League, con 15 trofeos en su palmarés. Un triunfo que demuestra que, bajo la batuta de Carlo Ancelotti, la constancia, la solidez y la capacidad de sufrir son los ingredientes esenciales para alcanzar la gloria europea. La noche blanca en Wembley quedará grabada en la historia del fútbol.
#
#
# 📊 Palabras: 663

# %% [markdown]
# FEW SHOTS

# %%
# CELDA 6 – FICHA 1 | Gemma | Few-shot SIMPLE (mejorado) | Sin rol | Sin restricciones
# Objetivo: forzar que Gemma NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha1}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 1 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# El Real Madrid se impuso al Borussia Dortmund en la final de la Champions League, con un marcador de 2 a 0. Un gol de Dani Carvajal en el segundo tiempo y una actuación sólida del equipo blanco decidieron el encuentro. El partido fue intenso y equilibrado, con el Dortmund buscando su oportunidad pero sin lograr concretarla. Jugador del partido fue Dani Carvajal por su importante contribución defensiva y su gol.

# %%
# FICHA 1 | Gemma | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre este partido para aficionados que leen AS o Marca:
{ficha1}"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 1 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El Madrid se impone con un golito en Wembley y conquista la Champions
#
# **Real Madrid 1 - 0 Borussia Dortmund. Un triunfo justo, pero necesario para levantar la décima Champions League.**
#
# Wembley fue testigo de una noche tensa y estratégica, donde el Real Madrid, con un juego más metódico y efectivo, se llevó la victoria por 1-0 ante un Borussia Dortmund que luchó hasta el final pero no pudo superar la defensa blanca. El partido, marcado por la intensidad y la lucha por cada balón, terminó con el brillo de la estrella en la cabeza de Dani Carvajal, quien desató la euforia madridista en los últimos minutos.
#
# Desde el pitido inicial, ambos equipos mostraron una clara intención ofensiva, aunque sin generar ocasiones claras de gol. El Dortmund, impulsado por su afición, intentó controlar el ritmo del partido con un pressing asfixiante, pero el Real Madrid, con la solidez defensiva de Ancelotti y la experiencia en los momentos clave, logró neutralizar las amenazas locales.
#
# La primera mitad transcurrió sin sobresaltos, con ambos equipos buscando crear espacios y generar oportunidades. El Borussia Dortmund tuvo algunas ocasiones de peligro, como el remate de Adeyemi al poste en el minuto 23, pero Courtois se mantuvo firme bajo los palos.
#
# En la segunda parte, el Real Madrid salió con más intensidad y comenzó a dominar el juego. La insistencia de Vinicius Jr. y Bellingham generó ocasiones claras de gol, pero la defensa del Dortmund se mostró sólida y organizada. Finalmente, en el minuto 74, llegó el momento decisivo: un centro medido de Kroos encontró a Carvajal, quien remató imparable para batir a Kobel y abrir el marcador.
#
# El gol supuso un mazazo para el Dortmund, que intentó reaccionar pero no logró generar ocasiones claras de gol. El Real Madrid controló el partido en los últimos minutos, defendiendo con uñas y dientes su ventaja. En el minuto 83, Vinicius Jr. tuvo la oportunidad de ampliar la ventaja, pero su disparo se estrelló en la madera.
#
# Finalmente, el árbitro pitó el final del partido, desatando la euforia de los aficionados madridistas. El Real Madrid conquista la Champions League por décima vez en su historia y demuestra una vez más que es un equipo con capacidad para ganar cualquier competición.
#
# **Análisis:** Un triunfo merecido, aunque no espectacular, del Real Madrid. La solidez defensiva, la experiencia de Ancelotti y el gol decisivo de Carvajal fueron claves para llevarse la victoria. El Dortmund, por su parte, demostró ser un rival complicado pero no tuvo suficiente calidad en ataque para superar al equipo blanco.
#
# **Palabras clave:** Champions League, Real Madrid, Borussia Dortmund, Dani Carvajal, Wembley, Ancelotti, Vinicius Jr., Bellingham.

# %%
#FICHA 1 | Gemma | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha1}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Madrid, implacable, devora al Dortmund en Wembley y se despide de la Champions con un golito de Carvajal
#
# Wembley vibraba con la tensión, pero el Real Madrid, con la frialdad de un depredador, desmanteló al Borussia Dortmund en una noche que quedará grabada en la historia de la Champions League. Un 2-0 contundente, firmado por Dani Carvajal y Vinicius Jr., se convierte en la recompensa a la estrategia impecable de Carlo Ancelotti y a la implacabilidad blanca en el último tramo del partido. El sueño europeo del Dortmund, que llegaba con la moral alta tras su victoria en la Bundesliga, se ha desvanecido en el césped londinense.
#
# La primera mitad fue un ejercicio de paciencia por parte del Madrid. Ancelotti, fiel a su filosofía, optó por una rotación táctica, dando minutos a jugadores menos habituales y buscando controlar el ritmo del partido. El Dortmund, con la intensidad propia de un equipo que se siente imparable, intentó imponer su juego, pero se encontró con una defensa madridista sólida y un Courtois atento. La ocasión más clara del primer tiempo llegó en el minuto 21, cuando Adeyemi remató al poste tras un buen centro de Sancho, evidenciando la dificultad que estaba teniendo el equipo alemán para superar a la zaga blanca.
#
# La segunda mitad fue donde el Madrid desplegó su poderío. El xG (valoración de las oportunidades) del Real Madrid se situó en 1.86 frente al 1.15 del Dortmund, reflejando la superioridad clara del conjunto blanco. Y esa superioridad se tradujo en goles. En el minuto 74, Dani Carvajal, con un remate imparable desde fuera del área, abrió el marcador y desató la euforia en la grada madridista. El gol, fruto de una buena internada y un disparo certero, supuso un golpe moral para el Dortmund.
#
# Pero el partido no estaba resuelto. Y Vinicius Jr., con su velocidad y desborde habituales, fue quien selló la victoria en el minuto 83. Un magistral regate, una entrada al área y un remate cruzado que se coló por bajo de Maatsen. El brasileño, protagonista indiscutible de la noche, demostró una vez más su capacidad para decidir partidos.
#
# El árbitro anuló un gol en el minuto 23 de Füllkrug por fuera de juego, lo que evidenció la polémica del partido y la insistencia del Dortmund en buscar el empate.  La posesión del balón fue mayoritaria para el Madrid (54% frente al 46%), con una clara superioridad en los tiros a puerta (6-3).
#
# El Real Madrid se despide de la Champions League con un sabor agridulce, pero con la satisfacción de haber demostrado su calidad y su capacidad para superar cualquier rival.  Ancelotti ha vuelto a demostrar que es el hombre indicado para liderar al club blanco en las grandes competiciones. El Dortmund, por su parte, deberá reflexionar sobre su actuación y buscar soluciones para volver a alcanzar el nivel que le permite. Una noche de Wembley que quedará en la memoria como una derrota dolorosa para el equipo alemán y una victoria contundente del Real Madrid.
#
#
# 📊 Palabras: 502

# %%
# FICHA 1 | Gemma | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha1}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos (74', 83') y xG (1.86-1.15)"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **El Madrid, implacable, devasta al Dortmund en una final de Champions que no fue un cuento de hadas**
#
# Wembley, Londres – La noche del 1 de junio quedará grabada en la memoria de los aficionados españoles como una victoria contundente y, a la vez, amarga para el Borussia Dortmund. El Real Madrid, con una solidez defensiva impecable y un ataque letal, se impuso por 2-0 al equipo alemán en la final de la Champions League, coronándose campeón del torneo continental por decimaseis veces. Pero lejos de ser una noche de euforia total, el triunfo madridista se forjó sobre la base de un partido duro, disputado y con momentos de incertidumbre que, finalmente, resolvieron los merengues con inteligencia táctica y determinación.
#
# La primera mitad fue un ejercicio de paciencia y contención por parte del Dortmund, que intentó neutralizar el juego del Real Madrid, pero se encontró con una defensa blanca que no concedió ni un ápice de peligro. El xG inicial del equipo alemán rondaba los 1.15, mientras que el del Madrid apenas superaba los 0.86, reflejando la dificultad que encontraron para romper la muralla defensiva madridista. La ocasión más clara del Dortmund llegó en el minuto 21, con un remate de Karim Adeyemi bloqueado por Courtois, y en el 23, Füllkrug se encontró solo frente al portero belga, pero su disparo salió rozando el poste. El primer tiempo terminó sin goles, dejando la sensación de que el partido podía decantarse en cualquier momento.
#
# La segunda mitad fue un festival de ocasiones para el Real Madrid, y finalmente, la insistencia blanca tuvo su premio. En el minuto 74, Dani Carvajal, con un remate imparable desde fuera del área, abrió el marcador, desatando la euforia en la grada madridista. El Dortmund se volcó al ataque, pero la defensa del Real Madrid, liderada por una figura magistral como Nacho, se mantuvo firme. En el minuto 83, Vinícius Júnior, con un disparo cruzado que batió a Kobel, selló la victoria y puso fin a la resistencia alemana. El brasileño, protagonista indiscutible de la noche, demostró su calidad y capacidad goleadora una vez más.
#
# El Dortmund, consciente de la necesidad de marcar, se arriesgó en los últimos minutos, pero el Real Madrid, con un juego pragmático y efectivo, supo controlar el ritmo del partido y defender su ventaja. En el minuto 90+4, Lucas Vázquez entró al campo para suplir a Vinícius Júnior, que había sido sustituido por Éder Militão, y cerró una noche histórica para el club blanco.
#
# Carlo Ancelotti demostró, una vez más, su capacidad para gestionar partidos de alta presión y adaptar su estrategia según las circunstancias. La solidez defensiva del Real Madrid, combinada con la eficacia en ataque, fue la clave del triunfo. El Borussia Dortmund, por su parte, mostró un gran coraje y determinación, pero no pudo superar la superioridad técnica y táctica del rival.
#
# El Real Madrid se alza como campeón de Europa, consolidándose como una de las leyendas del fútbol mundial. Una victoria que, sin duda, quedará en el recuerdo de los aficionados españoles como una noche inolvidable en Wembley. El xG final del partido refleja la clara superioridad madridista: 1.86 contra 1.15. Un resultado que, a pesar de la dureza del encuentro, confirma la grandeza y la historia del Real Madrid.
#
#
# 📊 Palabras: 543

# %% [markdown]
# CHAIN OF THOUGHT

# %%
# FICHA 1 | Gemma | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Real Madrid 2-0 Dortmund (Wembley UCL Final)
2. GOLES: 74' Carvajal (córner Kroos), 83' Vinicius (asist. Bellingham)  
3. 1T: Dortmund domina (xG 1.86 vs 1.15 Madrid), Füllkrug poste
4. 2T: Madrid remonta, Courtois MVP 1T
5. JUGADOR: Carvajal

ESCRIBE crónica AS/Marca usando estos 5 puntos:"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 1 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)
# ================================================================================
# Aquí tienes una crónica estilo AS/Marca basada en los 5 puntos proporcionados:
#
# **Real Madrid se impone al Dortmund con un gol agónico y la figura de Carvajal en Wembley**
#
# El Real Madrid ha conquistado la Champions League tras vencer al Borussia Dortmund por 2-0 en una final épica disputada en el Estadio de Wembley. Un partido que, a pesar de la clara superioridad del Dortmund en los primeros 70 minutos, terminó con la victoria blanca gracias a un gol tardío de Carvajal y la desatención defensiva del rival.
#
# El primer tiempo fue dominio absoluto del Borussia. Los alemanes controlaron el juego, generando una clara superioridad en ataque (xG 1.86 contra 1.15 del Madrid) y poniendo en aprietos a la defensa madridista. La ocasión más clara llegó con un poste de Füllkrug que dejó sin opciones a Courtois.
#
# Sin embargo, el Real Madrid, liderado por un Courtois que se erigió como MVP de la primera mitad, resistió las embestidas del Dortmund y esperó su momento. En la segunda parte, la actitud cambió radicalmente. El equipo blanco, con una presión asfixiante, logró romper la muralla defensiva alemana.
#
# El gol de Carvajal, tras un córner magistral de Kroos, desató la locura en el banquillo madridista y abrió la puerta a la victoria.  Justo ocho minutos después, Vinicius Jr., con una asistencia impecable de Bellingham, selló el 2-0 definitivo, confirmando la superioridad del Real Madrid.
#
# **Carvajal, héroe inesperado.** El lateral derecho español fue clave en la contención defensiva y, finalmente, se convirtió en el autor del gol que levantó la décima Champions League para el Real Madrid.

# %%
# FICHA 1 | Gemma | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista AS/Marca. RAZONA PASO A PASO:

1. RESULTADO: Real Madrid 2-0 Dortmund Wembley UCL Final
2. GOLES: 74' Carvajal (córner Kroos), 83' Vinicius (asist. Bellingham)
3. 1T: Dortmund domina (xG 1.86 vs 1.15), Füllkrug poste min 23
4. 2T: Madrid remonta con goles
5. JUGADOR: Carvajal (MVP)

ESCRIBE crónica siguiendo tus 5 pasos:"""

response = client.chat.completions.create(
    model="google/gemma-3-1b",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=1500
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 1 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **Crónica AS/Marca: El Real Madrid, implacable, derriba al Dortmund en Wembley y conquista la Champions League**
#
# **1. RESULTADO:** Real Madrid 2-0 Dortmund - Wembley UCL Final
#
# **2. GOLES:** 74' Carvajal (córner Kroos), 83' Vinicius Jr. (asist. Bellingham)
#
# **3. 1T: El Dortmund asume el control.** La primera mitad fue un claro dominio del Borussia, que se impuso en la posesión y generó más oportunidades de gol. Su xG (esperado de goles) llegó a 1.86, mientras que el Real Madrid solo consiguió 1.15. Füllkrug tuvo una clara ocasión en el minuto 23, estrellando un poste tras un centro peligroso. El equipo alemán se mostró superior en todas las líneas y planteó un juego muy sólido.
#
# **4. 2T: La remontada blanca.**  El Real Madrid salió con otra actitud en la segunda mitad, aprovechando la intensidad del Dortmund para cambiar el ritmo del partido. Y fue en el minuto 74' cuando Carvajal, tras un córner botado por Kroos, sorprendió a Gregor Kobel y abrió el marcador. La alegría blanca se multiplicó al 83', con Vinicius Jr., asistido por Bellingham, que desató la locura en la grada madridista y selló la victoria.
#
# **5. JUGADOR: Carvajal, MVP.** El veterano defensa central del Real Madrid fue fundamental en la contundencia defensiva del equipo y, además, aprovechó su oportunidad para marcar un gol crucial que le valió el premio al mejor jugador del partido. Un auténtico héroe de la noche.
#
# **En resumen:** Una victoria sufrida pero necesaria para el Real Madrid, que demostró resiliencia y capacidad de reacción para conquistar la Champions League tras una primera mitad dominada por el Dortmund. ¡Hala Madrid!

# %%
# FICHA 1 | Gemma | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Real Madrid 2-0 Dortmund (Wembley UCL Final)
2. GOLES: 74' Carvajal (córner Kroos), 83' Vinicius (Bellingham)
3. 1T Dortmund domina: xG 1.86-1.15, Füllkrug poste min 23
4. 2T Madrid remonta con 2 goles
5. ESTADÍSTICAS: Posesión 46-54%, tiros 13-13
6. MVP: Carvajal

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Real Madrid se corona en Wembley y desplasta al Dortmund en una final de Champions épica
#
# **Entrada:** El Real Madrid ha conquistado la Champions League por sexta vez en su historia, derrotando al Borussia Dortmund en un vibrante encuentro que culminó con un 2-0 en el Estadio de Wembley. Una victoria merecida para los merengues, que demostraron resiliencia y determinación tras una primera mitad dominada por los alemanes, logrando una remontada espectacular en la segunda parte.
#
# **Cronología:** La historia de esta final se puede dividir en dos actos bien diferenciados. En el primer tiempo, el Borussia Dortmund salió con todo para imponer su dominio. El equipo alemán controló la posesión (54% frente al 46% del Real Madrid) y generó numerosas oportunidades de gol, incluyendo un peligroso poste de Youssoufa Füllkrug en el minuto 23. Su xG (esperado de goles) alcanzó los 1.86, superando con creces el 1.15 del Real Madrid. Sin embargo, la defensa blanca, liderada por un excepcional Dani Carvajal, se mantuvo firme y logró mantener a raya a los atacantes alemanes.
#
# La segunda mitad fue una muestra de carácter y capacidad de reacción por parte del Real Madrid. Tras una presión constante y con cambios tácticos inteligentes, el equipo blanco encontró la red en el minuto 74 gracias a un gol de Karim Benzema, que culminó un córner perfectamente ejecutado por Toni Kroos.  Pero la alegría no duró mucho. En el minuto 83, Vinicius Jr., asistido por Jude Bellingham, selló la victoria con un gol que desató la euforia en las gradas y confirmó la superioridad del Real Madrid.
#
# **Análisis xG:** Las estadísticas revelan una clara superioridad del Dortmund en la creación de oportunidades (xG 1.86 vs 1.15). Sin embargo, el Real Madrid supo aprovechar al máximo sus pocas ocasiones, transformando un 13% de ellas en goles, mientras que los alemanes solo lograron convertir el 13% de sus tiros a puerta. La diferencia en la posesión (46-54%) refleja el control inicial del Dortmund, pero no se tradujo en superioridad goleadora.
#
# **Cierre:** El Real Madrid ha demostrado ser un equipo imbatible en Wembley y una fuerza imparable en la Champions League.  La actuación de Dani Carvajal, elegido como MVP de la final, fue fundamental para la solidez defensiva del equipo blanco. Una victoria que consolida el legado de Carlo Ancelotti y reafirma al Real Madrid como el rey indiscutible del fútbol europeo. La conquista de esta sexta Champions League es un hito histórico para el club madrileño y una prueba más de su grandeza en la competición más prestigiosa del mundo.
#
#
# 📊 Palabras: 424

# %%
# CELDA 13 – FICHA 1 | Gemma | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista AS/Marca con 20 años experiencia Champions.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Real Madrid 2-0 Dortmund Wembley UCL Final 2024
2. GOLES: 74' Carvajal (córner Kroos), 83' Vinicius (asist. Bellingham)
3. 1T: Dortmund domina xG 1.86-1.15, Füllkrug poste min 23, Courtois MVP
4. 2T: Madrid remonta, Dortmund se hunde
5. ESTADÍSTICAS: Posesión 46-54%, tiros 13-13, córners 9-8
6. MVP: Carvajal (Jugador del partido)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos + 'merengues' 'aurinegros'"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **¡El Madrid se corona en Wembley! Un Carvajal heroico y un Vinicius letal desmantelan al Dortmund en una final de Champions inolvidable**
#
# Wembley, Londres – La noche europea ha sido para los merengues. El Real Madrid se alza con su decimosextima Copa de Europa tras vencer al Borussia Dortmund por 2-0 en una final de Champions League que quedará grabada en la memoria de todos los aficionados. Un partido cargado de tensión, emoción y un final de infarto que consolidó el dominio blanco en la competición más prestigiosa del mundo.
#
# La primera mitad fue un claro dominio aurinegro. Los alemanes, con una intensidad brutal, controlaron el balón y generaron numerosas ocasiones de gol. El Dortmund se impuso en la creación de oportunidades, alcanzando un xG (valor esperado de goles) de 1.86 frente al 1.15 del Real Madrid. Füllkrug, con un poste minúsculo a los 23 minutos, tuvo una ocasión clarísima para abrir el marcador que se estrelló en la madera. Thibaut Courtois, sin duda, fue el héroe blanco de la primera mitad, salvando al Madrid de la derrota con atajadas cruciales. Los merengues, por su parte, se defendieron con uñas y dientes, mostrando una solidez defensiva encomiable.
#
# La segunda mitad trajo un cambio radical en el rumbo del partido. El Real Madrid, liderado por Carlo Ancelotti, salió con otra actitud, presionando alto y buscando la portería alemana con insistencia. Y su recompensa llegó al minuto 74: un córner magistralmente ejecutado por Toni Kroos fue rematado de cabeza por Álvaro Carvajal, colocando el 1-0 en el marcador. El estadio se volcó en un rugido ensordecedor.
#
# Pero la historia no terminó ahí. Apenas tres minutos después, Jude Bellingham asistió a Vinicius Jr., quien con una velocidad y precisión letales batió al portero alemán y sentenció el partido (2-0). La alegría blanca fue incontenible. El Dortmund, visiblemente abatido, se hundió en la segunda mitad, perdiendo la iniciativa y sin encontrar respuestas ante la solidez defensiva del Real Madrid.
#
# Las estadísticas reflejan la superioridad madridista en los últimos minutos: posesión 46% contra el 54%, con un ligero favoritismo de tiros (13-13) y una clara dominación en córners (9-8). Sin embargo, las cifras no cuentan toda la historia. Lo que sí cuenta es la determinación, la experiencia y la capacidad de sufrimiento del Real Madrid para levantar su decimo sexta Champions League.
#
# Carvajal, nombrado Jugador del Partido, fue el arquitecto de la victoria con su remate en el córner y su liderazgo en defensa. Un partido épico, un final inolvidable que confirma al Real Madrid como el rey indiscutible de Europa. ¡Hala Madrid!
#
#
# 📊 Palabras: 428

# %% [markdown]
# FICHA 2
# ZERO SHOT

# %%
# FICHA 2 | Gemma | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha2 = """ID_PARTIDO: UCL_2024_J1_BAY_DIN
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1
Fecha: 17/09/2024
Hora: 19:00 UTC
Estadio: Allianz Arena (Múnich)
Asistencia: 75 000
Árbitro: Juan Martínez Munuera (España)

Equipo 1: Bayern Munich
Equipo 2: Dinamo Zagreb

Entrenador Bayern Munich: Vincent Kompany
Entrenador Dinamo Zagreb: Sergej Jakirović

Alineación Bayern Munich:
Neuer; Kimmich, Upamecano, De Ligt, Davies; Goretzka, Pavlović; Olise, Musiala, Sané; Kane

Alineación Dinamo Zagreb:
Livaković; Ristovski, Théophile-Catherine, Mmaee, Smolcic; Mišić, Perić; Pjaca, Baturina, Hoxha; Petković

Resultado final: Bayern Munich 9 – 2 Dinamo Zagreb
Resultado al descanso: 3–0

Goles:
19’ Harry Kane (Bayern Munich), gol de penalti
34’ Raphaël Guerreiro (Bayern Munich), gol
38’ Michael Olise (Bayern Munich), gol
48’ Harry Kane (Bayern Munich), gol
57’ Michael Olise (Bayern Munich), gol
73’ Harry Kane (Bayern Munich), gol de penalti
81’ Kingsley Coman (Bayern Munich), gol
87’ Joshua Kimmich (Bayern Munich), gol
90+3’ Mathys Tel (Bayern Munich), gol

Goles Dinamo Zagreb:
49' Bruno Petković, gol
50' Takuya Ogiwara, gol

Tarjetas amarillas Bayern Munich: N/D
Tarjetas amarillas Dinamo Zagreb: 77' Ristovski
Tarjetas rojas: N/D

Sustituciones Bayern Munich: N/D
Sustituciones Dinamo Zagreb: N/D

Eventos registrados:
19’ Penalti a favor del Bayern Munich convertido por Harry Kane
73’ Segundo penalti a favor del Bayern Munich convertido por Harry Kane

Estadísticas totales:
Posesión (%): 72 – 28
Tiros: 32 – 7
Córners: 12 – 2

Estadísticas avanzadas:
xG: 5.4 – 1.2

Jugador del partido: Harry Kane"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha2}"

response = client.chat.completions.create(
    model="google/gemma-3-4b",  # ✅ COMA AÑADIDA
    messages=[{"role": "user", "content": prompt_config1}],  # ✅ COMA AÑADIDA
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 1 (Gemma | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 2 – CONFIG 1 (Gemma | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# ## El Bayern, una furia imparable, anota nueve goles al Dinamo Zagreb en un recital de dominio absoluto
#
# **Allianz Arena, Múnich -** La Champions League ha dado la bienvenida a la temporada 2024/25 con un espectáculo que no se esperaría ni en los sueños más ambiciosos del Bayern Munich. El equipo de Vincent Kompany, liderado por una máquina imparable como Harry Kane, desató su potencial ofensivo ante un Dinamo Zagreb que se vio abrumado desde el primer minuto y terminó recibiendo una humillante derrota de 9-2.
#
# La noche en Múnich fue para olvidar para los croatas, que llegaron al Allianz Arena con la esperanza de plantar cara a uno de los gigantes europeos. Sin embargo, esa ilusión se desvaneció rápidamente tras un penalti temprano convertido por Harry Kane en el minuto 19. El delantero inglés, ya en plena forma, demostró su capacidad goleadora y sentó las bases de una noche histórica para el Bayern.
#
# El Dinamo Zagreb intentó reaccionar, pero la defensa del Bayern, liderada por un sólido De Ligt y Upamecano, se mostró impenetrable. La presión bávara fue constante y, en el minuto 34, Raphaël Guerreiro aprovechó una internación para marcar el segundo gol, desatando la euforia entre los aficionados locales.
#
# La segunda mitad fue un auténtico festival de goles. Michael Olise, con su velocidad y habilidad, se incorporó al ataque para marcar dos tantos más en el minuto 38 y el 57, demostrando que Kompany ha encontrado el equilibrio perfecto en su equipo. Kane volvió a aparecer en el marcador en los minutos 48 y 73, ambos convertidos desde los penaltis, consolidando su estatus como el máximo goleador del partido.
#
# El capitán Kingsley Coman y el joven Mathys Tel completaron la goleada en los últimos minutos, con goles en el 81’ y el 90+3’, respectivamente, para sellar una actuación que quedará grabada en la memoria de los aficionados. El Dinamo Zagreb logró dos goles aislados a través de Bruno Petković (minuto 49) y Takuya Ogiwara (minuto 50), pero fueron esfuerzos insuficientes para frenar el embate del Bayern.
#
# **Un Kane imparable, un partido demoledor**
#
# Harry Kane fue, sin duda, la figura indiscutible de la noche. Con nueve puntos en su cuenta, el delantero inglés ha demostrado que está decidido a conquistar Europa y a seguir demostrando por qué es uno de los mejores delanteros del mundo. Su capacidad goleadora, combinada con la solidez defensiva del Bayern, hizo imposible para el Dinamo Zagreb ofrecer una resistencia digna.
#
# **Estadísticas que hablan por sí solas:** El dominio del Bayern fue absoluto en todos los aspectos del juego. Con un 72% de posesión y 32 tiros contra solo 7 del Dinamo, la superioridad bávara fue evidente desde el principio. La diferencia en xG (5.4 – 1.2) refleja la clara superioridad ofensiva del equipo alemán.
#
# **El futuro se presenta brillante para el Bayern:** Este triunfo no solo consolida al Bayern Munich como uno de los favoritos para llegar a las rondas finales de la Champions League, sino que también demuestra la capacidad de Vincent Kompany para transformar su equipo en una máquina goleadora imparable. El Dinamo Zagreb, por su parte, deberá analizar este duro revés y prepararse para afrontar un grupo complicado.
#
# **En resumen:** Una noche histórica en el Allianz Arena, donde el Bayern Munich demostró su poderío ofensivo y dejó claro que está dispuesto a luchar por los títulos de Europa. Un partido que quedará grabado en la memoria de los aficionados como uno de los más espectaculares de la Champions League.

# %%
# FICHA 2 | Gemma | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha2}""".format(ficha2=ficha2)

response = client.chat.completions.create(
    model="google/gemma-3-1b",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=1500
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 2 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El Bayern, una furia imparable, anota nueve goles al Dinamo Zagreb y desata la Champions League
#
# **Por Miguel Ángel Sánchez, AS**
#
# El Allianz Arena fue ayer un auténtico hervidero de emociones, pero no en el sentido que esperaba el Dinamo Zagreb. El gigante bávaro, con Vincent Kompany al mando, se deshizo del modesto equipo croata con una exhibición de poderío ofensivo y un marcador final de 9-2 que deja claro que el Bayern Munich es la máxima potencia europea.
#
# Desde el pitido inicial, el Bayern dominó el partido con una intensidad brutal. La presión alta, la velocidad de Musiala y Sané, y la letalidad de Kane en los penaltis desataron un ataque implacable contra la defensa del Dinamo Zagreb, que se vio rápidamente superada. El joven Harry Kane, ya instalado en su nuevo hogar, demostró una vez más por qué es uno de los delanteros más temidos del mundo, convirtiendo dos de los tres penaltis concedidos y sentando las bases de una goleada histórica.
#
# El primer gol, al 19’, llegó tras un penal dudoso que Kane transformó con sangre fría. A partir de ahí, el partido se convirtió en un recital de goles. Raphaël Guerreiro (34’) amplió la ventaja con un disparo cruzado y Michael Olise (38’) sumó otro gol para dejar el partido en 3-0 al descanso.
#
# El Dinamo Zagreb intentó reaccionar tras el descanso, pero se encontró con una muralla infranqueable del Bayern. Bruno Petković (49’) y Takuya Ogiwara (50’) lograron dos goles de honor que, aunque importantes para la estadística, no pudieron frenar el atropello bávaro.  Kane volvió a aparecer en el marcador al minuto 48’ y luego, con dos nuevos penaltis al 73’ y 81’, selló su hat-trick y la victoria del Bayern. Kingsley Coman (81’) y Joshua Kimmich (87’) completaron la goleada, mientras que Mathys Tel cerró el marcador en el tiempo de descuento (90+3’).
#
# **Un Dinamo Zagreb humillado pero con orgullo**
#
# El Dinamo Zagreb, por su parte, se vio abrumado por la superioridad del Bayern. A pesar de las tarjetas amarillas concedidas a Ristovski (77’), no lograron generar ninguna amenaza real ante la defensa bávara. El equipo croata demostró coraje y determinación, pero careció de ideas y recursos para contrarrestar el ataque implacable del gigante alemán.
#
# **Harry Kane, el rey de la noche**
#
# La actuación de Harry Kane fue, sin duda, la más destacada del partido. Con cinco goles en su debut con el Bayern Munich, el delantero inglés se consolida como una pieza clave para las ambiciones del equipo. Su capacidad goleadora y su presencia en el área son un arma letal que no puede ser subestimada.
#
# **Análisis Final:**
#
# El Bayern Munich ha dado una señal contundente de sus intenciones en la fase de grupos de la Champions League. Con esta victoria, el equipo bávaro se asegura el primer puesto del grupo y probablemente el mejor emparejamiento en octavos de final. El Dinamo Zagreb, por su parte, deberá analizar los errores que cometió y trabajar para mejorar su defensa si quiere tener opciones de avanzar en la competición.
#
# **Calificación: 9/10** - Un partido aplastante del Bayern Munich, con una exhibición ofensiva impresionante y un marcador final que deja claro quién es el rey de Europa.

# %%
#FICHA 2 | Gemma | Zero-shot | Sin rol | CON RESTRICCIONES
prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha2}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 2 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Bayern, una furia imparable, anota nueve goles al Dinamo Zagreb en un recital de dominio
#
# **Múnich –** La Allianz Arena fue testigo esta noche de una exhibición de poderío absoluto del FC Bayern Múnich, que se deshizo del Dinamo Zagreb con un contundente 9-2. Un partido que, más allá del resultado, dejó claro el camino que Vincent Kompany quiere imprimir a su equipo y la necesidad urgente de revitalización en el conjunto croata.
#
# La noche comenzó con una atmósfera electrizante, con una asistencia de 75.000 espectadores ansiosos por ver cómo se desarrollaba este primer encuentro de la fase de grupos de la Champions League. Y no decepcionó, aunque quizás demasiado para los aficionados del Dinamo Zagreb. Desde el pitido inicial, el Bayern tomó las riendas del partido, ejerciendo una presión asfixiante sobre la defensa visitante y buscando constantemente la portería de Livaković.
#
# El primer gol llegó en el minuto 19, tras un penalti cometido por Ristovski. Harry Kane, con su habitual frialdad, no falló desde los once metros, adelantando a los bávaros por primera vez. La insistencia del Bayern continuó y, en el 34’, Raphaël Guerreiro aprovechó una internada para marcar el segundo gol, consolidando la ventaja de tres al descanso.
#
# La segunda mitad fue un auténtico festival de goles. En el minuto 38, Michael Olise, con un disparo imparable, aumentó la cuenta local, dejando a los visitantes en una situación desesperada. La reacción del Dinamo Zagreb fue mínima y, en el minuto 49, Bruno Petković logró descontar, pero la alegría duró poco. Justo después, en el 50’, Takuya Ogiwara sorprendió a Livaković con un gol de cabeza, aunque este tanto no sirvió para frenar el atropello bávaro.
#
# El Bayern, imparable, siguió atacando y, en el minuto 57, Olise volvió a aparecer en la zona ofensiva para marcar su segundo gol del partido. La insistencia continuó y, en el minuto 73’, Kane fue nuevamente decisivo tras otro penalti, confirmando así su estatus como máximo goleador del equipo. En el 81’ Kingsley Coman y, finalmente, en el 87’ Joshua Kimmich cerraron la goleada con dos nuevos goles que sellaron un resultado abrumador. Para completar la noche, Mathys Tel se sumó al marcador en el tiempo de descuento (90+3’), dejando el partido definitivo: 9-2.
#
# Las estadísticas reflejan la superioridad del Bayern, que dominó el encuentro por completo, controlando la posesión (72% frente al 28%) y generando un xG significativamente mayor (5.4 contra 1.2). El Dinamo Zagreb, por su parte, recibió siete tarjetas amarillas, con Ristovski siendo el más castigado, evidenciando la intensidad del partido y la dificultad que encontraron para contener el ataque bávaro.
#
# Harry Kane fue nombrado jugador del partido, merecidamente, gracias a sus tres goles y su capacidad goleadora. Sin embargo, este resultado no solo es una victoria para el Bayern, sino también un duro golpe de realidad para el Dinamo Zagreb, que deberá replantearse su estrategia si quiere aspirar a seguir adelante en la competición europea. La Champions League, como siempre, exige despliegue total y, esta noche, el Bayern lo demostró con creces.
#
#
# 📊 Palabras: 506

# %%
#FICHA 2 | Gemma | Zero-shot | CON ROL | CON RESTRICCIONES
prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha2}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## El Bayern desata la barbarie en el Allianz Arena y humilla al Dinamo Zagreb con un 9-2 que deja a todos boquiabiertos
#
# **Por [Tu Nombre], periodista deportivo de AS/Marca**
#
# El Allianz Arena se convirtió anoche en un auténtico infierno para el Dinamo Zagreb, escenario de una exhibición brutal del Bayern Múnich que dejó un marcador final de 9-2 y una sensación de incredulidad en la grada. Tras dos años de espera, Vincent Kompany ha vuelto a demostrar por qué es uno de los entrenadores más respetados del mundo, liderando a su equipo hacia una Champions League donde el dominio absoluto parece ser la norma.
#
# **Entrada impactante: Un Bayern despiadado desde el primer minuto**
#
# La previa no prometía nada bueno, pero el inicio del partido fue aún más demoledor de lo que cualquiera podría haber imaginado. En el 19’, un penalti cometido por Ristovski sobre Kane, convertido con frialdad por el propio delantero inglés, abrió la lata. El Dinamo, visiblemente intimidado, no logró reaccionar y en el 34’ Guerreiro amplió la ventaja con un disparo cruzado que se coló en la portería de Livaković.  El partido ya no era una competición, sino una lección de fútbol para aquellos que se atrevían a creer en la posibilidad de un milagro.
#
# **Desarrollo cronológico: Un recital de goles y ocasiones**
#
# La segunda mitad fue aún más descontrolada. En el 38’, Olise, con una velocidad y precisión asombrosas, aprovechó un hueco para marcar su primer gol del partido, elevando la ventaja a 3-0.  El Dinamo, que se había mostrado incapaz de generar peligro ofensivo, recibió un golpe seco en el alma. En el minuto 49’, Petković logró descontar con un remate dentro del área, pero la alegría duró poco. Justo al minuto siguiente, el Bayern recuperaba un penalti (esta vez por una falta sobre Musiala) y Kane, imparable, volvía a firmar en el marcador.  La insistencia bávara se tradujo en dos nuevos penaltis en los minutos 73’ y 81’, ambos convertidos también por Kane, consolidando su estatus como máximo goleador del partido y del equipo. En el descuento, Coman y Tel sellaron la victoria con goles de espectacularidad, dejando al Dinamo sin opciones.
#
# **Cierre reflexivo: Un Bayern que domina y un Dinamo en crisis**
#
# El marcador final de 9-2 es una cifra que refleja la superioridad absoluta del Bayern Múnich.  Con un xG de 5.4 frente a los 1.2 del Dinamo, el dominio bávaro fue abrumador. La posesión (72% vs 28%) y los tiros (32 vs 7) son solo dos ejemplos más de la superioridad táctica y física del equipo de Kompany.  La actuación de Harry Kane ha sido, sin duda, la protagonista indiscutible. El delantero inglés, con un hat-trick y dos goles en penalti, ha demostrado una vez más por qué es uno de los mejores delanteros del mundo.
#
# El Dinamo Zagreb, por su parte, sufrió una derrota humillante que pone en serias dudas su capacidad para competir en la Champions League.  La falta de ideas ofensivas, la ineficacia y la fragilidad defensiva fueron las principales razones de su debacle. El equipo croata deberá replantearse su estrategia si quiere tener alguna esperanza de avanzar en la competición.
#
# **Jugador del partido: Harry Kane (9/10)** – Su capacidad goleadora, su precisión en los penaltis y su liderazgo en el ataque lo convierten en el claro protagonista de este partido.  Un rendimiento excepcional que consolida su posición como uno de los mejores delanteros de Europa.
#
# Este resultado no solo demuestra la calidad del Bayern Múnich, sino también la vulnerabilidad del Dinamo Zagreb. La Champions League se presenta como un desafío exigente para ambos equipos, pero el camino del Bayern parece mucho más claro que el del Dinamo.  La pregunta ahora es: ¿podrá el Dinamo Zagreb reaccionar ante su próximo rival o será esta derrota una señal de alarma para todo el proyecto?
#
#
# 📊 Palabras: 636

# %% [markdown]
# FEW SHOT
# FICHA 2

# %%
# FICHA 2 | Gemma | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Gemma NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha2}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 2 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# El Bayern Munich se impuso con contundencia ante el Dinamo Zagreb en su estadio, el Allianz Arena de Múnich, en un encuentro correspondiente a la primera jornada de la fase de grupos de la UEFA Champions League. El marcador final reflejó la superioridad bávara, que se llevó una victoria por 9-2. Harry Kane fue el máximo goleador del partido, con cuatro tantos, además de otros tres de Michael Olise y un gol de Kingsley Coman y Joshua Kimmich. Los goles tempranos de Kane (de penalti), Guerreiro, Olise y Kane (otro de penalti) sentaron las bases de la contundente victoria.  El Dinamo Zagreb logró anotar dos goles en el primer tiempo con Petković y Ogiwara, pero no pudo reaccionar ante el dominio absoluto del Bayern. En la segunda mitad, Kane volvió a marcar dos veces desde los once metros, Olise añadió otro gol y Coman y Kimmich cerraron la goleada. El partido se resolvió rápidamente, dejando claro el abismo entre ambos equipos.

# %%
# FICHA 2 | Gemma | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha2 para aficionados que leen AS o Marca:
{ficha2}"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 1 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# **¡El Bayern humilla al Dinamo Zagreb con una exhibición de poderío y un Kane imparable!**
#
# Múnich, 17 de septiembre de 2024 - El Allianz Arena fue testigo esta noche de una goleada histórica. El Bayern Múnich ha destrozado al Dinamo Zagreb por un contundente 9-2, dejando claro que Vincent Kompany tiene mucho trabajo por delante para levantar a los bávaros. Un partido dominado desde el primer minuto por la máquina ofensiva del equipo alemán y, sobre todo, por la implacable puntería de Harry Kane.
#
# Desde el pitido inicial, el Bayern se mostró con una intensidad brutal, buscando asfixiar al Dinamo Zagreb en su propio campo. Y lo consiguió. En apenas 19 minutos, el marcador ya reflejaba la superioridad del equipo bávaro gracias a un penalti transformado por Kane tras una falta sobre Musiala. Pero la fiesta no paró ahí.
#
# Raphaël Guerreiro (34’), Michael Olise (38’) y Harry Kane (48’, 73’ – otro penalti) volvieron a desatar el marcador, dejando al Dinamo Zagreb en estado de shock. El croata logró responder con dos goles de Bruno Petković (49’) y Takuya Ogiwara (50’), pero la reacción fue efímera. Olise (57’) y Kane (81’) sellaron una noche que pasará a la historia del club múnicho, mientras Kingsley Coman (87’) y Joshua Kimmich (90+3) completaron el marcador final.
#
# El Bayern dominó por completo el partido, controlando la posesión (72% frente al 28%) y generando un xG de 5.4 contra solo 1.2 del Dinamo Zagreb. La diferencia en disparos también fue abismal: 32 a 7.  La defensa del Dinamo, claramente superada, no pudo contener la avalancha ofensiva del Bayern.
#
# Harry Kane, con una actuación estelar y dos goles de penalti, se llevó el premio al Jugador del Partido, demostrando por qué es uno de los delanteros más letales del mundo.
#
# Este resultado deja al Dinamo Zagreb en una situación muy complicada en la fase de grupos de la Champions League. El Bayern, por su parte, empieza con buen pie y demuestra que sigue siendo un equipo a tener en cuenta en Europa.  Kompany tendrá que encontrar soluciones rápidas para evitar que este tipo de humillaciones se repitan.

# %%
#FICHA 2 | Gemma | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha2 para aficionados al fútbol que leen AS o Marca:

{ficha2}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Bayern, una máquina imparable contra un Zagreb que se vio superado por la implacabilidad bávara
#
# El Allianz Arena vibró anoche con el rugido de su afición, pero no fue suficiente para frenar la avalancha del Bayern Múnich. Los alemanes pulverizaron al Dinamo Zagreb 9-2 en una exhibición de poderío ofensivo que dejó a los croatas sin opciones y demostró, una vez más, la superioridad del equipo bávaro. Un partido dominado desde el primer minuto por un Bayern que no dio respiro al rival y lo castigó con una precisión quirúrgica.
#
# La primera mitad fue un recital de goles. En el 19’, Harry Kane transformó un penalti para adelantar a los locales, iniciando una racha goleadora que parecía incesante. Apenas tres minutos después, Raphaël Guerreiro aprovechó un error defensivo para ampliar la ventaja. El Bayern no se detuvo y, en el 38’, Michael Olise, con un disparo imparable, elevó el marcador a 3-0. La sensación era clara: el Dinamo Zagreb estaba ante una tarea hercúlea.
#
# La segunda mitad continuó en el mismo compás. En el 49’, Bruno Petković logró descontar para los visitantes, pero la respuesta del Bayern fue inmediata. Harry Kane volvió a aparecer desde las doce yardas en el 50’ para marcar su segundo gol del partido y restablecer la distancia. Olise, con otra pincelada de clase, aumentó la ventaja en el 57’. La insistencia bávara culminó con los goles de Kane (73’, penalti) y Coman (81’) y, finalmente, Joshua Kimmich (87’) y Mathys Tel (90+3’), cerrando un marcador que reflejaba la superioridad absoluta del equipo alemán.
#
# El Dinamo Zagreb, por su parte, se vio abrumado por el ritmo y la intensidad del partido. A pesar de conseguir dos goles gracias a Petković y Ogiwara, no pudieron contener la avalancha de ocasiones del Bayern. Las estadísticas hablan claro: el Bayern dominó la posesión (72% frente al 28%) y el xG (5.4 contra 1.2), evidenciando su superioridad táctica y física. La actuación de Harry Kane, con sus tres goles y dos penaltis convertidos, fue indiscutiblemente la más destacada del partido, consagrándolo como el Jugador del Partido.
#
# Este resultado no solo consolida la posición del Bayern en la fase de grupos, sino que también subraya su capacidad para dominar cualquier rival. El Dinamo Zagreb, por su parte, deberá analizar sus errores y buscar mejorar su defensa si quiere aspirar a competir con los grandes equipos europeos. Una noche oscura para el fútbol croata, pero una noche gloriosa para el Bayern Múnich, un equipo que sigue demostrando ser una máquina imparable en la Champions League.
#
#
# 📊 Palabras: 425

# %%
# FICHA 2 | Gemma | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha2 para aficionados que leen AS o Marca:

{ficha2}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## El Bayern, una máquina imparable: 9-2 al Dinamo Zagreb en un recital de ataque
#
# **Múnich se convierte en el escenario de una exhibición brutal del Bayern Munich, que ha humillado al Dinamo Zagreb con un 9-2 que deja claro que Vincent Kompany está construyendo un equipo con hambre de goles y dominio absoluto.** El Allianz Arena vibró hasta la última hora, testigo de un partido donde el ataque bávaro fue implacable y el Dinamo Zagreb se vio abrumado por una velocidad y precisión inigualables. Para los aficionados de AS/Marca, este resultado no solo es un triunfo deportivo, sino una confirmación de que el Bayern está en camino a dominar la Champions League.
#
# **La entrada impactante llegó temprano, en el minuto 19**, cuando Harry Kane transformó un penalti con frialdad y colocó al Bayern por delante. La afición local ya sentía la atmósfera de un partido fácil, pero Kompany no quería dar respiro a sus jugadores. El Dinamo Zagreb, sin embargo, intentaba resistir, aunque su defensa se mostró vulnerable ante el ataque constante del gigante bávaro.  La insistencia del Bayern se vio recompensada en el minuto 34 cuando Raphaël Guerreiro aprovechó un error defensivo para marcar el segundo gol y ampliar la ventaja a 2-0.
#
# **La cronología del partido fue una sucesión de goles y ocasiones.** El Dinamo, con valentía pero sin recursos ofensivos, logró sorprender al Bayern en el minuto 49 gracias a Bruno Petković, reduciendo las diferencias. Sin embargo, esta alegría duró poco.  En apenas dos minutos, Michael Olise, con un disparo imparable, y Harry Kane, nuevamente desde los once metros, volvieron a colocar al Bayern por delante en el marcador (3-1). La insistencia del equipo bávaro continuó, y en el minuto 57, Olise volvió a aparecer para marcar su segundo gol del partido.  La defensa croata se desmoronaba bajo la presión constante de un ataque letal.
#
# **El descanso llegó con un 4-1 en el marcador, pero el Bayern no se detuvo.** En la segunda mitad, Kane siguió siendo la estrella del partido, convirtiendo dos penaltis más (73’ y 81’) para elevar su cuenta a cinco goles. Kingsley Coman (81’) y Joshua Kimmich (87’) sellaron una actuación magistral del equipo bávaro, mientras que Mathys Tel (90+3’) redondeó la goleada final. El Dinamo Zagreb, sin opciones, se vio superado por un Bayern que no paraba de marcar.
#
# **El resultado final, 9-2, es un reflejo de la superioridad absoluta del Bayern Munich.**  Con una posesión del 72% y un xG de 5.4 contra el 1.2 del Dinamo Zagreb, el equipo bávaro dominó el partido desde el principio hasta el final. La actuación de Harry Kane, con cinco goles, fue excepcional, pero la contribución de todos los jugadores ofensivos del Bayern fue fundamental para este resultado abrumador.
#
# **En conclusión**, este partido no solo es un triunfo deportivo para el Bayern Munich, sino también una muestra de la ambición y el poderío que Kompany está construyendo en el banquillo bávaro. El Dinamo Zagreb, por su parte, sufrió una derrota humillante que le obliga a replantearse su proyecto deportivo.  Para los aficionados de AS/Marca, este resultado confirma que el Bayern Munich es un equipo a tener muy en cuenta en la Champions League y que, con esta forma, puede llegar hasta lo más alto. La pregunta ahora es: ¿podrá el resto de los equipos de Europa competir con una máquina tan implacable como esta?
#
#
# 📊 Palabras: 561

# %% [markdown]
# CHAIN OF THOUGHT
# FICHA 2

# %%
# FICHA 2 | Gemma | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Bayern Munich 9-2 Dinamo Zagreb (Allianz Arena, UCL 2024/25)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern domina, 3-0 al descanso, posesión 72%, xG 5.4 vs 1.2
4. 2T: Goleada histórica con hat-trick de Kane, Dinamo marca dos seguidos (49'–50'), but sin reacción
5. JUGADOR: Harry Kane (3 goles, liderazgo, clave ofensiva)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales
"""
response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 2 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 2 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)
# ================================================================================
# Aquí tienes dos versiones de crónica, una al estilo AS y otra a la Marca, basadas en los datos proporcionados. Ambas intentan capturar el tono y estilo que solicitaste:
#
# **Opción 1: Estilo AS**
#
# **¡UNA MÁQUINA DE GOLES! El Bayern Devasta al Dinamo Zagreb con un 9-2 Histórico**
#
# El Allianz Arena fue testigo de una exhibición ofensiva brutal del FC Bayern Munich, que pulverizó al Dinamo Zagreb por un contundente 9-2 en su debut en la Champions League. Un partido que quedará grabado en la memoria por la implacable dominación bávara y el hat-trick de Harry Kane.
#
# Desde el pitido inicial, el Bayern se mostró con una intensidad asombrosa, controlando el balón y ejerciendo una presión constante sobre la defensa croata. Kane abrió el marcador temprano con un penalti (19’) y Guerreiro respondió con un gol sorpresa (34’). Sin embargo, la superioridad del equipo bávaro era innegable. Olise, Ogiwara y Coman se sumaron al ataque, desatando una avalancha de goles que dejó a Zagreb sin opciones.
#
# El descanso llegó con el marcador 3-0 a favor del Bayern, un resultado que reflejaba la clara superioridad en posesión (72%) y en la creación de oportunidades (xG 5.4 vs 1.2). En la segunda mitad, Kane se convirtió en el protagonista absoluto, anotando tres goles más, incluyendo dos penaltis (48’ y 73’) que sellaron su actuación histórica. Petković y Tel también se unieron a la fiesta goleadora, completando la contundente victoria.
#
# **Kane, el Rey de la Noche:** El delantero inglés no solo marcó tres goles, sino que lideró el ataque del Bayern con una presencia constante y decisiva. Su capacidad para transformar penaltis en goles es simplemente asombrosa. Un jugador clave, sin duda.
#
# Un 9-2 que deja al Dinamo Zagreb con un reto monumental y al Bayern Munich como uno de los favoritos para avanzar en la Champions League. ¡Una noche para olvidar!
#
#
# **Opción 2: Estilo Marca**
#
# **¡EXPLOSIÓN BÁVARA! El Bayern, una Bomba de Goles Contra el Dinamo (9-2) – Kane, el Arquitecto de la Victoria**
#
# El Allianz Arena se convirtió en un auténtico campo de fútbol para el FC Bayern Munich, que desató su potencial ofensivo y derrotó al Dinamo Zagreb por 9-2. Un resultado demoledor, una goleada histórica que deja al equipo croata con la misión casi imposible de remontar.
#
# Desde el primer minuto, el Bayern dominó el partido, ejerciendo un control absoluto del balón y asfixiando la salida del Dinamo. Kane abrió el marcador con un penalti (19’) y Guerreiro sorprendió a Neuer con un gol inesperado (34’). Pero la respuesta bávara fue inmediata y devastadora.
#
# La segunda mitad fue una exhibición de poderío ofensivo. Kane, imparable, se llevó los focos, anotando tres goles más, incluyendo dos penaltis que consolidaron su actuación. Ogiwara, Olise, Petković, Coman y Tel completaron la goleada, dejando a Zagreb sin tiempo para reaccionar.
#
# **Kane: El Hombre del Partido:**  El delantero inglés no solo marcó tres goles, sino que fue el motor de ataque del Bayern. Su liderazgo en la punta de ataque y su capacidad goleadora lo convierten en un jugador fundamental para el equipo. Un hat-trick que quedará en la historia.
#
# Con una posesión del 72% y un xG superior a cinco veces al del Dinamo (5.4 vs 1.2), el Bayern demostró ser un equipo imparable.  Una victoria contundente que avanza las aspiraciones del Bayern en la Champions League. ¡Un partido para recordar!
#
# ---
#
# Espero que estas versiones te sean útiles. He intentado capturar el estilo periodístico de cada medio, priorizando la expresividad y el ritmo narrativo.

# %%
# FICHA 2 | Gemma | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, UCL 2024/25, Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern impone ritmo, 3-0 antes del descanso, dominio total (posesión 72%, xG 5.4 vs 1.2)
4. 2T: Dinamo anota dos seguidos (49’-50’), pero el festival bávaro continúa con hat-trick de Kane y lluvia de goles
5. JUGADOR: Harry Kane (3 goles, participación clave, líder ofensivo)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Kompany
- No inventes declaraciones ni citas textuales
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 2 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **¡El Bayern, una máquina imparable! El Dinamo Zagreb no pudo frenar el tsunami bávaro en la Champions (9-2)**
#
# 1. **El Resultado:** Un 9-2 que deja a todos boquiabiertos. Una humillación para el Dinamo Zagreb y un mensaje brutal del Bayern Múnich.
# 2. **Los Goles:** Kane, Guerreiro, Olise, Kane, Petković, Ogiwara, Olise, Kane (pen.), Coman, Kimmich, Tel. Un recital de goles que recuerda al Bayern en su mejor momento.
# 3. **La Primera Parte:** El Bayern dominó desde el primer minuto. Imponiendo un ritmo frenético, controlando el balón y asfixiando al Dinamo. 3-0 al descanso. ¡Una exhibición de poderío! (72% posesión, 5.4 xG frente a 1.2).
# 4. **La Segunda Parte:** El Dinamo intentó reaccionar con dos goles seguidos, pero el Bayern no se inmutó. Kane, imparable, siguió marcando y la lluvia de goles continuó. ¡Un festival bávaro!
# 5. **El Jugador:** Harry Kane, el rey indiscutible. 3 goles, un líder ofensivo que desató su artillería y dejó claro que sigue siendo uno de los mejores del mundo.
#
# **Comentario:** El Bayern Múnich, bajo la dirección de Kompany, ha demostrado una vez más su ambición en la Champions League. Un partido aplastante que deja al Dinamo Zagreb con un reto monumental para las próximas jornadas.  El equipo alemán, con Kane como principal protagonista, se presenta como un serio aspirante al título. ¡Un Bayern imparable!

# %%
# FICHA 2 | Gemma | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, UEFA Champions League 2024/25, Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern 3-0 al descanso, dominio absoluto en posesión (72%) y ritmo ofensivo; Dinamo apenas se asoma
4. 2T: Dos goles rápidos del Dinamo (49’, 50’) antes del festival bávaro final con seis tantos más
5. ESTADÍSTICAS: Posesión 72–28%, tiros 32–7, córners 12–2, xG 5.4–1.2
6. MVP: Harry Kane (hat-trick, líder de ataque, decisivo)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Bayern Munich Aplasta al Dinamo Zagreb en la Primera Jornada de Champions League**
#
# El Allianz Arena fue testigo de una exhibición de poderío bávaro que dejó un marcador final de 9-2 frente al Dinamo Zagreb. El Bayern Munich, liderado por Harry Kane, dominó el encuentro desde el principio y desató un ataque implacable contra el equipo croata, que apenas pudo contener los embates del gigante alemán.
#
# **Cronología del Partido:**
#
# El partido comenzó con una temprana ventaja para el Bayern gracias a un penalti transformado por Harry Kane en el minuto 19.  A lo largo de la primera mitad, el dominio bávaro fue absoluto. El equipo de Múnich controló la posesión del balón (72% contra el 28%) y mantuvo un ritmo ofensivo constante, asfixiando al Dinamo Zagreb. A los 34 minutos, Guerreiro redujo distancias con un gol que puso el 2-0 en el marcador.  La segunda mitad vio una explosión de goles por parte del Bayern. En el minuto 48, Petković aprovechó una oportunidad para marcar su primer tanto, seguido inmediatamente por el gol de Ogiwara en el minuto 50, colocando el 4-0. El ritmo se aceleró aún más con los goles de Olise (minutos 57 y 81), Kane (minutos 49 y 73, ambos también penales) y Coman (minuto 81).  El partido culminó con dos goles en el tiempo añadido: Kimmich en el minuto 87 y Tel en el minuto 90+3.
#
# **Análisis Estadístico:**
#
# Las estadísticas reflejan la superioridad del Bayern Munich. El equipo bávaro disparó 32 veces contra los 7 del Dinamo Zagreb, con una diferencia de xG (valor esperado de goles) de 5.4 a 1.2.  El control del balón fue fundamental, con el Bayern teniendo 12 córners frente a los 2 del Dinamo. La clara superioridad en posesión y la efectividad en ataque demostraron la calidad del equipo alemán.
#
# **Harry Kane, el Arquitecto de la Victoria:**
#
# La actuación de Harry Kane fue excepcional. El delantero inglés marcó un hat-trick (tres goles) y lideró el ataque del Bayern con una eficacia brutal. Su capacidad para transformar penaltis también contribuyó significativamente a la victoria.  Kane no solo anotó goles, sino que también demostró ser decisivo en el juego ofensivo del equipo.
#
# **Conclusión:**
#
# El Bayern Munich inició su camino en la Champions League con una contundente victoria sobre el Dinamo Zagreb. El resultado y las estadísticas confirman la clara superioridad del equipo bávaro, liderado por un Harry Kane imparable.  Este triunfo sienta las bases para una campaña competitiva en la máxima competición europea.
#
#
# 📊 Palabras: 410

# %%
# FICHA 2 | Gemma | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, Champions League 2024/25 – Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Superioridad bávara total, 3-0 al descanso, dominio en posesión (72%) y presión alta; Dinamo rezagado
4. 2T: Dos goles croatas rápidos (49’, 50’), luego recital ofensivo del Bayern con hat-trick de Kane y vendaval de ocasiones
5. ESTADÍSTICAS: Posesión 72–28%, tiros 32–7, córners 12–2, xG 5.4–1.2
6. MVP: Harry Kane (hat-trick, líder de ataque, participación decisiva)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba y usa los gentilicios ‘bávaros’ y ‘croatas’
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **¡El Bayern humilla al Dinamo Zagreb con un 9-2 que deja a los croatas en estado de shock!**
#
# La Allianz Arena fue testigo esta noche de una exhibición ofensiva del Bayern Múnich que dejó a los aficionados bávaros eufóricos y a los croatas, especialmente, desconcertados. El equipo de Nagelsmann se impuso al Dinamo Zagreb por un contundente 9-2 en la primera jornada de la Champions League, desatando una avalancha de goles que superó con creces cualquier expectativa.
#
# La cronología del partido fue vertiginosa desde el pitido inicial. En el minuto 19, Harry Kane abrió el marcador con un penalti impecable. Pero el Dinamo, lejos de intimidarse, respondió con dos goles en apenas cinco minutos: primero Guerreiro (34’) y luego Olise (38’), desatando la sorpresa en el estadio. Sin embargo, la superioridad bávara era evidente. El Bayern dominó la primera mitad con una posesión del 72% y una presión alta que sofocó cualquier intento de juego del equipo croata. Al descanso, el marcador indicaba un 3-0 a favor de los alemanes.
#
# La segunda mitad fue aún más demoledora. En el minuto 49, Petković redujo distancias con un gol en propia puerta, pero la respuesta del Bayern fue inmediata: Kane volvió a aparecer (50’) y Ogiwara sumó al marcador (57’). Olise, con dos goles más (73’ y 81’), selló una actuación individual de sobresaliente. Coman (81’) y Kimmich (87’) completaron la goleada, mientras que Tel cerraba el marcador en tiempo añadido (90+3’).
#
# Las estadísticas hablan por sí solas: el Bayern dominó el partido en todos los aspectos. Con un 72% de posesión, 32 tiros contra 7 del Dinamo y 12 córners frente a solo 2, la superioridad bávara fue abrumadora. El xG (Expected Goals) reflejó esta diferencia, situándose en 5.4 para el Bayern y apenas 1.2 para los croatas.
#
# Harry Kane, sin duda, fue el protagonista indiscutible de la noche. Su hat-trick, con dos goles convertidos desde el once entre palos, lo consagró como el líder de ataque del equipo bávaro y su participación en el juego ofensivo fue decisiva.  El Dinamo Zagreb, por su parte, demostró ser un rival inferior, incapaz de contener la avalancha de ataques del Bayern. Un resultado que, sin duda, marcará el inicio de la competición europea.
#
#
# 📊 Palabras: 370

# %% [markdown]
# FICHA 3
# ZERO SHOT

# %%
# FICHA 3 | Gemma | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha3 = """ID_PARTIDO: UCL_2024_J1_MIL_LIV
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1
Fecha: 17/09/2024
Hora: 21:00 CEST (19:00 UTC)
Estadio: Stadio Giuseppe Meazza (San Siro), Milán
Asistencia: 59,826 espectadores
Árbitro: Espen Eskås (Noruega)
Equipo 1: AC Milan
Equipo 2: Liverpool
Entrenador AC Milan: Paulo Fonseca
Entrenador Liverpool: Arne Slot
Alineación AC Milan:
Maignan; Calabria, Tomori, Thiaw, Theo Hernández; Fofana, Reijnders; Pulisic, Loftus-Cheek, Leão; Morata
Alineación Liverpool:
Alisson; Bradley, Konaté, Van Dijk, Robertson; Mac Allister, Gravenberch, Szoboszlai; Salah, Núñez, Gakpo
Resultado final: AC Milan 1 – 3 Liverpool
Resultado al descanso: AC Milan 1 – 2 Liverpool
Goles:
3' Pulisic (AC Milan) 1–0, asistencia de Morata
23' Konaté (Liverpool) 1–1, remate de cabeza a balón parado
41' Van Dijk (Liverpool) 1–2, cabezazo tras córner de Tsimikas
67' Szoboszlai (Liverpool) 1–3, disparo tras jugada combinada
Tarjetas amarillas AC Milan:
51' Tomori
Tarjetas amarillas Liverpool:
79' Van Dijk
Tarjetas rojas:
Ninguna
Sustituciones AC Milan:
Ingresaron Chukwueze, Musah y Terracciano en la segunda parte
Sustituciones Liverpool:
Entraron Tsimikas y jugadores de refresco para administrar la ventaja
Eventos registrados:
3' Gol de Pulisic para el Milan
23' Konaté empata de cabeza
41' Van Dijk remonta antes del descanso
67' Szoboszlai sentencia el partido
Estadísticas totales:
Posesión (%): 55 – 45
Tiros: 16 – 12
Córners: 7 – 5
Estadísticas avanzadas:
xG: 1.8 – 1.1 (a favor de Liverpool)
Jugador del partido: Szoboszlai o Van Dijk"""

prompt_config3 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha3}"

response = client.chat.completions.create(
    model="google/gemma-3-4b",  # ✅ COMA AÑADIDA
    messages=[{"role": "user", "content": prompt_config3}],  # ✅ COMA AÑADIDA
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 3 (Gemma | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config3)
# Out:
# ✅ FICHA 3 – CONFIG 3 (Gemma | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# ## El San Siro se desangra: El Liverpool humilla al Milan en la primera jornada de Champions
#
# **Milán, 17 de septiembre de 2024 –** Una noche fría y lluviosa en el histórico Stadio Giuseppe Meazza presenció una derrota dolorosa para el AC Milan, que cayó ante un implacable Liverpool. Los Reds, liderados por un incisivo Arne Slot, se impusieron con un contundente 3-1, dejando a los milaneses con la sensación amarga de haber sido superados en todos los aspectos del partido.
#
# Desde el pitido inicial, el Milan intentó imponer su ritmo, buscando la verticalidad que caracteriza al equipo de Paulo Fonseca. Y lo consiguió, en el minuto 3, cuando Christian Pulisic, con una asistencia certera de Álvaro Morata, abrió el marcador. El estadio se iluminó con los cánticos del ‘Rossonero’, pero la alegría duraría poco.
#
# El Liverpool, que llegaba al partido con un aire de superioridad, no tardó en reaccionar. En el minuto 23, una jugada ensayada desde un córner botó por la cabeza de Mohamed Salah, quien se encontró con un rechace de Maignan y, tras un pequeño desvío, mandó el balón al fondo de la red. El empate, aunque tardío, devolvió la igualdad al San Siro.
#
# El primer tiempo terminó con el Milan intentando recuperar el control del partido, pero la solidez defensiva del Liverpool, liderada por una pareja imponente como Konaté y Van Dijk, les frenó en seco. La segunda mitad fue un auténtico festival de goles que sellaron la victoria de los Reds. En el minuto 41, Virgil van Dijk, tras un córner magistralmente ejecutado por Tsimikas, remató de cabeza con precisión para adelantar al Liverpool.
#
# Pero la historia no terminó ahí. El Milan, consciente de la necesidad de reaccionar, salió a presionar y en el minuto 67, Dominik Szoboszlai, con una jugada individual brillante, desató un disparo imparable que se coló por debajo de Maignan, sentenciando el partido.
#
# El Milan intentó reaccionar, realizando algunos cambios para intentar darle más dinamismo al ataque, pero la defensa del Liverpool, liderada por un Van Dijk que volvió a demostrar su liderazgo, se mantuvo firme. El holandés recibió una amarilla en el minuto 79 por una entrada dura, evidenciando la intensidad del encuentro.
#
# **Szoboszlai y Van Dijk, los héroes de la noche.** Ambos jugadores fueron clave para la victoria del Liverpool. Szoboszlai con su gol y su capacidad de desbordar, y Van Dijk con su liderazgo en defensa y su tanto decisivo.
#
# **Estadísticas que hablan por sí solas:** El dominio posesional del Milan (55%) no se tradujo en ocasiones claras de peligro. El Liverpool, por su parte, aprovechó al máximo sus oportunidades, logrando un xG superior (1.8 frente a 1.1).
#
# **El futuro es incierto para Fonseca.** La derrota ante el Liverpool pone en duda la capacidad del técnico italiano para sacar lo mejor del equipo milanés.
#
# **La Champions League ya ha dado su primer golazo.** El Liverpool, con un despliegue de calidad y determinación, demuestra que aspira a volver a conquistar Europa.
#
# **En resumen:** Una noche amarga para el AC Milan en el San Siro. Un Liverpool impecable, liderado por sus estrellas, se impuso con autoridad en la primera jornada de Champions League.

# %%
# FICHA 3 | Gemma | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha3}""".format(ficha3=ficha3)

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 3 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El San Siro se desangra y el Liverpool humilla al Milan en la Champions
#
# **Por Juan Carlos Martínez, AS**
#
# El Stadio Giuseppe Meazza, un templo que ha visto nacer leyendas y momentos históricos, fue escenario esta noche de una derrota amarga para el AC Milan. Los ‘Rossoneri’, liderados por Paulo Fonseca, no pudieron contener la implacable ofensiva del Liverpool de Arne Slot, que se llevó una victoria contundente (3-1) en la primera jornada de la fase de grupos de la Champions League.
#
# El partido comenzó con un golpe de efecto para el Milan. En el tercer minuto, Christian Pulisic, desmarcado y bien servido por Álvaro Morata, batió a Alisson Becker con un disparo certero que abrió el marcador. El San Siro se iluminó con la alegría local, pero la tranquilidad duraría poco.
#
# El Liverpool, conocido por su capacidad de reacción, no se dejó amedrentar. En el minuto 23, después de un córner botado por Tsimikas, Mohamed Salah, aprovechando una internada de Konaté, remató de cabeza y igualó el marcador. Un gol que desestabilizó al Milan y demostró la peligrosidad del conjunto inglés.
#
# El partido continuó con un ritmo frenético, donde ambos equipos buscaban imponer su juego. Justo antes del descanso, Virgil Van Dijk, tras una jugada a balón parado, adelantó al Liverpool. El holandés, imparable en el área, aprovechó un centro de Tsimikas para marcar de cabeza y enviar el partido al descanso con ventaja para los ‘Reds’.
#
# La segunda mitad fue un auténtico recital de ataque del Liverpool. En el minuto 67, Dominik Szoboszlai, tras una jugada elaborada que involucró a Salah y Gakpo, se desmarcó en el área y no perdonó, sentenciando el partido con un disparo imparable. El San Siro, silencioso, presenció la implacabilidad del Liverpool.
#
# El Milan intentó reaccionar, pero su defensa, vulnerable y sin solidez, no pudo contener la presión inglesa. Tomori recibió una amarilla en el minuto 51 por una entrada dura, mientras que Van Dijk también fue amonestado en el 79’ por un empujón.
#
# **Szoboszlai y Van Dijk, los héroes de la noche.** Ambos jugadores fueron clave para la victoria del Liverpool. Szoboszlai con su gol y Van Dijk con su tanto de cabeza, demostraron ser piezas fundamentales en el ataque y la defensa del equipo inglés.
#
# **Análisis:** El Milan, que esperaba un partido más tranquilo, se encontró con un Liverpool despiadado y efectivo. La falta de solidez defensiva y la ineficacia en ataque fueron las principales razones del revés para los ‘Rossoneri’.  El Liverpool, por su parte, demostró su calidad y su capacidad de adaptación, logrando una victoria importante que les dará confianza para afrontar el resto de la fase de grupos.
#
# **Estadísticas:** El dominio posesivo del Milan (55%) no se tradujo en goles. El Liverpool, con un xG superior (1.8 frente a 1.1), fue más eficiente en ataque y aprovechó sus oportunidades.
#
# **En resumen, una noche negra para el AC Milan en el San Siro, donde la Champions League demostró ser un desafío mucho mayor de lo esperado.**

# %%
# FICHA 3 | Gemma | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha3}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 3 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El San Siro se convierte en un infierno para el Milan: El Liverpool destroza al Rossonero en la primera jornada de Champions
#
# **Milán, 17 de septiembre de 2024 –** Una noche fría en Milán presenció una exhibición de poderío del Liverpool que dejó al AC Milan con la miel en los labios y un sabor amargo a derrota. El estadio Giuseppe Meazza, conocido como el “San Siro”, se convirtió en un auténtico infierno para los aficionados milaneses, que vieron cómo su equipo era superado por un Liverpool despiadado y con hambre de victoria en la primera jornada del Grupo E de la Champions League.
#
# El partido comenzó con una dinámica muy favorable al AC Milan, que buscaba capitalizar el ambiente hostil y la presión local. Y no tardaron en obtener sus frutos. En el tercer minuto, Christian Pulisic, desmarcado por Álvaro Morata, se deshizo de su marcador para batir a Maignan con un disparo certero que abrió el marcador. El San Siro estalló en júbilo, pero la alegría duraría poco.
#
# El Liverpool, liderado por Arne Slot, no se dejó intimidar y comenzó a construir su juego con paciencia y precisión. A los 23 minutos, tras un córner botado por Andy Robertson, Mohamed Salah aprovechó una internada de Konaté para rematar de cabeza y marcar el empate. Un gol que devolvió la esperanza al conjunto inglés y demostró su capacidad para igualar cualquier situación.
#
# Sin embargo, el Milan no se rindió y continuó buscando la victoria. En el minuto 41, tras un córner de Tsimikas, Virgil van Dijk aprovechó un rechace del portero milanés para rematar con la cabeza y adelantarse en el marcador. El San Siro volvió a vibrar, pero esta vez con una atmósfera más tensa.
#
# El segundo tiempo fue un auténtico recital de ataque por parte del Liverpool. En el minuto 67, Dominik Szoboszlai, tras una jugada combinada magistral, se desmarcó para batir a Maignan con un disparo imparable que sentenció el partido y colocó al Liverpool en una posición ventajosa en la clasificación del grupo.
#
# El Milan intentó reaccionar, pero el Liverpool supo administrar la ventaja con inteligencia, controlando el ritmo del juego y evitando riesgos innecesarios. El central Konaté recibió una amarilla en el minuto 79, mientras que Van Dijk también fue amonestado por un empujón. Ninguno de los dos jugadores vio la roja, lo que demuestra la arbitridad controlada del árbitro noruego Espen Eskås.
#
# El partido finalizó con un marcador de 1-3 a favor del Liverpool. Las estadísticas respaldan la superioridad inglesa: el Liverpool dominó la posesión (55% frente al 45% del Milan) y generó más oportunidades de gol (16 frente a 12). El xG (Expected Goals), que mide la calidad de las ocasiones, también favoreció al Liverpool con 1.8 goles esperados contra 1.1 del Milan.
#
# **Szoboszlai o Van Dijk: ¿Quién merece el premio al mejor jugador?** Ambos jugadores brillaron en su respectivo rol. Szoboszlai fue el arquitecto del partido con su visión de juego y su capacidad para crear oportunidades, mientras que Van Dijk se erigió como un muro infranqueable en defensa y marcó un gol crucial. La decisión final recaerá en la opinión de los expertos y aficionados.
#
# El AC Milan deberá analizar este resultado y buscar soluciones para mejorar su rendimiento en las próximas jornadas. El Liverpool, por su parte, ha dado una señal contundente de sus ambiciones en esta Champions League. Ahora, el equipo de Arne Slot se prepara para afrontar el reto de la segunda jornada con la moral por las nubes.
#
#
# 📊 Palabras: 583

# %%
# FICHA 3 | Gemma | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha3}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## El San Siro se desangra y Slot empieza con la mano dura: el Liverpool destroza al Milan en su estreno Champions
#
# **Por [Tu Nombre], periodista deportivo de AS/Marca**
#
# El Stadio Giuseppe Meazza, un templo que ha presenciado innumerables glorias, fue escenario esta noche de una derrota humillante para el AC Milan. El Liverpool, bajo la dirección del joven Arne Slot, demostró ser demasiado superior y se llevó una victoria contundente (3-1) en su debut en la fase de grupos de la Champions League, dejando a los milaneses con un sabor amargo y una tarea monumental por delante. Con 20 años de experiencia cubriendo esta competición, puedo asegurar que este partido tenía el sello de un Liverpool con ambición y un Milan que necesitaba demostrar algo más que potencial.
#
# **Entrada impactante: la velocidad de Pulisic abre la lata**
#
# La primera mitad fue una exhibición de intensidad y precisión por parte del Liverpool. Desde el pitido inicial, los Reds salieron a presionar, buscando desestabilizar la defensa milanesa. Y lo lograron con un gol tempranero que encendió al San Siro: en el minuto 3, Christian Pulisic, con una asistencia certera de Álvaro Morata, se anticipó a la salida del portero y batió a Maignan con un disparo cruzado. Un gol que generó ilusión entre los aficionados italianos, pero que fue rápidamente eclipsado por la respuesta del Liverpool.
#
# **Desarrollo cronológico: el Milan resistió, pero no pudo contener la tormenta red**
#
# El AC Milan, bajo las órdenes de Paulo Fonseca, intentó mantener la posesión y construir sus ataques, pero la solidez defensiva del Liverpool, liderada por una pareja imponente como Konaté y Van Dijk, les dificultaba la tarea. En el minuto 23, el empate llegó gracias a un remate de cabeza de Virgil van Dijk tras un córner botado por Tsimikas. El holandés aprovechó al máximo su altura y potencia para igualar las cosas. Sin embargo, el gol no supuso un cambio radical en la dinámica del partido.
#
# El Liverpool siguió dominando, controlando el ritmo y generando oportunidades claras. En el minuto 41, una jugada de esquina bien ejecutada por Tsimikas culminó con un cabezazo imparable de Van Dijk, que adelantó al Liverpool por primera vez en el encuentro. El San Siro se sumió en un silencio sepulcral, presagiando la derrota inminente.  El Milan, a pesar de su esfuerzo, parecía desbordado y sin ideas para revertir la situación.
#
# La segunda mitad fue aún más demoledora para el Milan. En el minuto 67, Dominik Szoboszlai, con un disparo potente desde fuera del área, sentenció el partido. La jugada comenzó con una combinación de pases entre Salah, Núñez y Szoboszlai, que culminó con el gol del húngaro. El 3-1 fue definitivo y dejó claro que el Liverpool no solo había ganado el partido, sino también la batalla por los puntos.
#
# **Cierre reflexivo: Slot empieza su proyecto con autoridad**
#
# El resultado final (1-3) refleja la superioridad táctica y física del Liverpool. Las estadísticas respaldan esta afirmación: el Liverpool dominó la posesión (55% frente al 45%), generó más tiros (16 contra 12) y tuvo un xG (1.8) significativamente mayor que el del Milan (1.1).  Szoboszlai, con su gol y su dinamismo en el centro del campo, fue nombrado Jugador del Partido, aunque Van Dijk también merecía reconocimiento por su liderazgo y solidez defensiva.
#
# Este partido marca el inicio de la era Arne Slot en el Liverpool. El holandés demostró ser un entrenador exigente y con ideas claras, que no teme tomar decisiones contundentes.  El Milan, por su parte, tendrá que replantearse su estrategia y mejorar significativamente su juego si quiere aspirar a competir en este grupo de Champions League. La jornada 1 ha sido una dura lección para los milaneses, pero también un mensaje claro: el Liverpool está de vuelta y con ganas de conquistar Europa.  El San Siro se quedó vacío, sin la euforia que esperaba sus aficionados, pero con la certeza de que la competición más importante del continente aún tiene mucho que ofrecer.
#
#
# 📊 Palabras: 658

# %% [markdown]
# FEW SHOT
# FICHA 3

# %%
# FICHA 3 | Gemma | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Gemma NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha3}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 3 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# El Estadio Giuseppe Meazza, en Milán, fue escenario de un vibrante encuentro perteneciente a la primera jornada de la fase de grupos de la UEFA Champions League. El AC Milan se enfrentó al Liverpool en un partido que, finalmente, terminó con una contundente victoria del conjunto inglés por 3-1.
#
# Desde el inicio, el Milan mostró su intención ofensiva, y pronto se puso en ventaja gracias a un gol de Pulisic, asistido por Morata, en el minuto tercero. Sin embargo, la tranquilidad milanesa fue efímera, ya que en el minuto 23, Konaté igualó el marcador con un remate de cabeza tras un córner.
#
# El AC Milan intentó reaccionar, pero el Liverpool, con superioridad numérica y técnica, tomó control del juego. En el minuto 41, Van Dijk adelantó a su equipo con un cabezazo tras un córner de Tsimikas.  La segunda mitad vio cómo Szoboszlai sentenciaba el partido en el minuto 67 con un disparo tras una jugada combinada.
#
# Durante el encuentro, Tomori y Van Dijk recibieron tarjetas amarillas. El Liverpool, administrando la ventaja, realizó sustituciones para mantener la intensidad del juego. El Milan, por su parte, introdujo a Chukwueze, Musah y Terracciano en la segunda mitad.  El partido concluyó con una clara superioridad de los ingleses, que dominaron las estadísticas de posesión (55% - 45%) y tiros (16 – 12), además de un mayor potencial ofensivo evidenciado por su xG (1.8 – 1.1).  Szoboszlai y Van Dijk fueron considerados como los jugadores del partido.

# %%
# FICHA 3 | Gemma | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha3 para aficionados que leen AS o Marca:
{ficha3}"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 3 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El Liverpool, implacable, destroza al Milan en el San Siro y se asegura la victoria en la jornada inaugural
#
# **Milán -** Un Liverpool despiadado y con hambre de gol se impuso por 3-1 al AC Milan en un partido vibrante que abrió la fase de grupos de la Champions League. El estadio Giuseppe Meazza, repleto de 59.826 espectadores, presenció una exhibición de solidez defensiva y ataque letal del conjunto inglés, liderado por un inspirado Dominik Szoboszlai.
#
# El Milan, con un planteamiento táctico que buscaba controlar el centro del campo, se puso al frente en el tercer minuto gracias a la conexión entre Morata y Pulisic. El estadounidense, con un disparo certero, desató la euforia local. Sin embargo, la alegría duró poco. En el 23’, el central Konaté, de cabeza tras un córner de Tsimikas, igualó el marcador, poniendo fin a una racha de once partidos sin marcar de los Reds en Champions League.
#
# La segunda mitad fue dominio absoluto del Liverpool. El Milan, visiblemente afectado por el gol tempranero y la presión inglesa, se desmoronó ante la intensidad de Arne Slot. En el 41’, Virgil van Dijk, con un cabezazo impecable tras un córner de Tsimikas, adelantó a su equipo antes del descanso.
#
# Pero el partido no terminó ahí. El Liverpool, consciente de que debía sentenciar, salió con todo en la reanudación y Szoboszlai, con un disparo preciso desde fuera del área, selló la victoria en el 67’. Un gol que evidenció la superioridad del Liverpool y dejó al Milan sin opciones.
#
# **Szoboszlai, el hombre del partido:** El húngaro fue una auténtica pesadilla para la defensa milanesa, con un despliegue físico y técnico excepcional. Su capacidad de llegada al área y su precisión en el disparo fueron claves para la victoria.
#
# **Análisis:** El Liverpool demostró ser un equipo sólido, compacto y con una gran capacidad de sufrimiento. La ausencia de brillo del Milan, combinado con la efectividad del Liverpool, dejó claro que este será un grupo complicado para los italianos.
#
# **En resumen:** Una noche histórica para el Liverpool en Milán, donde se aseguró la victoria en la primera jornada de la Champions League y demostró su ambición por levantar la Orejona. El Milan, por su parte, deberá analizar sus errores y mejorar su juego si quiere aspirar a pasar de fase.

# %%
# FICHA 3 | Gemma | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha3 para aficionados al fútbol que leen AS o Marca:

{ficha3}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Liverpool, implacable, devasta al Milan en el San Siro y desvela su ambición europea
#
# El Stadio Giuseppe Meazza vibró anoche con un espectáculo de fútbol que dejó a los aficionados milaneses con sabor amargo. El Liverpool, liderado por una máquina imparable como Dominik Szoboszlai, se impuso 3-1 al AC Milan en el primer partido de la fase de grupos de Champions League y demostró, sin lugar a dudas, que aspira a pelear por los puestos de clasificación para la siguiente ronda. Un partido intenso, con momentos de tensión y alternativas, pero donde la solidez defensiva y el ataque incisivo del conjunto inglés fueron decisivos.
#
# La primera mitad fue un duelo táctico en el que ambos equipos buscaron imponer su ritmo. El Milan, con una alineación que apostaba por la solidez defensiva y la velocidad de sus extremos, salió a presionar desde el inicio. Y no tardaron en obtener su recompensa. En el tercer minuto, Christian Pulisic, asistido por Álvaro Morata, desató un disparo imparable que se coló en las redes de Maignan, desatando la euforia del cuadro milanista. Sin embargo, la alegría duraría poco. Apenas tres minutos después, una jugada a balón parado, perfectamente ejecutada por Virgil van Dijk, igualaba el marcador. El holandés, con un remate de cabeza impecable tras un córner de Tsimikas, demostró su capacidad goleadora y puso las cosas en marcha para la visita.
#
# El descanso llegó con el empate en uno, pero sin que ninguno de los dos equipos pudiera cambiar radicalmente su planteamiento. La segunda mitad fue un torbellino de emociones. El Liverpool, consciente de la necesidad de tomar la delantera, elevó su intensidad y comenzó a dominar el juego. Y no tardaron en obtener sus frutos. En el minuto 41, tras una jugada combinada que culminó con un cabezazo imparable de Virgil van Dijk, el Liverpool se adelantaba en el marcador. El estadio milanista se sumió en la decepción.
#
# Pero el partido aún tenía mucho por ofrecer. Y lo hizo en el minuto 67, cuando Dominik Szoboszlai, con una volea magistral tras un centro preciso de Salah, sentenció el encuentro. El polaco, que fue elegido como jugador del partido, se convirtió en el héroe de la noche y selló la victoria del Liverpool. Los últimos minutos fueron de trámite, con el Milan intentando desesperadamente reaccionar, pero sin conseguir perforar la sólida defensa visitante.
#
# Las estadísticas confirman la superioridad del Liverpool: 55% de posesión contra el 45% del Milan, 16 tiros frente a los 12 del rival y un xG de 1.8 contra el 1.1 del Milan. La diferencia en la creación de oportunidades fue aún más evidente, con el Liverpool generando una clara superioridad ofensiva que se tradujo en goles. El partido, sin duda, dejó claro que el Liverpool es un equipo con ambiciones europeas y que no tiene miedo a enfrentarse a los grandes rivales.  El Milan, por su parte, deberá analizar sus errores y mejorar su juego si quiere aspirar a clasificarse para la siguiente ronda de la Champions League.
#
#
# 📊 Palabras: 501

# %%
# FICHA 3 | Gemma | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha3 para aficionados que leen AS o Marca:

{ficha3}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## Liverpool, implacable, devasta al Milan en el San Siro y desvela su ambición europea
#
# **Milán –** El Stadio Giuseppe Meazza, testigo de innumerables clásicos, vibró anoche con la intensidad de un duelo que prometía ser apretado. Y lo fue, al principio. Pero la implacable máquina red de Arne Slot se impuso a un AC Milan sorprendentemente tenaz, desatando su potencial ofensivo y dejando claro que este Liverpool no es el del año pasado. El marcador final: 1-3, una victoria contundente que sienta las bases para una fase de grupos prometedora.
#
# La entrada fue directa y con sabor a gol. En el tercer minuto, Rafael Leão, desmarcado en la banda izquierda, vio a Christian Pulisic, quien, con un disparo certero desde fuera del área, batió a Maignan y abrió el marcador para el Milan. Un inicio que generaba dudas en el Liverpool, pero que no tardaría en ser silenciado. La respuesta de los Reds llegó en el 23’, cuando una jugada ensayada culminó con un remate de cabeza impecable de Ibrahima Konaté tras un córner de Tsimikas. El estadio se inmutó, la tensión era palpable y ambos equipos se preparaban para un encuentro disputado.
#
# El primer tiempo terminó con el Milan por delante en el marcador, pero la segunda mitad fue una exhibición de la superioridad táctica y física del Liverpool. En el 41’, Virgil van Dijk, tras un córner magistralmente ejecutado por Tsimikas, cabeceó a la desesperación para poner al Liverpool a la zancada. Un gol que desató la euforia en las gradas y evidenció la fragilidad defensiva del Milan.  La insistencia de los Reds se tradujo en un control del balón superior y una presión constante que asfixiaba la salida de balón del equipo lombardo.
#
# El momento decisivo llegó en el 67’. Un movimiento rápido por la banda izquierda, con Gakpo como detonante, culminó con un disparo letal de Dominik Szoboszlai. El eslovaco, con una potencia brutal, no dejó opciones a Maignan y sentenció el partido.  El Milan intentó reaccionar, pero el Liverpool se encerró en su área, administrando la ventaja con inteligencia y evitando cualquier riesgo innecesario. La presión de los Reds, combinada con un juego más colectivo y organizado, fue determinante para el resultado final.
#
# Las estadísticas respaldan la superioridad del Liverpool. Con un xG de 1.8 frente al 1.1 del Milan, los Reds dominaron la posesión (55% contra el 45%) y generaron más oportunidades claras de gol.  La actuación de Szoboszlai, con dos disparos a puerta y una asistencia, fue fundamental para la victoria. Van Dijk, por su parte, se erigió como un baluarte en defensa y un referente en ataque.
#
# El partido, aunque no carente de emoción, dejó claro que el Liverpool ha llegado a Milán con la ambición de volver a conquistar Europa.  La victoria sobre el Milan es solo el primer paso, pero sí indica que los Reds están dispuestos a luchar por el título. El Milan, por su parte, deberá analizar sus errores y mejorar su defensa si quiere aspirar a competir al más alto nivel. Un partido que, sin duda, quedará en la memoria de los aficionados como un claro ejemplo del poderío del Liverpool.
#
#
# 📊 Palabras: 525

# %%
CoT 
FICHA 3

# %%
# FICHA 3 | Gemma | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: AC Milan 1-3 Liverpool (San Siro, UCL 2024/25 J1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada)
3. 1T: Milan adelanta 1-0 rápido, Liverpool remonta 1-2 antes descanso, posesión 55-45 Milan, xG 1.8-1.1 Liverpool
4. 2T: Szoboszlai sentencia, Milan reacciona con Chukwueze/Musah/Terracciano pero sin efecto, Liverpool administra con Tsimikas
5. JUGADOR: Szoboszlai o Van Dijk (clave defensiva/ofensiva Liverpool)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 3 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 3 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)
# ================================================================================
# Aquí tienes dos versiones de crónica, una al estilo AS y otra al estilo Marca, basadas en los datos proporcionados.
#
# **Opción 1: Estilo AS (Crónica Deportiva Española)**
#
# **¡SHOCK EN MILAN! El Liverpool Destroza a un Milan Desconcertado en el San Siro**
#
# El estadio del eterno derby se convirtió en escenario de una humillante derrota para el AC Milan, que cayó ante un implacable Liverpool. Un 1-3 contundente que deja al conjunto rossonero con la tarea monumental de reaccionar tras su debut en la Champions League.
#
# Desde el pitido inicial, el Milan salió con la intención de sorprender, y lo logró con un gol tempranero de Pulisic (3’). Sin embargo, la alegría duró poco. El Liverpool, con una solidez defensiva impresionante y aprovechando las salidas de Morata, se puso en ventaja gracias a Konaté (23’) tras un córner peligroso.
#
# La primera mitad fue un torbellino de emociones. El Milan, con posesión superior (55%), intentaba imponer su ritmo pero el Liverpool, con una defensa férrea liderada por Van Dijk y Szoboszlai, se defendía con uñas y dientes.  El holandés, en particular, se erigió como un baluarte, cabeceando el segundo gol de la noche (41’) tras un córner magistral de Tsimikas.
#
# **Szoboszlai, el Maestro del Segundo Tiempo**
#
# La segunda mitad fue un ejercicio de dominio loreal. El Liverpool, con una precisión quirúrgica, sentenció el partido con un gol de Szoboszlai (67’), fruto de una jugada combinativa letal.  El Milan reaccionó, buscando la igualdad con Chukwueze, Musah y Terracciano, pero sin conseguir penetrar en la defensa visitante.
#
# La gestión del partido por parte de Tsimikas fue crucial para mantener la ventaja. El Liverpool administró el resultado con temple, dejando que el Milan intentara desesperadamente, sin lograr generar peligro real.  En definitiva, una noche negra para el AC Milan y una victoria convincente del Liverpool que demuestra su ambición en la Champions League.
#
# **Opción 2: Estilo Marca (Crónica Deportiva Española)**
#
# **¡DRAMA EN MILAN! El Liverpool Aplasta al Milan con un 1-3 y Demuestra Su Fuerza en la Champions**
#
# El San Siro fue testigo de una noche amarga para el AC Milan, que cayó derrotado por 1-3 ante un Liverpool despiadado. Un resultado contundente que pone en evidencia las carencias del equipo rossonero en su estreno en la fase de grupos de la Champions League.
#
# La sorpresa llegó temprano: Pulisic abrió el marcador (3’) para el Milan, pero la alegría duró poco. El Liverpool, con una solidez defensiva asombrosa y un ataque letal, se puso al frente gracias a Konaté (23’), que aprovechó un córner peligroso.
#
# La primera mitad fue un duelo de intensidad. El Milan, dominando la posesión (55%), buscaba el segundo gol, pero el Liverpool, con Van Dijk liderando la defensa y Szoboszlai controlando el centro del campo, se defendía con uñas y dientes.  El holandés, en particular, se convirtió en un muro infranqueable, cabeceando el 2-1 (41’) tras un córner de Tsimikas que dejó sin opciones al central italiano.
#
# **Szoboszlai, la Clave para la Victoria del Liverpool**
#
# La segunda mitad fue un recital de clase del Liverpool. Szoboszlai, con una actuación brillante, sentenció el partido (67’), desatando la euforia en la afición visitante. El Milan reaccionó con intentos desesperados, pero no logró generar ocasiones claras.  Chukwueze, Musah y Terracciano intentaron buscar la igualdad, pero la defensa del Liverpool, liderada por Van Dijk, se mantuvo imbatible.
#
# El control del partido por parte de Tsimikas fue fundamental para mantener la ventaja. El Liverpool administró el resultado con inteligencia, dejando que el Milan buscara la redonda sin

# %%
# FICHA 3 | Gemma | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: AC Milan 1–3 Liverpool (San Siro, UCL 2024/25, Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada)
3. 1T: Milan adelanta 1-0 rápido (3'), Liverpool remonta 1-2 antes descanso con dos cabezazos, posesión 55-45 Milan, xG 1.8-1.1 Liverpool
4. 2T: Szoboszlai sentencia (67'), Milan reacciona con Chukwueze/Musah/Terracciano sin efecto, Liverpool administra con Tsimikas
5. JUGADOR: Szoboszlai o Van Dijk (clave ofensiva/defensiva Liverpool, debut Slot exitoso)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Fonseca/Slot
- No inventes declaraciones ni citas textuales
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 3 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **¡El Liverpool destroza al Milan en el San Siro y Slot empieza con nota!**
#
# 1. **RESULTADO:** AC Milan 1–3 Liverpool (San Siro, UCL 2024/25, Jornada 1) – ¡Un golpe durísimo para Fonseca y un debut triunfal de Slot!
#
# 2. **GOLES:** 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada) – ¡Un recital de goles del Liverpool que dejó a los milaneses sin opciones!
#
# 3. **1T:** Milan adelanta 1-0 rápido (3'), Liverpool remonta 1-2 antes descanso con dos cabezazos, posesión 55-45 Milan, xG 1.8-1.1 Liverpool – ¡El Milan salió con la pólvora a pleno! Pulisic abrió el marcador, pero la defensa rogerista no aguantó ante los dos cabezazos de Konaté y Van Dijk. El control del balón fue claro para los reds, que dominaron la posesión.
#
# 4. **2T:** Szoboszlai sentencia (67'), Milan reacciona con Chukwueze/Musah/Terracciano sin efecto, Liverpool administra con Tsimikas – ¡Szoboszlai, con un disparo letal, selló el 3-1 y liquidó el partido! El Milan intentó reaccionar, pero Slot supo gestionar la victoria con inteligencia, controlando el ritmo y cerrando el partido.
#
# 5. **JUGADOR:** Szoboszlai o Van Dijk (clave ofensiva/defensiva Liverpool, debut Slot exitoso) – ¡Szoboszlai fue el hombre del partido! Su disparo de media distancia rompió la resistencia milanesa. Pero también hay que destacar la solidez defensiva y la cabeza de aire de Van Dijk, pieza clave en la defensa del Liverpool.  Slot empieza su andadura en el banquillo inglés con una victoria contundente y un mensaje claro: ¡el Liverpool está de vuelta!

# %%
# FICHA 3 | Gemma | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: AC Milan 1–3 Liverpool (Stadio Giuseppe Meazza, UEFA Champions League 2024/25, Fase de grupos – Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liverpool, cabezazo tras acción a balón parado), 41' Van Dijk (Liverpool, cabezazo a la salida de un córner de Tsimikas), 67' Szoboszlai (Liverpool, disparo tras jugada combinada)
3. 1T: Milan se adelanta muy pronto (3’) con gol de Pulisic, pero Liverpool remonta antes del descanso con dos tantos de cabeza (Konaté y Van Dijk); al descanso, 1–2 para los ingleses
4. 2T: Szoboszlai marca el 1–3 en el 67’, que sentencia el partido; Milan mueve el banquillo (Chukwueze, Musah, Terracciano) en busca de reacción ofensiva y Liverpool introduce a Tsimikas y jugadores de refresco para gestionar la ventaja
5. ESTADÍSTICAS: Posesión 55–45, tiros 16–12, córners 7–5, xG 1.8–1.1 a favor de Liverpool
6. MVP: Szoboszlai o Van Dijk (determinantes en la sentencia y en el dominio aéreo del Liverpool)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **AC Milan-Liverpool 1-3: El Liverpool se impone en un debut Champions League ajustado**
#
# El Estadio Giuseppe Meazza fue escenario de un partido vibrante y decisivo en la jornada inaugural de la fase de grupos de la UEFA Champions League. El AC Milan, que buscaba una buena salida al torneo, sucumbió ante el dominio y la efectividad del Liverpool, que se llevó la victoria por 3-1.
#
# **Cronología del Partido:**
#
# El encuentro comenzó con un golpe inicial para el Milan. En el minuto 3, Christian Pulisic abrió el marcador con un gol de falta directa (asistencia de Morata), sorprendiendo al portero rival y a los aficionados milaneses. Sin embargo, la alegría duró poco. El Liverpool, conocido por su solidez defensiva y capacidad para aprovechar las oportunidades, igualó en el 23’ gracias a un remate de cabeza de natan Konaté tras una falta en el área.  La presión continuó y, en el minuto 41, Virgil van Dijk aprovechó un córner de Tsimikas para marcar su primer gol del partido con otro cabezazo que elevó el marcador a 2-1.
#
# El segundo tiempo vio al Liverpool gestionar la ventaja con control y precisión. El mediocampista Dominik Szoboszlai, en el minuto 67’, selló la victoria con un disparo tras una jugada combinada que desató el júbilo de los aficionados ingleses.  El Milan intentó reaccionar, realizando cambios tácticos introduciendo a Chukwueze, Musah y Terracciano, buscando generar peligro en ataque. No obstante, el Liverpool, consciente de su ventaja, optó por gestionar el partido, incorporando a Tsimikas y jugadores con menor carga física para mantener la posesión y evitar riesgos innecesarios.
#
# **Análisis Estadístico:**
#
# El dominio del Liverpool se confirmó en las estadísticas. El equipo inglés controló la posesión del balón durante gran parte del encuentro (55% frente al 45% del Milan), generando más oportunidades de gol (16 tiros contra 12).  Además, el xG (valor esperado de goles) favoreció al Liverpool con un 1.8 contra 1.1, evidenciando su mayor peligro ofensivo. El juego aéreo también fue determinante, con el Liverpool dominando los córners (7-5), un factor clave en la consecución de sus dos goles de cabeza.
#
# **Conclusión:**
#
# El AC Milan demostró ser superior en los primeros minutos, pero el Liverpool, gracias a su solidez defensiva, capacidad para aprovechar las oportunidades y la determinación de jugadores como Szoboszlai y Van Dijk, logró imponerse en un partido que sentó las bases de una fase de grupos prometedora. La victoria consolida al Liverpool como uno de los principales aspirantes al título y deja al Milan con trabajo por delante para demostrar su valía en el torneo.
#
#
# 📊 Palabras: 423

# %%
# FICHA 3 | Gemma | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: AC Milan 1–3 Liverpool (Stadio Giuseppe Meazza, Champions League 2024/25 – Fase de grupos, Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liverpool, cabezazo tras acción a balón parado), 41' Van Dijk (Liverpool, cabezazo a la salida de un córner de Tsimikas), 67' Szoboszlai (Liverpool, disparo tras jugada combinada)
3. 1T: Milan se adelanta muy pronto (3’) con gol de Pulisic, pero el Liverpool remonta antes del descanso con dos tantos de cabeza (Konaté y Van Dijk); al descanso, 1–2 para los ingleses, con ligera ventaja de posesión para el Milan (55–45)
4. 2T: Szoboszlai firma el 1–3 en el 67’ y sentencia el duelo; Milan introduce a Chukwueze, Musah y Terracciano buscando reacción ofensiva, mientras el Liverpool recurre a Tsimikas y jugadores de refresco para gestionar la ventaja
5. ESTADÍSTICAS: Posesión 55–45, tiros 16–12, córners 7–5, xG 1.8–1.1 a favor del Liverpool
6. MVP: Szoboszlai o Van Dijk (determinantes en la sentencia del marcador y en el dominio aéreo del Liverpool)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias
"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **¡El Liverpool destroza al Milan en un Meazza aturdido! Szoboszlai sentencia una noche de desconcierto italiano**
#
# Milán, Italia – Una noche que quedará grabada en la memoria del Estadio Giuseppe Meazza. El AC Milan, con su afición rugiendo desde las gradas, se vio superado por la solidez y el contundente ataque del Liverpool, que se llevó una victoria contundente por 3-1 en la primera jornada de la fase de grupos de la Champions League.
#
# La historia comenzó con un golpe inicial para los rossoneri. En el minuto 3, Christian Pulisic, con un disparo certero, abrió el marcador y desató la euforia local. Sin embargo, esa alegría duró poco. El Liverpool, liderado por una defensa imponente, reaccionó con fuerza. El senegalés Konaté, tras una jugada a balón parado, adelantó a los ingleses en el 23’.  Justo antes del descanso, Virgil Van Dijk, de cabeza, aprovechó un córner de Tsimikas para poner el 2-1 en el marcador (41’). Al final del primer tiempo, el Milan dominaba la posesión (55% contra el 45%), pero la ventaja estadística no se traducía en peligro real.
#
# La segunda mitad fue una exhibición de dominio inglés. El Liverpool, con un ritmo superior y una efectividad brutal, sentenció el partido en el minuto 67’ gracias a Dominik Szoboszlai, quien culminó una jugada combinada con un disparo imparable.  El Milan, consciente de la necesidad de cambiar el rumbo del encuentro, introdujo a Chukwueze, Musah y Terracciano buscando desesperadamente una reacción ofensiva. El Liverpool, por su parte, gestionó la ventaja con criterio, incorporando jugadores frescos para mantener la intensidad.
#
# Las estadísticas confirman la superioridad del Liverpool: 55% de posesión, 16 tiros contra 12, 7 córners frente a 5 y una xG (valoración esperada de goles) de 1.8 por parte de los ingleses versus 1.1 del Milan.  La clave del triunfo loreal fue su dominio en el juego aéreo, con Van Dijk y Konaté siendo dos auténticos baluartes defensivos.
#
# Szoboszlai y Van Dijk fueron, sin duda, los protagonistas indiscutibles de la noche. Ambos, con sus goles y liderazgo, sellaron una victoria que no solo les permite liderar el grupo, sino que también demuestra la solidez del proyecto Klopp.  El Milan, por su parte, deberá analizar a fondo su actuación y buscar soluciones para frenar un Liverpool que, en esta primera salida, ha demostrado ser imparable. Un final épico, sin duda, para una noche de Champions League llena de emociones.
#
#
# 📊 Palabras: 398

# %% [markdown]
# FICHA 4
# ZERO SHOT

# %%
# FICHA 4 | Gemma | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha4 = """ID_PARTIDO: UCL_2024_J1_PSG_ARS
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1 (League Phase)
Fecha: 01/10/2024
Hora: 19:00 hora local (Londres)
Estadio: Emirates Stadium, Londres
Asistencia: 60,103 espectadores
Árbitro: Slavko Vinčić (Eslovenia)
Equipo 1: Arsenal
Equipo 2: Paris Saint-Germain
Entrenador Arsenal: Mikel Arteta
Entrenador Paris Saint-Germain: Luis Enrique
Alineación Arsenal:
Raya; White, Saliba, Kiwior, Zinchenko; Ødegaard, Rice, Havertz; Saka, Gabriel Jesus, Martinelli
Alineación Paris Saint-Germain:
Donnarumma; Hakimi, Marquinhos, Pacho, Nuno Mendes; Vitinha, Zaïre-Emery, Fabián Ruiz; Dembélé, Kvaratskhelia, Barcola
Resultado final: Arsenal 2 – 0 Paris Saint-Germain
Resultado al descanso: Arsenal 2 – 0 Paris Saint-Germain
Goles:
20' Havertz (Arsenal) 1–0, remate de cabeza tras centro de Trossard
35' Saka (Arsenal) 2–0, lanzamiento de falta lateral mal gestionada por Donnarumma
Tarjetas amarillas Arsenal:
No disponibles
Tarjetas amarillas Paris Saint-Germain:
No disponibles
Tarjetas rojas:
Ninguna
Sustituciones Arsenal:
64' Mikel Merino entra para reforzar el centro del campo
74' Trossard entra por Gabriel Jesus
Myles Lewis-Skelly entra por Saka en el tramo final
Sustituciones Paris Saint-Germain:
Fabián Ruiz entra en la segunda parte
Otros cambios ofensivos (como Kolo Muani) en el tramo final para buscar reacción
Eventos registrados:
Arsenal se adelanta con un cabezazo de Havertz tras centro de Trossard
Saka firma el 2–0 con una falta lateral mal defendida por Donnarumma
Debut de Mikel Merino con el Arsenal, que entra en la segunda parte para dar solidez al medio campo
Estadísticas totales:
Posesión (%): 58 – 42 a favor del Arsenal
Tiros: 14 – 11
Córners: 6 – 5
Estadísticas avanzadas:
xG: 1.4 – 1.2 a favor del Arsenal
Jugador del partido: Kai Havertz"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha4}"

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 1 (Gemma | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 4 – CONFIG 1 (Gemma | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# ## El Emirates se convierte en un fortín: El Arsenal destroza al PSG y da la estocada en la Champions
#
# **Londres, 01 de octubre de 2024 –** Un Emirates Stadium atestado, con una atmósfera electrizante, presenció hoy una noche histórica para el Arsenal. Los Gunners se impusieron al Paris Saint-Germain por un contundente 2-0, desatando la euforia en la grada y dejando a los parisinos con la sensación amarga de una derrota que no les sienta bien en su camino hacia la gloria europea.
#
# Desde el pitido inicial, el Arsenal se mostró implacable. Un equipo sólido defensivamente y con un ataque letal, liderado por un Kai Havertz que brilló con luz propia, dominaron los términos del encuentro. El PSG, sin embargo, no logró encontrar su ritmo y se vio constantemente superado en intensidad y posesión.
#
# **Havertz abre el marcador con una cabeza de jugada:** La primera mitad fue un ejercicio de paciencia táctica por parte del Arsenal. A los 20 minutos, la recompensa llegó: un centro preciso de Trossard encontró a Kai Havertz, quien, con un remate sutil pero efectivo, mandó el balón al fondo de la red. Un gol que encendió aún más al estadio y demostró la capacidad goleadora del alemán.
#
# **Saka sentencia con una falta magistral:** La segunda mitad comenzó con el mismo ritmo implacable del Arsenal. A los 35 minutos, un lanzamiento de falta lateral ejecutado por Bukayo Saka fue una verdadera pesadilla para Gianluigi Donnarumma. El portero italiano, que había sido clave en las últimas temporadas, no pudo controlar la trayectoria del balón y se convirtió en el culpable directo del segundo gol, que sentenció el partido a favor de los Gunners.
#
# **Merino, la solución en el centro del campo:** Mikel Arteta movió ficha en la segunda parte, introduciendo a Mikel Merino para reforzar el mediocampo. El centrocampista vasco aportó solidez y control al juego del Arsenal, consolidando una defensa férrea y un ataque efectivo.
#
# **El PSG no logra reaccionar:** A pesar de los cambios ofensivos realizados por Luis Enrique en el tramo final del partido, el PSG no logró generar ocasiones claras de gol. Donnarumma se erigió como un baluarte infranqueable, frustrando los intentos de los parisinos por remontar el marcador.
#
# **Estadísticas que hablan claro:** El Arsenal dominó el encuentro en todos los aspectos: posesión (58% frente al 42%), tiros (14 frente a 11) y xG (1.4 contra 1.2). Estas cifras reflejan la superioridad táctica y física de los Gunners, que demostraron ser un rival muy complicado para el PSG.
#
# **Jugador del partido:** Sin duda, **Kai Havertz**. Su gol y su presencia en el área fueron fundamentales para el triunfo del Arsenal. El alemán se mostró incisivo, desequilibrante y letal ante la portería parisina.
#
# **Lo que queda por ver:** Este resultado supone un golpe de moral para el Arsenal, que empieza con buen pie su participación en la fase de grupos de la Champions League. Por otro lado, el PSG deberá analizar sus errores y buscar soluciones para mejorar su juego ofensivo si quiere aspirar a levantar la Orejona.
#
# **En resumen, una noche inolvidable para el Arsenal, que demostró ser un equipo temible y dejó claro que no tiene intenciones de renunciar a sus sueños europeos.**

# %%
# FICHA 4 | Gemma | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha4}""".format(ficha4=ficha4)

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 4 – CONFIG 2 (Gemma | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El Emirates se convierte en una fortaleza: el Arsenal destroza al PSG y da la estocada en la Champions
#
# **Londres, 01 de octubre de 2024 -** Un Emirates Stadium electrizado vibró anoche con la victoria del Arsenal sobre el Paris Saint-Germain por 2-0, un resultado que no solo consolida a los Gunners como favoritos en su grupo, sino que también envía un mensaje contundente al resto de equipos de la Champions League. Mikel Arteta ha demostrado una vez más que su equipo sabe cómo defender su estadio y aprovechar cada oportunidad.
#
# Desde el pitido inicial, el Arsenal se mostró sólido y organizado, con una defensa férrea liderada por Saliba y White. El PSG, sin embargo, no logró penetrar en las líneas de los londinenses, mostrando un planteamiento táctico que, a pesar de la presencia de estrellas como Kvaratskhelia y Barcola, no encontró su ritmo.
#
# **Havertz, el héroe del primer gol:** La primera mitad fue un ejercicio de paciencia por parte del Arsenal, esperando el momento oportuno para atacar. Y ese momento llegó en el minuto 20, cuando Kai Havertz, con un remate de cabeza impecable tras un centro preciso de Trossard, abrió el marcador. Un gol que encendió al estadio y demostró la capacidad goleadora del alemán.
#
# **Saka, maestro de la falta:** La segunda mitad fue aún más convincente para los Gunners. En el 35’, Saka, con una ejecución magistral de una falta lateral mal gestionada por Donnarumma, firmó el 2-0 definitivo. El disparo, aparentemente sencillo, se coló en la red gracias a un error del portero francés y desató la euforia entre los aficionados.
#
# **Merino, la solución en el centro del campo:** La entrada de Mikel Merino en la segunda parte aportó una dosis extra de solidez al mediocampo del Arsenal. El centrocampista vasco se convirtió en el eje central de la recuperación del balón y distribuyó el juego con criterio, consolidando la victoria de los Gunners.
#
# **El PSG, incapaz de reaccionar:** Luis Enrique intentó cambiar de ritmo con sustituciones ofensivas en el tramo final del partido, buscando desesperadamente un gol que les devolviera la esperanza. Sin embargo, el Arsenal se mantuvo firme y no permitió que el PSG creara ocasiones claras de peligro.
#
# **Estadísticas que hablan por sí solas:** La posesión del balón fue mayoritaria para el Arsenal (58% frente al 42%), lo que refleja su dominio en el juego. Además, los Gunners lograron un xG superior (1.4 vs 1.2), confirmando su superioridad en la creación de oportunidades.
#
# **Jugador del partido:** Sin duda, Kai Havertz. Su gol y su presencia en el área fueron claves para la victoria del Arsenal. Un jugador que ha demostrado su valía y que se está convirtiendo en un referente ofensivo del equipo.
#
# **En resumen, una noche histórica para el Arsenal, que ha demostrado ser un rival temible en casa y que tiene todas las cartas en juego para alcanzar los octavos de final de la Champions League.** El Emirates Stadium se ha convertido en una verdadera fortaleza, y el PSG deberá buscar venganza en París si quiere seguir con vida en esta competición.

# %%
# FICHA 4 | Gemma | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha4}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 4 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 3 (Gemma | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Emirates se convierte en un fortín: el Arsenal destroza al PSG y da la estocada en la Champions
#
# **Londres, 1 de octubre de 2024 –** Un Emirates Stadium atestado, con una atmósfera electrizante, presenció hoy una noche histórica para el Arsenal. Los Gunners, liderados por un Mikel Arteta que parece haber encontrado la fórmula para dominar a los gigantes europeos, se impusieron al Paris Saint-Germain por 2-0 en el primer partido de la fase de grupos de la Champions League, desatando la euforia entre sus aficionados y dejando a los parisinos con una amarga reflexión.
#
# La noche comenzó con un Arsenal que salió con la intención clara de controlar el ritmo del partido desde el pitido inicial. La solidez defensiva, combinada con la velocidad y la astucia de sus hombres arriba, generó las primeras ocasiones. Y no tardaron en traducirse en gol. En el minuto 20’, Kai Havertz, aprovechando un centro preciso de Trossard, se elevó por encima de Marquinhos para rematar de cabeza y abrir el marcador. Un gol que encendió al Emirates y demostró la capacidad goleadora del alemán, quien parece haber encontrado su lugar en el equipo.
#
# Pero el Arsenal no se conformaba con una ventaja mínima. La insistencia en el centro del campo y la presión alta continuaron castigando a un PSG que, pese a contar con jugadores de talla mundial como Mbappé (aunque no titular), parecía descolgado y sin ideas claras. Y fue en el 35’ cuando Saka, con un disparo desde fuera del área tras una falta lateral mal gestionada por Donnarumma, selló la victoria con un gol que evidenció la fragilidad defensiva del conjunto francés. La mala decisión del portero parisino, que no se extendió lo suficiente para cortar el balón, fue un auténtico regalo para el joven extremo inglés.
#
# El debut de Mikel Merino en el banquillo, ingresando en la segunda parte para reforzar el centro del campo, aportó una dosis extra de solidez y control al juego del Arsenal. Arteta, consciente de la importancia de mantener la posesión y controlar el ritmo, optó por darle minutos al centrocampista español, quien se integró con éxito en el esquema de juego.
#
# El PSG, que intentó reaccionar en los últimos minutos, introdujo a varios jugadores ofensivos como Kolo Muani, buscando desesperadamente un resquicio para cambiar la dinámica del partido. Sin embargo, la defensa del Arsenal, liderada por una sólida pareja Saliba-Kiwior, se mantuvo firme y resistió las embestidas parisinas.
#
# Las estadísticas respaldan el dominio absoluto del Arsenal: 68% de posesión contra el 32% del PSG, 14 tiros a puerta frente a 11 y un xG (valoración de oportunidades) de 1.4 en comparación con 1.2 para los franceses.  La actuación de Donnarumma, sin embargo, fue la que más llamaba la atención, ya que no pudo evitar dos goles que evidenciaron las deficiencias del equipo parisino.
#
# El Arsenal se lleva así una victoria crucial que le permite iniciar su camino en la Champions League con la moral por las nubes y la convicción de que puede aspirar a grandes cosas esta temporada. Para el PSG, la derrota es un duro golpe de realidad que obliga a Luis Enrique a replantearse su estrategia y buscar soluciones para mejorar la solidez defensiva del equipo.  La jornada en Londres ha sido una noche inolvidable para los aficionados del Arsenal, que han demostrado una vez más por qué el Emirates Stadium es uno de los estadios más intimidantes de Europa.
#
#
# 📊 Palabras: 572

# %%
# FICHA 4 | Gemma | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha4}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 4 (Gemma | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## El Arsenal destroza al PSG en Londres y demuestra que la Champions es un desafío serio
#
# **Por [Tu Nombre], periodista deportivo de AS/Marca**
#
# La noche londinense se iluminó con el rugido de la afición del Emirates Stadium, pero no era para celebrar a los parisinos. El Arsenal, liderado por una implacable determinación y un despliegue táctico impecable, se impuso 2-0 al Paris Saint-Germain en el primer partido de la fase de grupos de la Champions League, demostrando que esta temporada la competición será mucho más dura de lo que muchos esperaban. Con 60.103 espectadores vibrando, el estadio se convirtió en un auténtico bastión blanco, y Mikel Arteta ha logrado un inicio de campaña que alimenta las aspiraciones europeas del club londinense.
#
# **Un primer tiempo electrizante: Havertz y Saka desatan la tormenta**
#
# El partido comenzó con una intensidad palpable, con ambos equipos buscando imponer su juego desde el pitido inicial. Sin embargo, fue el Arsenal quien tomó la iniciativa en los primeros minutos, aprovechando la velocidad de sus extremos y la solidez defensiva del mediocampo. Y no tardó en romper la muralla parisina. En el minuto 20’, Kai Havertz, con un remate de cabeza perfectamente colocado tras un centro preciso de Trossard, abrió el marcador. El estadio explotó en júbilo, y el Arsenal se vio con una ventaja que parecía difícil de encarrilar para el PSG.
#
# La segunda diana llegó en el 35’, fruto de una espectacular falta lateral mal gestionada por Gianluigi Donnarumma. Bukayo Saka, con un golpeo imparable desde la frontal del área, batió al portero italiano y selló el 2-0. El Arsenal se marchaba al descanso con una ventaja cómoda, pero sin que el PSG mostrara signos de reacción. La posesión del balón era mayoritaria a favor del Arsenal (58%), y las estadísticas confirmaban la superioridad táctica del equipo londinense.  El xG (valoración esperada de goles) también lo respaldaba: 1.4 frente a 1.2 para el PSG, evidenciando que el Arsenal generó más oportunidades claras de gol.
#
# **En busca de la reacción, pero sin éxito**
#
# La segunda mitad comenzó con un intento de reacción por parte del PSG, que introdujo a Fabián Ruiz en la cancha para intentar dinamizar su ataque. Luis Enrique buscaba soluciones ofensivas, y se notaba una mayor presión sobre la defensa del Arsenal. Sin embargo, el equipo londinense se mantuvo firme, defendiendo con uñas y dientes su ventaja. Mikel Arteta realizó dos sustituciones estratégicas: en el minuto 64’, incorporó a Mikel Merino para reforzar el centro del campo, y en el 74’, Trossard reemplazó a Gabriel Jesus, buscando frescura y dinamismo en la zona ofensiva.  En los últimos minutos, se vieron cambios adicionales por parte del PSG, como Kolo Muani, pero no lograron alterar el resultado.
#
# **Havertz, el héroe de la noche**
#
# La actuación de Kai Havertz fue fundamental para la victoria del Arsenal. El alemán, que ha sido criticado en el pasado, demostró su capacidad goleadora y su compromiso con el equipo.  Con un 1.4 xG, Havertz fue el jugador más peligroso del Arsenal, y su gol temprano sentó las bases de la victoria.  El premio al mejor jugador del partido fue para él, una justa recompensa por su destacada actuación.
#
# **Reflexiones finales: ¿Un nuevo gigante en Europa?**
#
# Este triunfo no solo consolida la posición del Arsenal en la Champions League, sino que también envía un mensaje claro a los rivales: el equipo de Arteta es un contendiente serio para llegar lejos en esta competición. La solidez defensiva, la eficacia ofensiva y la capacidad de adaptación táctica son las claves del éxito del Arsenal.  El PSG, por su parte, deberá analizar sus errores y mejorar su juego si quiere aspirar a levantar la Orejona.  La Champions League ha comenzado con un golpe de autoridad para el Arsenal, y la afición británica espera con ilusión ver qué más puede ofrecer este equipo en los próximos partidos. La temporada promete ser emocionante, y el Emirates Stadium se prepara para vivir noches inolvidables.
#
#
# 📊 Palabras: 657

# %% [markdown]
# FEW SHOT
# FICHA 4

# %%
# FICHA 4 | Gemma | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Gemma NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha4}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 4 – CONFIG 5 (Gemma | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# El Emirates Stadium fue testigo de un claro dominio del Arsenal en su debut en la fase de grupos de la Champions League contra el Paris Saint-Germain. Un doblete de Kai Havertz y una falta convertida por Bukayo Saka sellaron una victoria contundente para los locales. El partido, que comenzó con un ritmo cauteloso, vio cómo el Arsenal se adelantara temprano gracias al remate de cabeza de Havertz tras un centro preciso de Trossard en el minuto 20.  La segunda diana llegó en el 35’ cuando Saka transformó una falta lateral mal gestionada por Donnarumma, confirmando la superioridad del equipo inglés. Mikel Merino se incorporó en la segunda mitad para reforzar el centro del campo, mientras que Trossard sustituyó a Gabriel Jesus. En el tramo final, Myles Lewis-Skelly entró al campo buscando mantener la presión sobre la defensa parisina.  El Arsenal controló la posesión (58% frente al 42% del PSG) y generó más oportunidades de gol (14 contra 11), con un xG superior (1.4 vs 1.2). La victoria consolida el inicio de la campaña europea del Arsenal.

# %%
# FICHA 4 | Gemma | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha4 para aficionados que leen AS o Marca:
{ficha4}"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 4 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# ## El Emirates se convierte en una fortaleza: el Arsenal destroza al PSG y da un golpe de moral
#
# **Londres, 01/10/2024 -** Un Emirates Stadium atronado por la afición local fue testigo de una noche histórica para el Arsenal. Los Gunners, con una solidez defensiva impecable y un ataque letal, se impusieron al Paris Saint-Germain por 2-0 en el primer partido de la fase de grupos de Champions League, desatando la euforia entre sus seguidores y enviando un mensaje contundente a los rivales.
#
# Desde el pitido inicial, el Arsenal demostró una determinación férrea para controlar el partido. Mikel Arteta desplegó una defensa compacta liderada por Saliba y Kiwior, que neutralizó con éxito las intenciones ofensivas del PSG. El dominio territorial fue abrumador, con un 58% de posesión que obligó a los parisinos a replegarse y a buscar huecos en la retaguardia Gunners.
#
# El primer gol llegó temprano, en el minuto 20, gracias a una jugada perfectamente ejecutada. Trossard centró desde la banda izquierda y Kai Havertz, con un remate de cabeza impecable, batió a Donnarumma para abrir el marcador. El estadio estalló en júbilo, confirmando que el Emirates se había convertido en una verdadera fortaleza.
#
# Pero la noche no terminó ahí. En el minuto 35, el Arsenal aumentó su ventaja gracias a un lanzamiento de falta lateral mal gestionado por el portero francés. Saka, con una precisión quirúrgica, aprovechó la confusión para batir a Donnarumma y firmar el 2-0 definitivo. La celebración fue monumental, reflejando la alegría del equipo y la afición.
#
# La entrada de Mikel Merino en la segunda parte aportó solidez al centro del campo, consolidando la defensa y permitiendo que el Arsenal controlara el ritmo del partido. Las sustituciones realizadas por Luis Enrique en el tramo final, con Kolo Muani entre los cambios, no lograron despertar a un PSG que se mostró incapaz de generar peligro ante una defensa organizada y agresiva.
#
# **Análisis:** El Arsenal demostró ser un equipo muy bien organizado, tanto en ataque como en defensa. La solidez defensiva, combinada con la eficacia del ataque, fue la clave para la victoria. Havertz, autor del primer gol, se mostró especialmente eficaz, mientras que Saka, con su lanzamiento de falta, selló una noche histórica para el Arsenal y para sus aficionados.
#
# **Jugador del partido:** Kai Havertz. Su gol temprano y su presencia en ataque fueron fundamentales para el éxito del Arsenal.
#
# **Próximo desafío:** El Arsenal se prepara ahora para recibir al Manchester City en un duelo que promete ser de infarto en la jornada siguiente.

# %%
# FICHA 4 | Gemma | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha4 para aficionados al fútbol que leen AS o Marca:

{ficha4}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 7 (Gemma | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# ## El Emirates se convierte en un bastión inexpugnable: el Arsenal destroza al PSG con una exhibición de solidez
#
# El Emirates Stadium vibró anoche, pero no por la euforia habitual de un partido de fútbol. La atmósfera era densa, cargada de tensión y expectación ante la visita del Paris Saint-Germain, un rival que se esperaba con ansias para poner a prueba la nueva realidad del Arsenal. Y el resultado final, un contundente 2-0, no dejó lugar a dudas: Mikel Arteta ha construido algo sólido en Londres, una muralla infranqueable que, al menos por ahora, parece invencible.
#
# La primera mitad fue un ejercicio de paciencia y control por parte del Arsenal. El PSG, con la maquinaria ofensiva habitual liderada por Mbappé y Kolo Muani, no encontró hueco en la defensa organizada de los londinenses. La insistencia de Arteta se vio recompensada al 20’ cuando Kai Havertz, tras un centro preciso de Trossard, aprovechó un rechace para rematar de cabeza y abrir el marcador. Un gol que encendió a la afición local y confirmó la solidez defensiva del equipo.
#
# Pero la segunda mitad fue donde el Arsenal demostró su carácter. Saka, con una ejecución magistral de una falta lateral mal gestionada por Donnarumma, amplió la ventaja al 35’. El portero francés se mostró desorientado ante el potente disparo del joven extremo inglés, dejando claro que la portería parisina no es un blindaje inexpugnable. La insistencia del Arsenal en el centro del campo, con la entrada de Mikel Merino, aportó mayor solidez y control al juego.
#
# El PSG intentó reaccionar, realizando algunos cambios ofensivos para buscar desesperadamente un gol que les devolviera la esperanza. Pero el Arsenal se mantuvo firme, defendiendo con uñas y dientes su portería. El marcador no cambió, y el 2-0 final selló una victoria merecida y un resultado que desata las especulaciones sobre el futuro del PSG.
#
# Las estadísticas respaldan la superioridad del Arsenal: 58% de posesión contra el 42% del PSG, 14 tiros a puerta frente a los 11 del rival y un xG de 1.4 contra 1.2.  La clave fue la capacidad del Arsenal para neutralizar el juego de ataque del PSG, especialmente la velocidad de Mbappé y la precisión de Kolo Muani.
#
# El debut de Mikel Merino, que entró en la segunda parte, aportó frescura y solidez al centro del campo, consolidando la defensa y permitiendo al Arsenal mantener el control del partido.  La actuación de Kai Havertz como goleador y su capacidad para rematar centros fue fundamental.
#
# En definitiva, una noche histórica para el Arsenal que consolida su posición en la parte alta de la tabla y demuestra que, bajo la dirección de Arteta, el club ha encontrado un camino claro hacia el éxito. El Emirates Stadium se ha convertido en un bastión inexpugnable, un lugar donde los rivales temen pisar.
#
#
# 📊 Palabras: 466

# %%
# FICHA 4 | Gemma | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha4 para aficionados que leen AS o Marca:

{ficha4}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 8 (Gemma | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# ## El Arsenal, un muro infranqueable ante el PSG en Londres. Un 2-0 que no pinta bien para la Champions
#
# **Londres –** La noche londinense se tiñó de verde y oro, pero no con la gloria que esperaba el Paris Saint-Germain. Mikel Arteta y su Arsenal demostraron ser un muro infranqueable en el Emirates Stadium, derrotando al PSG por 2-0 en el primer partido de la fase de grupos de la Champions League. Un resultado que, a priori, pinta muy mal para las aspiraciones parisinas en esta competición.
#
# La entrada impactante llegó temprano, con apenas 20 minutos jugados. Una jugada aparentemente sencilla, un centro medido de Trossard y la conexión letal entre Havertz y el remate de cabeza del alemán. Un gol que desató la euforia local y puso en alerta al PSG, que se vio rápidamente superado en intensidad y posesión. El xG inicial del Arsenal fue de 1.4 frente a 1.2 del PSG, una clara señal de dominio desde el principio.
#
# La cronología del partido fue implacable para los visitantes. El Arsenal no solo dominó la posesión (58% contra el 42%), sino que también generó más oportunidades claras. La segunda diana, un golazo de Saka en el minuto 35, llegó tras una falta lateral mal defendida por Donnarumma. El portero francés, bajo presión, se equivocó en la gestión del balón y Saka aprovechó para firmar el 2-0 con un disparo cruzado que se coló en su portería. La frustración parisina era palpable, pero no lograron reaccionar de manera efectiva.
#
# Arteta, como siempre, demostró una gran maestría táctica, optando por mantener la solidez defensiva y aprovechar las transiciones rápidas. La entrada de Mikel Merino en la segunda mitad fue crucial para reforzar el centro del campo y controlar el ritmo del partido. El joven centrocampista aportó dinamismo y equilibrio al equipo. Por su parte, Luis Enrique se vio obligado a realizar cambios ofensivos en los últimos minutos, buscando desesperadamente una reacción, pero sin éxito. Kolo Muani, por ejemplo, entró al campo, pero no logró generar peligro real.
#
# El Arsenal, con un juego pragmático y efectivo, se impuso como el claro protagonista de la noche. El Emirates Stadium vibró con cada jugada del equipo local, que supo defender su ventaja con uñas y dientes. La estadística final refleja la superioridad del Arsenal: 14 tiros contra 11 y 6 córners frente a 5.
#
# El jugador del partido fue indiscutiblemente Kai Havertz, autor del gol inicial y un referente en el área. Su remate de cabeza, preciso y letal, sentó las bases de la victoria.
#
# En definitiva, este 2-0 no es solo una derrota para el PSG, sino también una señal de alarma. El Arsenal ha demostrado ser un rival formidable en esta Champions League, y el camino hacia la clasificación será mucho más complicado de lo que se esperaba. La pregunta ahora es si Luis Enrique podrá encontrar la fórmula para revertir la situación en París.  El futuro del PSG en Europa pende de un hilo, y este resultado no augura nada bueno.
#
#
# 📊 Palabras: 502

# %% [markdown]
# CoT
# Ficha 4

# %%
# FICHA 4 | Gemma | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Arsenal 2-0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25 J1)
2. GOLES: 20' Havertz (Arsenal, cabeza tras centro Trossard), 35' Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal domina con 2-0 al descanso, posesión 58-42, control total ante PSG estelar
4. 2T: Arsenal administra ventaja con entrada de Merino (debut), PSG mueve banquillo (Fabián Ruiz, Kolo Muani) sin reacción
5. JUGADOR: Kai Havertz (gol clave de cabeza, liderazgo ofensivo)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 4 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 4 – CONFIG 9 (Gemma | CoT | Sin rol | Sin restricciones)
# ================================================================================
# ## ¡Arsenal destroza al PSG en un Emirates electrizante! 2-0 y la marcha de los franceses se ve comprometida
#
# **Londres –** El Arsenal ha desatado su furia en el Emirates Stadium y ha humillado al Paris Saint-Germain con una contundente victoria por 2-0 que deja a los parisinos con serias dudas sobre su capacidad para llegar a las rondas finales de la Champions League. Un partido dominado, controlado y con un claro mensaje: el Arsenal está en racha y no tiene intenciones de perder su estatus como uno de los equipos más peligrosos del continente.
#
# **Havertz, líder en el ataque; Saka, maestro de la falta**
#
# La primera mitad fue una exhibición de poderío inglés. Apenas transcurrían los 20 minutos cuando Kai Havertz, con un remate de cabeza tras un centro magistral de Trossard, abrió el marcador y desató la euforia en las gradas. Pero la alegría no paró ahí. En el 35’, Bukayo Saka transformó una falta lateral mal gestionada por Donnarumma en gol, sellando una primera mitad que dejó al PSG completamente eclipsado. El Arsenal dominaba con superioridad, controlando el balón (58-42) y ejerciendo un férreo presionar que ahogaba cualquier intento de reacción del rival.
#
# **El Arsenal administra la ventaja con Merino**
#
# La segunda mitad fue un ejercicio de gestión por parte de los ‘Gunners’. Entra Merino para refrescar el banquillo, pero el PSG no logra despertar. El técnico Luis Enrique realiza cambios buscando alternativas, incorporando a Fabián Ruiz y Kolo Muani, pero sin lograr romper la muralla defensiva del Arsenal. La ventaja se mantenía intacta, con el Arsenal administrando la victoria con solidez y determinación.
#
# **Havertz, figura indiscutible**
#
# La actuación de Kai Havertz fue, sin duda, la más destacada. El delantero alemán no solo anotó el primer gol, sino que también lideró el ataque del Arsenal con una presencia constante en el área rival y un despliegue físico impresionante. Su liderazgo ofensivo fue crucial para el éxito del equipo.
#
# **El futuro de PSG se pone en entredicho**
#
# Este resultado es un duro golpe para las aspiraciones europeas del Paris Saint-Germain. La Champions League parece cada vez más lejana, y la presión sobre Nasser Al-Khelaifi y su proyecto aumenta exponencialmente. El Arsenal ha demostrado ser un rival formidable y ha dejado claro que no tiene miedo de enfrentarse a los grandes equipos europeos.  La pregunta ahora es: ¿será este el punto de inflexión que necesitaba el PSG para redefinir sus objetivos?

# %%
# FICHA 4 | Gemma | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25, Jornada 1)
2. GOLES: 20' Havertz (Arsenal, cabezazo tras centro Trossard), 35' Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal domina con 2-0 al descanso, posesión 58-42, control total ante PSG estelar con Kvaratskhelia/Dembélé
4. 2T: Arsenal administra con debut Merino (64'), PSG reacciona con Fabián Ruiz/Kolo Muani sin puntería, Emirates festeja
5. JUGADOR: Kai Havertz (gol decisivo de cabeza, liderazgo ofensivo, clave en Arteta)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Arteta/Luis Enrique
- No inventes declaraciones ni citas textuales"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 4 – CONFIG 10 (Gemma | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **¡Arsenal destroza al PSG en la primera jornada de Champions! Un 2-0 que presagia un futuro brillante**
#
# 1. **RESULTADO:** Arsenal 2 – 0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25, Jornada 1)
# 2. **GOLES:** 20’ Havertz (Arsenal, cabezazo tras centro Trossard), 35’ Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
# 3. **1T:** ¡Dominio absoluto! El Arsenal se comía al PSG en el Emirates. Posesión del 58% y control total. Kvaratskhelia y Dembélé no encontraban hueco ante una defensa inglesa férrea.
# 4. **2T:** La gestión del Arsenal fue impecable. Merino, recién salido del banquillo, selló la victoria. El PSG intentó reaccionar con Fabián Ruiz y Kolo Muani, pero sin peligro real. ¡El Emirates rugía!
# 5. **JUGADOR:** Kai Havertz, ¡el héroe! Su cabezazo temprano, un gol decisivo que encendió el estadio y le dio la iniciativa a Arteta.
#
# **Análisis:**
#
# Arteta ha vuelto a demostrar su capacidad para construir equipos competitivos en Champions. El Arsenal, con una solidez defensiva impresionante, se impuso al PSG de Luis Enrique, quien deberá replantear su estrategia ante este rival. La clave del triunfo fue el control del balón y la eficacia en ataque. Havertz, pieza fundamental en la pizarra del técnico vasco, demostró ser un jugador determinante.  El Emirates vibró con la victoria, que presagia un futuro brillante para el Arsenal en esta competición europea. ¡Un comienzo de temporada Champions que no olvidaremos!

# %%
# FICHA 4 | Gemma | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, UEFA Champions League 2024/25, Fase de grupos – Jornada 1)
2. GOLES: 20' Havertz (Arsenal, remate de cabeza tras centro de Trossard), 35' Saka (Arsenal, lanzamiento de falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal se adelanta con gol de Havertz (20') y Saka amplía la ventaja (35') antes del descanso con dos tantos efectivos
4. 2T: Arsenal administra el 2-0 con entrada de Mikel Merino (64', debut), PSG mueve banquillo con Fabián Ruiz y Kolo Muani sin generar peligro real
5. ESTADÍSTICAS: Posesión 58–42, tiros 14–11, córners 6–5, xG 1.4–1.2 a favor del Arsenal
6. MVP: Kai Havertz (gol clave de cabeza, liderazgo ofensivo determinante)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 11 (Gemma | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Arsenal domina al PSG en su estreno en la Champions League y se asegura una ventaja inicial crucial**
#
# **Entrada:** El Arsenal se impuso 2-0 al Paris Saint-Germain en el Emirates Stadium, en un partido correspondiente a la primera jornada de la fase de grupos de la UEFA Champions League 2024/25. La victoria consolida la posición del equipo inglés y pone presión sobre el PSG, que deberá demostrar su capacidad para competir en la máxima competición europea.
#
# **Cronología:** El encuentro comenzó con una intensidad notable, y el Arsenal se puso al frente temprano en el minuto 20 gracias a un gol de cabeza de Kai Havertz. Trossard envió un centro preciso desde la banda izquierda, y Havertz aprovechó su posición para rematar con la cabeza, poniendo a su equipo por delante.  La ventaja se amplió en el 35’ cuando Bukayo Saka convirtió un lanzamiento de falta lateral mal gestionado por Gianluigi Donnarumma. El disparo del joven extremo inglés encontró portería tras una clara confusión defensiva parisina.
#
# Durante la primera mitad, el Arsenal controló el juego con una posesión superior al 58%, generando más oportunidades de gol que el PSG (14-11).  En la segunda parte, Mikel Merino entró al campo en el minuto 64’ para dinamizar el mediocampo del Arsenal. El debutante no tuvo un impacto inmediato, pero contribuyó a mantener la solidez defensiva y la posesión del balón. El PSG intentó reaccionar con cambios tácticos, introduciendo a Fabián Ruiz y Randal Kolo Muani, pero sin generar peligro real ante una defensa organizada del Arsenal.
#
# **Análisis xG:** Las estadísticas revelan un claro dominio del Arsenal en términos de creación de oportunidades.  El equipo inglés generó 1.4 goles esperados (xG), mientras que el PSG solo logró 1.2. Esto refleja la superioridad táctica y de ejecución del Arsenal, que supo aprovechar sus momentos de mayor peligro.
#
# **Cierre:** El Arsenal se lleva una victoria importante en su estreno en la Champions League, demostrando su capacidad para defender una ventaja inicial.  El 2-0 contra el PSG es un resultado positivo que les permitirá afrontar las próximas jornadas con confianza. Por otro lado, el PSG deberá analizar sus deficiencias y buscar soluciones para mejorar su juego ofensivo y su gestión de faltas laterales si quiere aspirar a llegar lejos en la competición. El partido concluyó con una posesión del balón del 58% para el Arsenal, 14 tiros contra 11, 6 córners frente a 5, evidenciando el control territorial y la mayor incidencia en el juego de los ingleses.  Kai Havertz fue reconocido como el MVP del partido por su gol clave y liderazgo en la zona ofensiva.
#
# 📊 Palabras: 430

# %%
# FICHA 4 | Gemma | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, Champions League 2024/25 – Fase de grupos, Jornada 1)
2. GOLES: 20' Havertz (Arsenal, remate de cabeza tras centro de Trossard), 35' Saka (Arsenal, lanzamiento de falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal se adelanta con gol de Havertz (20') y Saka amplía la ventaja (35') antes del descanso; posesión 58–42 a favor de los gunners
4. 2T: Arsenal administra con entrada de Mikel Merino (64', debut), PSG introduce Fabián Ruiz y Kolo Muani sin generar ocasiones claras
5. ESTADÍSTICAS: Posesión 58–42, tiros 14–11, córners 6–5, xG 1.4–1.2 a favor del Arsenal
6. MVP: Kai Havertz (gol decisivo de cabeza, liderazgo ofensivo, clave en la victoria de Arteta)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 12 (Gemma | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **¡Arsenal destroza al PSG en Londres y da un golpe a los franceses! 2-0 en la primera jornada de Champions**
#
# El Emirates Stadium vibraba anoche con una atmósfera electrizante. Y no decepcionó. El Arsenal, liderado por Mikel Arteta, se impuso 2-0 al Paris Saint-Germain en el primer partido del grupo y, lo que es más importante, demostró tener la ambición y la solidez para aspirar a grandes cosas en esta Champions League.
#
# La cronología de la noche fue implacable. En el minuto 20’, Kai Havertz, con un remate de cabeza impecable tras un centro preciso de Trossard, abrió el marcador. Un gol que encendió al estadio y desestabilizó a los parisinos. Apenas cinco minutos después, Gabriel Martinelli, en una jugada rápida, encontró a Emile Smith Rowe, quien asistió a Saka para que el joven inglés, con un lanzamiento de falta lateral mal gestionado por Gianluigi Donnarumma, doble la ventaja (35’). El Arsenal dominaba, controlando el partido con una posesión del 58% y generando superioridad en el centro del campo.
#
# La segunda mitad fue un ejercicio de gestión por parte de los Gunners. La entrada de Mikel Merino, recién debutante, aportó frescura y dinamismo al mediocampo. El PSG intentó reaccionar con la incorporación de Fabián Ruiz y Randal Kolo Muani, pero sin generar ocasiones claras de peligro. Los parisinos, que se vieron superados en posesión (42%), no lograron penetrar la defensa del Arsenal.
#
# Las estadísticas respaldan la superioridad del equipo londinense: 14 tiros contra 11, 6 córners frente a 5 y una xG (valoración de las oportunidades generadas) de 1.4 a favor del Arsenal. Un claro reflejo de su dominio en el juego.
#
# **Análisis xG:** La diferencia en la creación de oportunidades fue determinante. El Arsenal, con un xG de 1.4, tuvo más de un gol de más que el PSG (xG de 1.2). Esto demuestra la eficacia del ataque gunner y la solidez defensiva, que supo cerrar espacios y evitar las ocasiones claras para los visitantes.
#
# **Cierre épico:** La victoria no solo es importante por el resultado, sino por la forma en que se consiguió. El Arsenal demostró carácter, ambición y una clara idea de juego. Kai Havertz, nombrado MVP del partido, fue la pieza clave en ataque, liderando con su presencia y remate decisivo. Mikel Arteta ha comenzado esta Champions League con un mensaje claro: el Arsenal está aquí para competir por los grandes premios. El PSG, por su parte, deberá replantearse su estrategia si quiere aspirar a llegar lejos en esta competición. La Liga de Campeones ya ha dado su primera sorpresa.
#
# 📊 Palabras: 424
