# %% [markdown]
# CONFIGURACIÓN INICIAL QWEN 3-4b-2507

# %%
import pandas as pd
from openai import OpenAI
import nltk
nltk.download('punkt_tab', quiet=True)
nltk.download('punkt', quiet=True)

# Cliente LM Studio (Qwen3-4b-2507)
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio"  # cadena ficticia, solo para cumplir la interfaz
)

print("✅ CLIENTE LM STUDIO CONECTADO - Qwen3-4b-2507 lista")
# Out:
# ✅ CLIENTE LM STUDIO CONECTADO - Qwen3-4b-2507 lista

# %%
# CELDA DE COMPROBACIÓN: listar modelos disponibles vía API local

modelos = client.models.list()
modelos_id = [model.id for model in modelos.data]

for mid in modelos_id:
    print(mid)
# Out:
# qwen/qwen3-4b-2507

# %% [markdown]
# FICHA 1
# ZERO SHOT

# %%
# FICHA 1 | Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha1 = """ID_PARTIDO: UCL_2024_FINAL
Competición: UEFA Champions League
Temporada: 2023/2024
Fase: Final
Fecha: 01/06/2024
Hora: 20:00 (UTC+1)
Estadio: Wembley Stadium, Londres
Asistencia: 86,212
Árbitro: Slavko Vinčić
Equipo 1: Borussia Dortmund
Equipo 2: Real Madrid
Entrenador Borussia Dortmund: Edin Terzić
Entrenador Real Madrid: Carlo Ancelotti
Alineación Borussia Dortmund:
Kobel; Ryerson, Hummels, Schlotterbeck, Maatsen; Can, Brandt, Sabitzer; Adeyemi, Füllkrug, Sancho
Alineación Real Madrid:
Courtois; Carvajal, Rüdiger, Nacho; Mendy; Camavinga, Valverde, Kroos; Bellingham; Rodrygo, Vinícius Júnior
Resultado final: Borussia Dortmund 0 – 2 Real Madrid
Resultado al descanso: 0 – 0
Goles:
74' Dani Carvajal (Real Madrid), gol
83' Vinícius Júnior (Real Madrid), gol
Tarjetas amarillas Borussia Dortmund:
40' Nico Schlotterbeck
43' Marcel Sabitzer
79' Mats Hummels
Tarjetas amarillas Real Madrid:
35' Vinícius Júnior
Sustituciones Borussia Dortmund:
72' Marco Reus por Karim Adeyemi
80' Donyell Malen por Emre Can
80' Sébastien Haller por Julian Brandt
87' Jamie Bynoe-Gittens por Jadon Sancho
Sustituciones Real Madrid:
85' Luka Modrić por Toni Kroos
85' Joselu por Jude Bellingham
90' Éder Militão por Rodrygo
90+4' Lucas Vázquez por Vinícius Júnior
Eventos registrados:
21' Ocasión de gol Borussia Dortmund: remate de Karim Adeyemi bloqueado
23' Remate de Niclas Füllkrug al poste
Final del partido: gol de Borussia Dortmund anulado por fuera de juego
Estadísticas totales:
Posesión (%): 46 – 54
Tiros: 13 – 13
Tiros a puerta: 3 – 6
Córners: 9 – 8
Faltas: 12 – 8
Fueras de juego: 1 – 0
Estadísticas por partes:
Primera parte: posesión 40 – 60, tiros 8 – 2, córners 5 – 1
Segunda parte: posesión 54 – 46, tiros 5 – 11, córners 4 – 7
Estadísticas avanzadas:
xG: 1.86 – 1.15
Jugador del partido: Dani Carvajal"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha1}"

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",  
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 1 (Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 1 – CONFIG 1 (Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# **CRÓNICA DEPARTAMENTAL: REAL MADRID 2-0 BORUSIA DORTMUND – LA FINAL DE LA CHAMPIONS DE 2024 EN WEMBLEY**
# *Por [Nombre del periodista], para AS y Marca*
# **01 de junio de 2024 | Wembley Stadium, Londres**
#
# El estadio de Wembley, en pleno corazón de Londres, se convirtió en el escenario de una de las finales más emocionantes y significativas de la historia de la UEFA Champions League. En una noche de fuego, de gritos y de gloria, **Real Madrid** se impuso con un claro 2-0 ante **Borussia Dortmund**, en una final que no solo cerró una temporada de títulos, sino que reafirmó la hegemonía del Real Madrid en el escenario europeo.
#
# El partido, disputado a las 20:00 horas (UTC+1), fue un espectáculo de intensidad, táctica y entrega. Con una asistencia de **86.212 espectadores**, el estadio se llenó de energía, de colores rojos y blancos, y de una expectativa que no se disipó hasta el último minuto. El árbitro **Slavko Vinčić** dirigió el partido con una línea clara, aunque sin grandes incidentes que alteraran el flujo del encuentro.
#
# ---
#
# ### **Un partido de dos ritmos: el inicio y el final**
#
# El primer tiempo fue un duelo de equilibrio, con el **Dortmund** intentando imponer su ritmo de juego, especialmente en los primeros 20 minutos. Aunque el equipo alemán tuvo más posesión (40% frente a 60%), sus intentos de gol fueron escasos. El **remate de Füllkrug al poste** en el minuto 23 fue uno de los momentos más cercanos al marcador, pero el balón fue desviado por el área y el esfuerzo de los defensores de Dortmund fue clave.
#
# El **Real Madrid**, por su parte, se mantuvo más ordenado, con una defensa compacta y una presión constante en el medio. Aunque no lograron convertir en el primer tiempo, su control de juego fue más efectivo, especialmente en los últimos 15 minutos, cuando comenzaron a presionar con más intensidad.
#
# El **minuto 21** fue clave: un remate de **Karim Adeyemi** fue bloqueado por el portero **Courtois**, y aunque el partido no se movió mucho, el error de la defensa del Dortmund fue notado por los aficionados. El gol de **Borussia** que se anuló por fuera de juego en el final del primer tiempo fue un momento que generó mucha polémica, pero que no cambió el rumbo del partido.
#
# ---
#
# ### **El segundo tiempo: el gol de Carvajal y el triunfo de Vinícius**
#
# El segundo tiempo fue el que marcó el destino del partido. A partir del minuto 60, el Real Madrid comenzó a imponer su ritmo, con más posesión (54% frente a 46%) y una mejor distribución de balones. La presión en el área fue constante, y el **minuto 74** fue el punto de inflexión.
#
# **Dani Carvajal**, en una de sus mejores actuaciones de la temporada, marcó el primer gol del partido. El lateral derecho, que hasta entonces había sido visto como un defensor de alto rendimiento, aprovechó una jugada de transición y puso el balón en el área. Su remate de media distancia fue impecable, y el balón entró por el lado derecho del área, con un gol que no solo marcó el punto de inflexión, sino que también fue un homenaje a su capacidad de juego en el área.
#
# Pero el verdadero momento de gloria llegó en el **minuto 83**, cuando

# %%
# FICHA 1 | Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha1}""".format(ficha1=ficha1)

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 2 (Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 1 – CONFIG 2 (Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# **CHAMPIONS LEAGUE 2023/2024: REAL MADRID 2-0 BORUSSIA DORTMUND – LA GLORIA DE UNA NOCHE INOLVIDABLE EN WEMBLEY**
#
# *Por [Tu Nombre], periodista deportivo | AS*
#
# **Londres, 1 de junio de 2024** — *El Wembley Stadium, en plena noche de gloria, se convirtió en el escenario de una final que no solo definía al ganador de la UEFA Champions League 2023/2024, sino que también marcó el final de una era en el fútbol europeo.*
#
# En una noche de intensidad, emociones y un clima de expectación que no dejó de crecer desde el primer minuto, **Real Madrid** se impuso con un claro 2-0 ante **Borussia Dortmund** en la final de la Champions League, alzándose con el trofeo tras una actuación de impecabilidad que dejó sin palabras a los aficionados del fútbol más exigente del mundo.
#
# El partido, disputado a las 20:00 horas (UTC+1) en el estadio de Wembley, congregó a más de **86.000 espectadores**, una multitud que celebró cada gol como si fuera el último de una década. El ambiente fue de tensión constante, con el público dividido entre los dos grandes equipos, pero al final, el equipo de **Carlo Ancelotti** fue el que se alzó con el título, consolidando su posición como uno de los más dominantes de la historia del fútbol europeo.
#
# ---
#
# ### **Un partido de dos ritmos: el dominio del Madrid en la segunda mitad**
#
# El partido comenzó con una intensidad que no dejó espacio para errores. Dortmund, con una alineación que parecía diseñada para la defensa y el control de juego, intentó imponerse desde el primer minuto. Pero el Madrid, con una presión constante y una movilidad que no se detuvo, fue el que marcó el tono.
#
# En la primera parte, el balón fue más dominado por los de Madrid (40-60 en posesión), aunque los alemanes no se rindieron. Füllkrug tuvo una ocasión clara en el minuto 23, rematando al poste, y Adeyemi tuvo una oportunidad en el minuto 21 que fue bloqueada por el arquero Courtois. Aunque el partido no tuvo goles, el nervio de los alemanes fue evidente.
#
# El descanso fue un punto de inflexión. A las 45', el marcador era 0-0, pero el ambiente ya comenzaba a cambiar. Los de Ancelotti, con una táctica de juego que mezclaba pasión y precisión, comenzaron a dominar el espacio, y en la segunda mitad, todo cambió.
#
# ---
#
# ### **Los goles que definieron el destino**
#
# El primer gol llegó en el minuto 74, cuando **Dani Carvajal**, en una de sus actuaciones más destacadas en la historia de la Champions, aprovechó una jugada de transición para colocar un balón de precisión al área. El balón fue desviado por el defensor de Dortmund y entró en la red con un toque de precisión. Fue un gol que no solo marcó el punto de inflexión, sino que también fue un homenaje a la capacidad de un jugador que, en su carrera, ha sido testigo de muchas grandes noches.
#
# Pero el verdadero momento de gloria llegó en el minuto 83, cuando **Vinícius Júnior**, con una carrera de 30 metros y un remate de imponente potencia, puso el segundo gol. El público se levantó en un rugido que se escuchó incluso en los puntos más lejanos del estadio. Fue un gol que no solo marcó el final

# %%
# FICHA 1 | Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha1}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 3 (Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config2)
print(f"\n📊 Palabras: {len(cronica_config2.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 3 (Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **CHAMPIONS LEAGUE 2023/2024: REAL MADRID 2-0 BORUSSIA DORTMUND – LA GLORIA DE UNA NOCHE INOLVIDABLE EN WEMBLEY**
#
# *Por [Tu Nombre], periodista deportivo | AS*
#
# **Londres, 1 de junio de 2024** — *El Wembley Stadium, en plena noche de gloria, se convirtió en el escenario de una final que no solo definía al ganador de la UEFA Champions League 2023/2024, sino que también marcó el final de una era en el fútbol europeo.*
#
# En una noche de intensidad, emociones y un clima de expectación que no dejó de crecer desde el primer minuto, **Real Madrid** se impuso con un claro 2-0 ante **Borussia Dortmund** en la final de la Champions League, alzándose con el trofeo tras una actuación de impecabilidad que dejó sin palabras a los aficionados del fútbol más exigente del mundo.
#
# El partido, disputado a las 20:00 horas (UTC+1) en el estadio de Wembley, congregó a más de **86.000 espectadores**, una multitud que celebró cada gol como si fuera el último de una década. El ambiente fue de tensión constante, con el público dividido entre los dos grandes equipos, pero al final, el equipo de **Carlo Ancelotti** fue el que se alzó con el título, consolidando su posición como uno de los más dominantes de la historia del fútbol europeo.
#
# ---
#
# ### **Un partido de dos ritmos: el dominio del Madrid en la segunda mitad**
#
# El partido comenzó con una intensidad que no dejó espacio para errores. Dortmund, con una alineación que parecía diseñada para la defensa y el control de juego, intentó imponerse desde el primer minuto. Pero el Madrid, con una presión constante y una movilidad que no se detuvo, fue el que marcó el tono.
#
# En la primera parte, el balón fue más dominado por los de Madrid (40-60 en posesión), aunque los alemanes no se rindieron. Füllkrug tuvo una ocasión clara en el minuto 23, rematando al poste, y Adeyemi tuvo una oportunidad en el minuto 21 que fue bloqueada por el arquero Courtois. Aunque el partido no tuvo goles, el nervio de los alemanes fue evidente.
#
# El descanso fue un punto de inflexión. A las 45', el marcador era 0-0, pero el ambiente ya comenzaba a cambiar. Los de Ancelotti, con una táctica de juego que mezclaba pasión y precisión, comenzaron a dominar el espacio, y en la segunda mitad, todo cambió.
#
# ---
#
# ### **Los goles que definieron el destino**
#
# El primer gol llegó en el minuto 74, cuando **Dani Carvajal**, en una de sus actuaciones más destacadas en la historia de la Champions, aprovechó una jugada de transición para colocar un balón de precisión al área. El balón fue desviado por el defensor de Dortmund y entró en la red con un toque de precisión. Fue un gol que no solo marcó el punto de inflexión, sino que también fue un homenaje a la capacidad de un jugador que, en su carrera, ha sido testigo de muchas grandes noches.
#
# Pero el verdadero momento de gloria llegó en el minuto 83, cuando **Vinícius Júnior**, con una carrera de 30 metros y un remate de imponente potencia, puso el segundo gol. El público se levantó en un rugido que se escuchó incluso en los puntos más lejanos del estadio. Fue un gol que no solo marcó el final
#
# 📊 Palabras: 543

# %%
# FICHA 1 | Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES
# AUDIENCIA: Aficionados AS/Marca

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha1}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos, xG, Jugador del partido"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 4 (Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 4 (Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **Champions 2024: Real Madrid conquista el trono de Wembley con dos goles de gloria**
#
# El Wembley de 2024 no solo albergó un partido de fútbol, sino una historia de gloria que se escribió en el último minuto del tiempo. En una noche de 20:00 horas, con 86.212 aficionados en el estadio londinense, Real Madrid se impuso por 2-0 ante Borussia Dortmund en la final de la UEFA Champions League, cerrando una temporada de ensueño con un triunfo que no solo fue técnico, sino emocional.
#
# El partido comenzó con una intensidad que no dejó espacio para errores. Aunque Dortmund, con su fútbol de alta presión y el talento de jugadores como Sancho y Füllkrug, intentó romper la línea defensiva, el balón no encontró su destino. En la primera parte, el dominio de posesión fue de 40-60, pero los tiros fueron escasos: solo tres para los de Borussia, frente a seis de los blancos. El xG (valor esperado de goles) de 1.86 para Dortmund frente a 1.15 para Real Madrid revelaba una clara desventaja en la calidad de oportunidades. Apenas en el 21’, Adeyemi tuvo una ocasión que fue bloqueada, y en el 23’, Füllkrug al poste, pero el partido no se movió.
#
# El descanso fue un punto de inflexión. A las 40’, Schlotterbeck recibió una tarjeta amarilla, y a las 43’, Sabitzer fue expulsado por una falta en el área. Pero el verdadero cambio llegó en la segunda mitad. A las 74’, Dani Carvajal, con un remate de precisión desde fuera del área, puso el primer gol de la noche. Fue un gol que no solo marcó el punto de inflexión, sino que también fue el **Jugador del Partido** por su actuación defensiva y ofensiva. A las 83’, Vinícius Júnior completó el triunfo con un gol de gran calidad, aprovechando una jugada de contragolpe que terminó en una diagonal de peligro.
#
# Las estadísticas hablan claro: Real Madrid dominó el partido con 54% de posesión, 6 tiros a puerta y un xG superior. A pesar de que Dortmund tuvo 13 tiros, solo 3 fueron a puerta, y el único fuera de juego fue anulado. Las sustituciones, como el ingreso de Modrić y Militão, fueron clave para mantener la intensidad.
#
# En un final que no dejó dudas, Real Madrid se lleva el trofeo. Pero más allá del resultado, el partido fue una demostración de madurez, de un equipo que sabe convertir oportunidades en goles. Con Carvajal como figura clave, el Madrid no solo ganó, sino que lo hizo con estilo, pasión y una entrega que solo los verdaderos campeones pueden ofrecer.
#
# 📊 Palabras: 428

# %% [markdown]
# FEW SHOT
# FICHA 1

# %%
# FICHA 1 | Qwen3-4b-2507 | Few-shot | Sin rol | Sin restricciones

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha1}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 5 (Qwen3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 1 – CONFIG 5 (Qwen3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# Borussia Dortmund 0–2 Real Madrid
# Un gol de Dani Carvajal en el minuto 74 y otro de Vinícius Júnior al final del partido decidieron una final de la UEFA Champions League que se disputó en el Wembley Stadium, Londres, el 1 de junio de 2024. El partido, celebrado a las 20:00 horas (UTC+1), contó con una asistencia de 86.212 espectadores, un récord para la competición en esta fase.
#
# El partido comenzó con equilibrio, aunque el Madrid dominó en posesión, especialmente en la segunda mitad, con una ventaja de 54 por ciento. A pesar de que el Dortmund tuvo varias ocasiones, solo una fue clara: un remate de Niclas Füllkrug al poste en el minuto 23, mientras que una oportunidad de gol de Karim Adeyemi en el minuto 21 fue bloqueada.
#
# La primera parte se cerró sin goles, con el Dortmund en posesión de 40 por ciento y solo dos tiros, mientras que el Madrid tuvo seis tiros a puerta. En la segunda mitad, el Madrid aumentó su presión, con una mayor cantidad de tiros (11 frente a 5) y más córners (7 frente a 4).
#
# El primer gol de Real Madrid llegó en el minuto 74, cuando Dani Carvajal marcó un gol de calidad, tras una buena jugada de transición. El segundo gol, en el minuto 83, fue anotado por Vinícius Júnior, quien aprovechó una buena posición en el área para convertir.
#
# Durante el partido, el Dortmund recibió tres tarjetas amarillas: Nico Schlotterbeck en el minuto 40, Marcel Sabitzer en el 43 y Mats Hummels en el 79. Real Madrid recibió una amarilla para Vinícius Júnior en el minuto 35.
#
# En el segundo tiempo, el Madrid realizó dos sustituciones clave: en el minuto 85, Luka Modrić y Joselu entraron en el campo, reemplazando a Toni Kroos y Jude Bellingham, respectivamente. A los 90 minutos, Éder Militão sustituyó a Rodrygo, y en el minuto 90+4, Lucas Vázquez entró en el campo en lugar de Vinícius Júnior.
#
# El partido finalizó con una victoria del Real Madrid por 2–0, tras una actuación sólida que permitió superar al Dortmund en una final clave.
#
# Jugador del partido: Dani Carvajal.

# %%
# FICHA 1 | Qwen3-4b-2507 | Few-shot SIMPLE | CON ROL | Sin restricciones
# Objetivo: forzar que Qwen NO copie la ficha y sí genere una crónica evaluable con rol periodístico.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot2 = f"""
Eres periodista deportivo de AS/Marca.

EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha1}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_fewshot2}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot2 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 6 (Qwen3-4b-2507 | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot2)
# Out:
# ✅ FICHA 1 – CONFIG 6 (Qwen3-4b-2507 | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# BORUSIA DORTMUND 0–2 REAL MADRID
# Un gol de Dani Carvajal a los 74 minutos y otro de Vinícius Júnior a los 83 minutos decidieron el partido en el Wembley Stadium, donde el Real Madrid se impuso en la final de la UEFA Champions League.
#
# El encuentro comenzó con equilibrio, aunque el Madrid dominó en posesión, especialmente en la segunda mitad, con una ventaja de 54 por ciento. A pesar de que el Dortmund tuvo varias ocasiones, como el remate de Füllkrug al poste y una oportunidad de gol de Adeyemi bloqueada, no logró convertir. El partido se mantuvo sin goles hasta el minuto 74, cuando Carvajal puso el primer gol de su equipo, tras una buena jugada de transición.
#
# A los 83, Vinícius Júnior cerró el partido con un gol de calidad, tras una rápida acción que terminó con una finalización precisa. El Madrid, que no recibió ninguna tarjeta roja, tuvo tres tiros a puerta, mientras que el Dortmund solo logró seis, aunque su xG (valor esperado de goles) fue inferior al de los blancos.
#
# El partido fue marcado por una intensa presión del Madrid, que se impuso en posesión y en el control del juego, especialmente en el segundo tiempo. Aunque el Dortmund tuvo varias ocasiones, el equipo de Ancelotti fue más eficaz en las transiciones y en el ataque.
#
# El jugador del partido fue Dani Carvajal, quien marcó el gol que puso al Real Madrid en ventaja.
#
# El partido se disputó a las 20:00 horas (UTC+1) ante una asistencia de 86.212 espectadores, y fue arbitrado por Slavko Vinčić.
#
# El Real Madrid se alzó con la Champions, tras una victoria que consolidó su título en la temporada 2023/2024.

# %%
# FICHA 1 | Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES
# Objetivo: generar crónica estructurada (400–500 palabras) sin copiar la ficha, pero respetando los datos clave.

# --- Prompt (few-shot real + restricciones) ---
ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha1 para aficionados al fútbol que leen AS o Marca:

{ficha1}

RESTRICCIONES:
• 500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 7 (Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 7 (Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Real Madrid, campeón de Europa: 2-0 frente al Borussia Dortmund en Wembley**
#
# El Real Madrid ha conquistado su séptimo título de la UEFA Champions League, al derrotar al Borussia Dortmund 2-0 en el Wembley Stadium el 1 de junio de 2024. Un partido que, aunque comenzó con equilibrio, terminó siendo una victoria clara y contundente para los blancos, que dominaron el partido con una intensidad y precisión que dejaron sin respuesta al equipo alemán.
#
# El primer gol llegó a los 74 minutos, cuando Dani Carvajal, en una de sus mejores actuaciones de la temporada, aprovechó un balón de salida para marcar con elegancia. El gol, que fue el primero de la noche, fue un claro ejemplo de la capacidad del Madrid para convertir oportunidades en puntos. Aunque el partido comenzó con una posesión del 46% para el Dortmund, el Madrid se impuso en el segundo tiempo, con una posesión del 54% y un xG de 1.86 frente a los 1.15 del equipo alemán.
#
# El segundo gol, a los 83 minutos, fue obra de Vinícius Júnior, quien aprovechó una jugada de contragolpe para anotar con precisión. El gol fue el último de una ofensiva que se consolidó tras la entrada de Luka Modrić y Joselu, quienes reforzaron el ataque. La eficacia del equipo en el segundo tiempo fue evidente: 5 tiros en el segundo tiempo, 6 a puerta, y un xG que subió a 1.86, mostrando una superioridad técnica y táctica.
#
# A pesar de que el Dortmund tuvo varias ocasiones, como el remate de Füllkrug al poste o el intento de Adeyemi bloqueado, el partido fue anulado en el final por fuera de juego, lo que dejó sin respuesta al equipo alemán. Las tarjetas amarillas (tres para el Dortmund y una para Vinícius) no afectaron el resultado, ya que el Madrid se mantuvo coherente en su juego.
#
# Carlo Ancelotti, con una rotación inteligente y una gestión táctica perfecta, demostró que su equipo es capaz de mantener el ritmo y la concentración hasta el final. Dani Carvajal, el jugador del partido, fue clave en el primer gol y en la defensa, mostrando una actuación que merece ser recordada.
#
# El Real Madrid no solo ganó, sino que lo hizo con claridad, dominio y una entrega que convierte este título en uno de los más importantes de la historia. Con este triunfo, el club se consolida como uno de los más exitosos de la Champions, y el camino hacia el nuevo reino del fútbol europeo está marcado.
#
# 📊 Palabras: 413

# %%
# FICHA 1 | Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES
# Objetivo: crónica periodística estructurada (400–500 palabras) con tono de profesional deportivo.

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha1 para aficionados que leen AS o Marca:

{ficha1}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos, sus minutos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 8 (Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 8 (Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **Real Madrid 2-0 Borussia Dortmund. Goles: 74' Dani Carvajal, 83' Vinícius Júnior.**
#
# El Wembley Stadium, albergó esta noche una de las finales más emocionantes de la historia de la UEFA Champions League, con el Real Madrid que, tras una intensa batalla, se impuso 2-0 ante el Borussia Dortmund en una noche de gloria para el club blanco. Con una posesión del 54% y un xG de 1.86 frente a 1.15, el Madrid dominó el partido desde el segundo tiempo, convirtiendo sus oportunidades en goles clave.
#
# El partido comenzó con una intensidad inmediata. Los alemanes, con una alineación de alto rendimiento, intentaron imponer su ritmo, pero el Madrid, con una defensa compacta y un ataque bien coordinado, se impuso en posesión. En la primera parte, el Dortmund tuvo tres ocasiones de gol: Adeyemi fue bloqueado en el primer minuto, Füllkrug remató al poste en el 23, y una final de partido fue anulada por fuera de juego. A pesar de eso, el Madrid no se dejó llevar por el nerviosismo.
#
# El primer gol llegó en el minuto 74, cuando Dani Carvajal, con un disparo de precisión desde fuera del área, puso el 1-0. Un gol que no solo marcó el inicio de la victoria, sino que también fue el primer gol de Carvajal en la final de la UCL. El segundo gol, en el 83, fue obra de Vinícius Júnior, quien aprovechó una jugada de contragolpe para anotar con un remate de cabeza. El xG de Real Madrid (1.86) fue superior al de Dortmund (1.15), reflejando una superioridad táctica y de creación.
#
# Durante el partido, el Madrid fue más eficiente en tiros a puerta (6 frente a 3), con una mejor distribución de córners (8 frente a 9) y una defensa más sólida. Aunque el Dortmund recibió tres amarillas (Schlotterbeck, Sabitzer y Hummels), el Madrid solo tuvo una (Vinícius), lo que evidenció una mayor disciplina.
#
# En el cambio de alineaciones, Ancelotti apostó por la estabilidad: Luka Modrić y Joselu entraron en el campo, y en el 90+4, Lucas Vázquez sustituyó a Vinícius, mostrando el alto nivel de rotación del entrenador.
#
# Este triunfo, en una final que se disputó ante una multitud de 86.212 espectadores, es un claro ejemplo de la capacidad del Real Madrid para convertir la superioridad técnica en victoria. Con un xG superior y una actuación coherente, el Madrid no solo ganó, sino que demostró que, en el escenario más alto, puede ser el mejor equipo del mundo.
#
# **Carlo Ancelotti, con su táctica y su liderazgo, ha dejado una marca indeleble en esta final.** El Madrid no solo se lleva el trofeo, sino que también se convierte en el último equipo en ganar la UCL en casa.
#
# 📊 Palabras: 448

# %% [markdown]
# CoT
# FICHA 1

# %%
# FICHA 1 | Qwen3-4b-2507 | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley, UCL 2023/24, Final)
2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)
3. 1T: Dortmund domina, genera más peligro y Füllkrug estrella un balón en el poste; xG 1.86 – 1.15 a favor del Dortmund
4. 2T: El Madrid reacciona, Carvajal abre el marcador en el 74’ y Vinícius sentencia en el 83’; Courtois decisivo en la primera parte
5. JUGADOR: Dani Carvajal (defensa goleador y referente del triunfo)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 9 (Qwen3-4b-2507 | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 1 – CONFIG 9 (Qwen3-4b-2507 | CoT | Sin rol | Sin restricciones)
# ================================================================================
# **REAL MADRID DESTRUYE A BORUSIA DORTMUND EN WEMBLEY: EL TRIUNFO QUE DEJA A LA CAMPANA EN EL PICO DEL TURBIO**
#
# *Wembley, 1 de mayo de 2024 – El Real Madrid, con el corazón en la boca y el alma en el campo, ha escrito una nueva página en la historia de la UEFA Champions League. Un 2-0, frío, preciso y lleno de fuerza, ha sido el homenaje al espíritu del equipo blanco frente al poderoso Borussia Dortmund, que en su casa, en el Wembley, no ha podido contener el fuego del Madrid.*
#
# **74’ – EL GOL QUE DEJA A LA CAMPANA EN EL PICO DEL TURBIO**
# El partido no comenzó con la sonrisa del Madrid. Al contrario: el Dortmund, con su intensidad, su ritmo y su talento, dominó la primera mitad. Füllkrug, el hombre de la noche, estrelló un balón en el poste, como si el cielo se hubiera abierto para él. El xG, 1.86 frente a 1.15, decía claramente: *el Dortmund tiene más peligro, más ritmo, más vida*. Pero el Madrid, como un relámpago, reaccionó.
#
# Y fue **Dani Carvajal**, el defensa que nunca se rinde, quien abrió el marcador. Un córner de Kroos, un balón que parecía caer en el suelo, y Carvajal, con una agilidad que solo los verdaderos héroes del fútbol pueden tener, lo despejó con un disparo que no tuvo remedio. *¡74’! El Madrid, de nuevo, se pone en pie.*
#
# **83’ – VINÍCIUS JÚNIOR: EL FINAL QUE NO SE PUEDE OLVIDAR**
# El segundo gol, el que sentenció el partido, fue el de **Vinícius Júnior**, con asistencia de Bellingham, un pase que parecía sacado de una película de acción. El brasileño, con su velocidad, su precisión y su alma de atacante, se lanzó como un rayo, y el balón, como un disparo de precisión, entró en el área y fue inmovilizado por el portero. *¡83’! El Madrid, de nuevo, se lleva el triunfo.*
#
# **COURTOIS, EL GUARDIÁN QUE NO DEJA ESPACIO**
# Pero no fue solo el ataque. Fue la defensa, fue el corazón del equipo, fue **Courtois**, el hombre que, en la primera mitad, se convirtió en el ángel de la defensa. Con una parada que parecía un milagro, y una presencia que no dejaba espacio, el portero de los blancos fue el eje del partido. Su actuación fue clave, no solo para evitar goles, sino para dar confianza al equipo.
#
# **CARVAJAL: EL HÉROE DE LA NOCHE**
# Y si hay un jugador que merece ser recordado en esta noche, es **Dani Carvaj, el defensa que no solo defiende, sino que ataca, que marca, que lidera**. No fue solo un gol. Fue un símbolo. Un mensaje: *el Madrid no se rinde, no se dobla, no se queda atrás*. Carvajal, con su fuerza, su inteligencia y su entrega, fue el referente del triunfo.
#
# **CONCLUSIÓN: EL MADRID, DE VOLTA AL PODER**
# Wembley no fue un escenario de gloria para el Dortmund. Fue un campo de batalla donde el Madrid, con su disciplina, su fuerza y su espíritu, demostró que el fútbol no se mide solo por el

# %%
# FICHA 1 | Qwen3-4b-2507 | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley, UCL 2023/24, Final)
2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)
3. 1T: Dortmund domina, más ocasiones claras y Füllkrug al poste; Courtois sostiene al Madrid con tres intervenciones clave.
4. 2T: Madrid cambia el rumbo, Kroos lanza el córner del 1–0, Bellingham asiste en el 2–0, eficacia total. 
5. JUGADOR: Dani Carvajal (líder, goleador y pieza decisiva en la final).

ESCRIBE crónica paso a paso siguiendo estos cinco puntos:
- Usa tono periodístico español (propio de AS/Marca)
- Mantén ritmo ágil y frases breves
- Menciona contexto 
- No inventes citas ni declaraciones textuales
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 10 (Qwen3-4b-2507 | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 1 – CONFIG 10 (Qwen3-4b-2507 | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **REAL MADRID 2-0 BORUSIA DORTMUND | FINAL DE LA UCL 2023/24 | WEMBLEY**
#
# ---
#
# **1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley, UCL 2023/24, Final)**
#
# Wembley se convierte en escenario de una victoria que pone al Real Madrid como campeón de la UEFA Champions League 2023/24. El equipo de Zidane se impone con claridad, 2-0, ante el Dortmund, que no logra superar el ritmo de un Madrid que, al final, domina el partido desde el minuto 74.
#
# ---
#
# **2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)**
#
# El primer gol llega en el segundo tiempo, tras un córner de Kroos. Carvajal, en una acción de precisión, pone el 1-0. El segundo, a los 83, es una obra maestra de Vinícius Jún, que aprovecha una asistencia de Bellingham para cerrar el partido. No hay duda: el Madrid gana con eficacia, sin necesidad de un gol de "fuerza", sino de inteligencia y ejecución.
#
# ---
#
# **3. 1T: Dortmund domina, más ocasiones claras y Füllkrug al poste; Courtois sostiene al Madrid con tres intervenciones clave**
#
# El primer tiempo es un claro dominio del Dortmund. Tienen más posesión, más ocasiones claras y Füllkrug casi mete el primer gol, al poste. Pero el Real Madrid, en un momento clave, se salva. Courtois, con tres intervenciones clave, evita el empate. Su reacción ante el ataque de los alemanes es fundamental. El Madrid no se rinde, aunque el partido parece estar en manos del rival.
#
# ---
#
# **4. 2T: Madrid cambia el rumbo, Kroos lanza el córner del 1–0, Bellingham asiste en el 2–0, eficacia total**
#
# A partir del minuto 60, el Madrid cambia el rumbo. Kroos, con un córner preciso, pone el 1-0. El equipo se organiza, se mueve con coherencia. En el segundo tiempo, Bellingham, con una asistencia de calidad, pone el 2-0. El Madrid, en este segundo tiempo, juega con coherencia, sin errores, con una línea de juego que domina el espacio. La eficacia es total. El partido se vuelve ineluctable.
#
# ---
#
# **5. JUGADOR: Dani Carvajal (líder, goleador y pieza decisiva en la final)**
#
# Dani Carvajal no solo es el goleador de la final. Es el líder. El hombre que marca el ritmo, que se posiciona en el córner, que ejecuta con precisión. Su gol es el primero del Madrid en Wembley en una final de la UCL. No es un simple atacante. Es el corazón del equipo. En una final de este nivel, Carvajal es el jugador que define el partido.
#
# ---
#
# **Conclusión:**
# El Real Madrid gana en Wembley, 2-0, con una victoria que combina inteligencia táctica, liderazgo y ejecución. El Dortmund domina el primer tiempo, pero el Madrid, con una segunda mitad de fuego, se impone. Carvajal, en su noche de gloria, es el alma del triunfo. La UCL 2023/24 queda oficialmente en los libros del Real Madrid.

# %%
# FICHA 1 | Qwen3-4b-2507 | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley Stadium, UEFA Champions League 2023/24 – Final)
2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)
3. 1T: Dortmund domina el primer tiempo (posesión 60–40), genera más peligro (xG 1.86 vs 1.15), Füllkrug al poste, Courtois sostiene al Madrid.
4. 2T: El Real Madrid reacciona tras el descanso; Carvajal anota el 1–0 en el 74’ y Vinícius sentencia el 2–0 en el 83’. 
5. ESTADÍSTICAS CLAVE: Posesión 54–46, tiros 13–13, córners 9–8, xG 1.86–1.15 Dortmund–Madrid.
6. MVP: Dani Carvajal (gol decisivo y actuación defensiva sobresaliente).

ESCRIBE una crónica para AS/Marca siguiendo estas pautas:
• Extensión: 400-500 palabras
• Estructura: Entrada + Desarrollo cronológico + Cierre analítico
• Menciona TODOS los datos proporcionados
• No uses metáforas poéticas ni exageraciones irreales
• No inventes citas ni declaraciones
• Mantén tono deportivo e informativo con ritmo narrativo
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 11 (Qwen3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 11 (Qwen3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Real Madrid vence a Borussia Dortmund 2–0 en Wembley: el triunfo que cierra la Champions 2023/24**
#
# El Real Madrid se alzó con la Copa de la UEFA en el Wembley, derrotando al Borussia Dortmund 2–0 en la final de la Champions League 2023/24. El partido, disputado en el estadio de Wembley, marcó el cierre de una temporada de intensidad y tensión, donde el equipo de Madrid demostró su capacidad para transformar el dominio en resultados.
#
# El primer tiempo fue claramente dominado por el Borussia Dortmund. Con una posesión del 60 por ciento frente al 40 por ciento del Real Madrid, el equipo alemán generó más peligro en el área, con un xG de 1.86 frente al 1.15 del conjunto español. Füllkrug se acercó al poste, pero Courtois logró mantener la portería en orden, evitando que el partido se fuera de la línea. A pesar del control de juego, el Madrid no logró convertir sus oportunidades, y el primer tiempo terminó con una clara ventaja táctica para los alemanes.
#
# Tras el descanso, el Real Madrid reaccionó con firmeza. Aunque la posesión se redujo ligeramente (54 por ciento frente al 46 por ciento), el equipo logró convertir sus oportunidades en goles. En el minuto 74, Dani Carvajal marcó el primer gol del partido tras un córner de Kroos, que fue ejecutado con precisión y terminó en el área. El gol fue clave para cambiar el rumbo del partido, ya que el Madrid comenzó a imponer su ritmo en el segundo tiempo.
#
# El segundo gol llegó en el minuto 83, cuando Vinícius Júnior anotó tras una asistencia de Bellingham. El ataque de los blancos se volvió más fluido y eficiente, y el gol sentenció el partido. Aunque ambos equipos tuvieron 13 tiros, el xG final fue de 1.86 para Dortmund y 1.15 para Madrid, reflejando la superioridad de la primera mitad.
#
# En cuanto a estadísticas, el Real Madrid mantuvo una posesión ligeramente superior (54–46), con 9 córners frente a los 8 del Dortmund. A pesar de la presión inicial, el Madrid logró convertir sus mejores oportunidades en goles, mientras que el Dortmund no logró igualar el nivel de peligro en el segundo tiempo.
#
# El jugador que más destacó fue Dani Carvajal, quien marcó el gol decisivo y mostró una actuación defensiva sobresaliente. Su desempeño fue clave para la victoria, y por ello fue elegido MVP del partido.
#
# El triunfo de Real Madrid en Wembley no solo fue un resultado, sino una demostración de resiliencia y capacidad de transformar el dominio en victoria.
#
# 📊 Palabras: 419

# %%
# FICHA 1 | Qwen3-4b-2507 | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley Stadium, Champions League 2023/24 – Final)
2. GOLES: 74' Dani Carvajal (Real Madrid, remate tras córner de Toni Kroos), 83' Vinícius Júnior (Real Madrid, definido tras asistencia de Jude Bellingham)
3. 1T: Borussia Dortmund domina el primer tiempo, genera más peligro, Füllkrug remata al poste y Courtois sostiene al Madrid; xG 1.86–1.15 a favor de los alemanes.
4. 2T: El Real Madrid ajusta, gana metros y efectividad; Carvajal abre el marcador en el 74’ y Vinícius sentencia el 2–0 en el 83’, con Ancelotti gestionando los cambios finales.
5. ESTADÍSTICAS CLAVE: Posesión 54–46, tiros 13–13, córners 9–8, xG 1.86–1.15.
6. MVP: Dani Carvajal (gol decisivo, peso defensivo y simbólico en la final).

ESCRIBE una crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos de los puntos 1–6
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 12 (Qwen3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 12 (Qwen3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **REAL MADRID 2–0 BORUSIA DORTMUND: EL FINAL QUE NO SE OLVIDA**
#
# Wembley se convirtió en escenario de una final que, al final, fue de los españoles. Real Madrid venció 2–0 a Borussia Dortmund en la final de la Champions League 2023/24, tras una primera parte dominada por los alemanes y una segunda que fue de ajuste, control y precisión.
#
# En el primer tiempo, Dortmund dominó el campo, con más posesión (46%) y más intentos de gol (6 tiros frente a 4 del Madrid). Füllkrug se acercó al poste, y Courtois, con una parada clave, evitó el primer gol. El xG de los alemanes (1.86) superaba ampliamente el de los blancos (1.15), lo que indicaba una primera mitad más peligrosa para los visitantes.
#
# Pero el segundo tiempo fue distinto. Madrid, con más metros y mejor distribución, se reorganizó. A los 74’, Dani Carvajal puso el primer gol tras un córner de Toni Kroos. El remate fue directo, de un disparo que no dejó margen. A los 83’, Vinícius Júnior cerró el partido con un gol definido tras asistencia de Jude Bellingham. El Madrid, con un juego más ajustado, logró la victoria con claridad.
#
# Las estadísticas reflejan el cambio: posesión 54–46, tiros 13–13, córners 9–8. El xG, aunque no fue de los alemanes, mostró que el Madrid fue más efectivo en los momentos clave. La diferencia no fue de cantidad, sino de calidad en el momento adecuado.
#
# El MVP fue Dani Carvajal. Su gol en el 74’ fue decisivo, pero también su peso defensivo y su presencia en el campo en una final de alto nivel. No fue un atacante, pero su actuación simbólica y táctica fue clave.
#
# En Wembley, el Madrid no solo ganó, sino que demostró que el control del partido, el ajuste y la capacidad de responder en el momento clave son lo que definen a los verdaderos campeones. El 2–0 no fue un resultado, fue una victoria estructurada, clara y finalmente inolvidable.
#
# 📊 Palabras: 324

# %% [markdown]
# FICHA 2
# ZERO SHOT

# %%
# FICHA 2 | Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha2 = """ID_PARTIDO: UCL_2024_J1_BAY_DIN
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1
Fecha: 17/09/2024
Hora: 19:00 UTC
Estadio: Allianz Arena (Múnich)
Asistencia: 75 000
Árbitro: Juan Martínez Munuera (España)

Equipo 1: Bayern Munich
Equipo 2: Dinamo Zagreb

Entrenador Bayern Munich: Vincent Kompany
Entrenador Dinamo Zagreb: Sergej Jakirović

Alineación Bayern Munich:
Neuer; Kimmich, Upamecano, De Ligt, Davies; Goretzka, Pavlović; Olise, Musiala, Sané; Kane

Alineación Dinamo Zagreb:
Livaković; Ristovski, Théophile-Catherine, Mmaee, Smolcic; Mišić, Perić; Pjaca, Baturina, Hoxha; Petković

Resultado final: Bayern Munich 9 – 2 Dinamo Zagreb
Resultado al descanso: 3–0

Goles:
19' Harry Kane (Bayern Munich), gol de penalti
34' Raphaël Guerreiro (Bayern Munich), gol
38' Michael Olise (Bayern Munich), gol
48' Harry Kane (Bayern Munich), gol
57' Michael Olise (Bayern Munich), gol
73' Harry Kane (Bayern Munich), gol de penalti
81' Kingsley Coman (Bayern Munich), gol
87' Joshua Kimmich (Bayern Munich), gol
90+3' Mathys Tel (Bayern Munich), gol

Goles Dinamo Zagreb:
49' Bruno Petković, gol
50' Takuya Ogiwara, gol

Tarjetas amarillas Bayern Munich: N/D
Tarjetas amarillas Dinamo Zagreb: 77' Ristovski
Tarjetas rojas: N/D

Sustituciones Bayern Munich: N/D
Sustituciones Dinamo Zagreb: N/D

Eventos registrados:
19' Penalti a favor del Bayern Munich convertido por Harry Kane
73' Segundo penalti a favor del Bayern Munich convertido por Harry Kane

Estadísticas totales:
Posesión (%): 72 – 28
Tiros: 32 – 7
Córners: 12 – 2

Estadísticas avanzadas:
xG: 5.4 – 1.2

Jugador del partido: Harry Kane"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha2}"

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 1 (Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 2 – CONFIG 1 (Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# **CRÓNICA DEPARTIDO: Bayern Munich 9-2 Dinamo Zagreb | Fase de Grupos, Jornada 1 | UEFA Champions League 2024/2025**
# *Por [Nombre del periodista], para AS y Marca – 17 de septiembre de 2024*
#
# ---
#
# **Múnich, 17 de septiembre de 2024** – *Un partido que no se olvidará en el calendario de la Champions League: el Bayern Munich, en una noche de fuego y de gloria, se impuso con una victoria que parece salir de una película de acción: 9-2 frente a Dinamo Zagreb en la Allianz Arena, ante una multitud de 75.000 aficionados que no solo celebraron un resultado, sino una demostración de dominio absoluto.*
#
# Este fue el primer partido de la temporada 2024/2025 de la **Fase de Grupos de la UEFA Champions League**, y el Bayern Munich lo ha marcado con una **furia ofensiva** que no deja espacio para dudas. Con una posesión del 72% y una presión constante, los alemanes dominaron el partido desde el primer minuto, y lo hicieron con una **fuerza táctica y un ritmo de juego que parecen haber sacado de la caja de herramientas de un equipo de élite**.
#
# El partido comenzó con el grito de la afición: **19’**, Harry Kane, tras un penalti convertido tras una infracción de Mmaee, puso el primer punto del partido. Fue el primer gol de un **"Kane Show"** que se avecina a convertirse en una de las más espectaculares de la historia del fútbol europeo.
#
# Pero no fue solo Kane quien brilló. **Raphaël Guerreiro** (34'), **Michael Olise** (38'), y **Harry Kane** de nuevo (48') hicieron que el Bayern fuera un equipo que no solo atacaba, sino que **atacaba con precisión y ritmo**. El gol de Olise en el minuto 38 fue un claro ejemplo de la capacidad del equipo para generar peligro en el área, y el segundo gol de Kane en el minuto 48 fue una muestra de su **fuerza mental y su capacidad de reacción**.
#
# El partido se fue a otro nivel en el segundo tiempo. A los **57’**, Olise anotó su segundo gol, y el Bayern ya no se detuvo. A los **73’**, el segundo penalti del partido fue convertido por **Harry Kane**, una vez más, demostrando que el "Gol de la Noche" no es solo un nombre, sino una **realidad constante**.
#
# **Kingsley Coman** (81’) y **Joshua Kimmich** (87’) fueron los que cerraron el partido con dos goles que no solo hicieron que el marcador fuera de 9-2, sino que **transformaron el partido en una obra de arte ofensiva**. Y el último gol, en el **90+3’**, de **Mathys Tel**, fue el que puso el punto final a una noche de gloria.
#
# ---
#
# ### **¿Qué pasó en el otro equipo?**
#
# Dinamo Zagreb, por su parte, no se rindió. Aunque no tuvieron la capacidad de responder al ritmo del Bayern, lograron **dos goles en el segundo tiempo**: **Bruno Petković** (49’) y **Takuya Ogiwara** (50’), que fueron goles que, aunque no fueron suficientes, mostraron que el equipo tiene potencial. Sin embargo, **fueron goles que no pudieron cambiar el rumbo del partido**, que ya estaba decidido desde el minuto 30.
#
# El único **amarillo** fue para **Ristovski** en el minuto 77, pero no fue suficiente para detener

# %%
# FICHA 2 | Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha2}""".format(ficha2=ficha2)

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=1500
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 2 (Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 2 – CONFIG 2 (Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# **Bayern Munich 9-2 Dinamo Zagreb | El partido más inverosímil de la historia de la Champions League: un 9-2 en la Allianz Arena que deja sin palabras a los aficionados del fútbol**
#
# *Por [Tu Nombre], periodista deportivo | AS – 17 de septiembre de 2024*
#
# ---
#
# **Múnich, 17 de septiembre de 2024** — *No hay que decir que este partido fue un desastre para el fútbol. No, no fue un error. Fue un milagro. O, mejor dicho, fue un ataque de locura. Un ataque de 9 goles, de 19 minutos a 90+3, que se deslizó como un rayo de luz entre las sombras del fútbol tradicional.*
#
# El **Bayern Munich** se ha convertido en el equipo más letal de la historia de la **UEFA Champions League** en una jornada que, por su inverosimilidad, podría ser recordada como una de las más absurdas de la era moderna. En la **Allianz Arena**, ante una multitud de **75.000 aficionados** que se agolparon en el estadio como si fuera un festival de locos, el equipo alemán **anotó 9 goles** contra **Dinamo Zagreb**, que solo lograron **dos** en un partido que, por sus cifras, parece haber sido escrito por un algoritmo de inteligencia artificial que se ha vuelto loco.
#
# ---
#
# ### **Un partido que no debería existir**
#
# El resultado final: **9-2**.
# El marcador al descanso: **3-0**.
# El primer gol: **19’**, un penalti de **Harry Kane**.
# El último: **90+3’**, un gol de **Mathys Tel** que, según los registros, fue el **10º gol del partido**… pero no, fue el **9º**.
#
# ¿Qué pasó?
# ¿Qué fue lo que hizo que Bayern Munich, un equipo que ya ha ganado 10 veces la Champions, se convirtiera en un *fuego de fuego* en el campo?
#
# La respuesta está en **Harry Kane**.
#
# ---
#
# ### **Harry Kane: el jugador que no debería estar en el fútbol**
#
# El inglés de 35 años, que en su último año en el fútbol profesional fue considerado un "cerebro de la ofensiva", **anotó 7 goles** en este partido.
# Sí, **7 goles**.
# Sí, **7 goles** en un partido de 90 minutos.
# Sí, **7 goles** en un partido que incluyó **3 penaltis convertidos por él**.
#
# ¿Es posible?
# En teoría, no.
# En la realidad, **sí**.
# Porque en este partido, **Kane no solo jugó**, **se convirtió en un dios**.
#
# - **19’**: Penalti convertido (1º gol)
# - **34’**: Raphaël Guerreiro (2º)
# - **38’**: Michael Olise (3º)
# - **48’**: Kane (4º)
# - **57’**: Olise (5º)
# - **73’**: Kane (6º, penalti)
# - **81’**: Kingsley Coman (7º)
# - **87’**: Joshua Kimmich (8º)
# - **90+3’**: Mathys Tel (9º)
#
# ¿Y Dinamo Zagreb?
# Solo **dos goles**.
# Uno de ellos, en el minuto **49**, por **Bruno Petković**.
# El segundo, en el **50**, por **Takuya Ogiwara**.
# Y un **amarillo** para **Ristovski** en el minuto 77.
# El resto del partido fue una **cataclismo de desesperación**.
#
# ---
#
# ### **Estadísticas que no se pueden creer**
#
# - **Posesión**: 72% a 28% (Bayern)
# - **Tiros**: 32 a 7
# - **Córners**: 12 a 2
# - **xG (valor esperado de goles)**: 5.4 (Bayern) vs 1.2 (Dinamo)
#
# Esto no es un partido.
# Esto es un **escenario de ciencia ficción**.
# Bayern no solo dominó el partido, **dominó el espacio, el tiempo, el pensamiento y la lógica**.
#
# ---
#
# ### **¿Qué pasó en el campo?**
#
# No se sabe.
# No se puede explicar.
# Pero lo que sí se sabe es que **el fútbol se volvió un espectáculo de locura**.
#
# El entrenador **Vincent Kompany**, que en su primer partido como técnico de Bayern, no solo dirigió el partido, **lo convirtió en una obra de arte**.
# Y **Sergej Jakirović**, entrenador de Dinamo Zagreb, que lleva años intentando construir un equipo de fútbol moderno, **se vio arrastrado por una fuerza que no entendió**.
#
# ---
#
# ### **El jugador del partido: Harry Kane**
#
# Harry Kane, que en su carrera ha marcado 300 goles en 500 partidos, **no solo anotó 7 goles**, **sino que los hizo con una intensidad que no se ha visto en décadas**.
#
# - En el minuto 19: un penalti que fue el **primer gol del partido**.
# - En el 48: un gol que fue el **cuarto**, y que se convirtió en el **gol del corazón**.
# - En el 73: un penalti que fue el **segundo de la noche**, y que marcó el **punto de inflexión**.
#
# No fue un gol de precisión.
# Fue un gol de **fuerza, de pasión, de locura**.
#
# ---
#
# ### **Conclusión**
#
# El partido entre **Bayern Munich y Dinamo Zagreb** en la **primera jornada de la fase de grupos de la UEFA Champions League 2024/2025** fue **uno de los más inolvidables en la historia del fútbol**.
#
# Un **9-2** que no solo rompe las normas del fútbol, **sino que redefine lo que es posible**.
#
# Bayern Munich, con su **dominio total**, su **fuerza ofensiva** y su

# %%
# FICHA 2 | Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha2}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 2 – CONFIG 3 (Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 3 (Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Bayern Munich golea 9-2 a Dinamo Zagreb en una noche de furia en la Allianz Arena**
#
# El 17 de septiembre de 2024, la Allianz Arena se convirtió en un escenario de descontrol y dominio absoluto: Bayern Munich, con una intensidad inigualable, derrotó a Dinamo Zagreb por 9-2 en la primera jornada de la fase de grupos de la UEFA Champions League. Un partido que no solo marcó el tono de la temporada, sino que dejó claro que el equipo alemán está en plena explosión ofensiva, liderada por un Harry Kane que no solo marcó tres goles, sino que también fue el autor de dos penaltis convertidos.
#
# El partido comenzó con el fuego de la ofensiva: apenas 19 minutos, Kane puso el primer punto tras convertir un penalti, tras una infracción en el área. A los 34, Raphaël Guerreiro amplió la ventaja con un gol de precisión, y a los 38, Michael Olise sumó el tercer gol, mostrando la agilidad y el ritmo que caracterizan al equipo. A los 48, Kane volvió a marcar, consolidando su papel como el motor ofensivo del equipo. A los 57, Olise anotó de nuevo, demostrando que el ataque no se cansaba. El gol de Kane a los 73, tras otro penalti, fue el quinto de su carrera en esta fase de grupos, y el 81, Coman puso el sexto. A los 87, Kimmich anotó el séptimo, y el gol de Tel en el minuto 90+3 fue el definitivo, cerrando una noche de 9 goles en apenas 90 minutos.
#
# El marcador final de 9-2 no fue solo un resultado, fue una declaración: Bayern Munich domina con una posesión del 72%, 32 tiros frente a 7 de Dinamo, y un xG de 5.4 frente a 1.2, lo que refleja una superioridad total en el juego. Aunque Dinamo Zagreb logró dos goles (uno de Petković a los 49 y otro de Ogiwara a los 50), no pudieron reaccionar ante el flujo ofensivo del Bayern.
#
# El jugador del partido, Harry Kane, fue el alma del partido: anotó cuatro goles, incluyendo dos penaltis, y fue el principal impulsor del ataque. Su capacidad para marcar en momentos clave y su conexión con los compañeros fue clave para el dominio del equipo.
#
# Este resultado no solo pone a Bayern en una posición de liderazgo en su grupo, sino que también muestra que el equipo, bajo el mando de Vincent Kompany, está listo para una campaña de alto rendimiento. Para los aficionados, fue una noche de pura emoción, de goles sin parar y de una Allianz Arena que parecía vibrar con cada gol. Un partido que, sin duda, será recordado como uno de los más espectaculares de la historia de la Champions.
#
# 📊 Palabras: 449

# %%
# FICHA 2 | Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha2}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 4 (Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 4 (Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **Bayern Munich 9-2 Dinamo Zagreb: un despliegue de poder que deja sin palabras a los aficionados**
#
# El Allianz Arena, en pleno fuego de la temporada, se convirtió en un escenario de desbordamiento: Bayern Munich, con una intensidad sin precedentes, derrotó a Dinamo Zagreb 9-2 en una jornada que parecía más de una exhibición que de un partido normal. Con una posesión del 72%, 32 tiros y un xG de 5.4 frente a apenas 1.2, el equipo alemán no solo ganó, sino que lo hizo con una fiera precisión que dejó sin palabras al público de Múnich y a los aficionados de toda Europa.
#
# El partido comenzó con el fuego de la ofensiva. A los 19 minutos, Harry Kane, en un penalti convertido tras una infracción de Mmaee, abrió el marcador. No fue el único: a los 34, Raphaël Guerreiro puso el segundo, y a los 38, Michael Olise, con un disparo de precisión, amplió la ventaja. El primer descanso, por tanto, se marcó con un 3-0, una ventaja que se consolidó en el segundo tiempo. A los 48, Kane marcó de nuevo, esta vez con un gol de cabeza tras una jugada de finta, y a los 57, Olise volvió a anotar, mostrando su capacidad de generar peligro en el área.
#
# El segundo tiempo fue una verdadera explosión. A los 73, Kane recibió su segundo penalti del partido y lo convirtió, demostrando una constancia inigualable. A los 81, Kingsley Coman puso el sexto gol, y a los 87, Joshua Kimmich, con un disparo de fuera de área, marcó el séptimo. El último gol, a los 90+3, fue anotado por Mathys Tel, un gol que parecía un acto de desesperación, pero que en realidad fue el epítome de la dominación alemán.
#
# Dinamo Zagreb, por su parte, apenas tuvo tiempo para reaccionar. Solo dos goles: uno de Bruno Petković a los 49 y otro de Takuya Ogiwara a los 50. Aunque el equipo croata mostró resistencia, su xG de 1.2 no fue suficiente frente al dominio táctico y ofensivo del Bayern.
#
# **Harry Kane** fue el protagonista absoluto: anotó cinco goles, incluyendo dos penaltis, y fue el jugador con mayor impacto en el partido. Su capacidad para convertir en momentos clave, especialmente en el área, lo convierte en el **Jugador del partido**.
#
# Este resultado no solo marca el inicio de una temporada de gloria para el Bayern, sino que también deja claro que, en esta fase de grupos, el equipo alemán no solo está en forma, sino que está dispuesto a imponer su estilo. Un 9-2 no es solo un resultado, es una declaración: el Bayern Munich domina, y lo hará con fuerza.
#
# 📊 Palabras: 440

# %% [markdown]
# FEW SHOT
# FICHA 2

# %%
# FICHA 2 | Qwen3-4b-2507 | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Qwen NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha2}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 5 (Qwen3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 2 – CONFIG 5 (Qwen3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# Bayern Munich derrotó 9–2 a Dinamo Zagreb en un partido de la primera jornada de la Fase de Grupos de la UEFA Champions League, disputado el 17 de septiembre de 2024 en el Allianz Arena de Múnich, ante una asistencia de 75.000 espectadores.
#
# El partido comenzó con una dominancia clara del equipo alemán, que se impuso desde el primer minuto. El primer gol llegó al minuto 19, tras un penalti convertido por Harry Kane, quien también marcó al minuto 34 y al 38, con un gol de Michael Olise. A mitad de partido, el Bayern amplió su ventaja con un gol de Raphaël Guerreiro, y al minuto 48, Kane anotó de nuevo, esta vez tras otro penalti.
#
# La ofensiva alemán continuó con fuerza: en el minuto 73, Kane marcó su segundo penalti del partido, y poco después, Kingsley Coman y Joshua Kimmich anotaron respectivamente al minuto 81 y al 87. El marcador se mantuvo en el 9–2 al final del partido, con un gol de Mathys Tel en el minuto 90+3.
#
# Dinamo Zagreb logró dos goles, uno de Bruno Petković al minuto 49 y otro de Takuya Ogiwara al 50, pero no lograron reaccionar ante la intensidad del ataque bayernés.
#
# El Bayern Munich controló el partido con una posesión del 72 por ciento, con 32 tiros frente a los 7 de Dinamo Zagreb, y una ventaja significativa en xG (5,4 frente a 1,2).
#
# El partido fue dirigido por Vincent Kompany, mientras que el técnico de Dinamo Zagreb fue Sergej Jakirović. El árbitro fue Juan Martínez Munuera (España).
#
# Jugador del partido: Harry Kane.

# %%
# FICHA 2 | Qwen3-4b-2507 | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha2 para aficionados que leen AS o Marca:
{ficha2}"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 6 (Qwen3-4b-2507 | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 2 – CONFIG 6 (Qwen3-4b-2507 | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# **Bayern Munich 9-2 Dinamo Zagreb. El partido más inolvidable de la UCL 2024/25: un despliegue de poder que deja sin palabras a los aficionados de Europa.**
#
# *Por [Tu Nombre], periodista deportivo de AS/Marca*
#
# **Múnich, 17 de septiembre de 2024** – El Allianz Arena se convirtió en un escenario de desbordamiento, de fuego y de una noche que jamás olvidarán los aficionados de la Champions League. Bayern Munich, con una intensidad sin precedentes, derrotó a Dinamo Zagreb por **9-2** en la primera jornada de la fase de grupos de la UEFA Champions League 2024/25, un resultado que no solo marca el inicio de una campaña de fuego, sino que deja a la máxima competición europea en el umbral de una nueva era de dominio alemán.
#
# El partido, disputado a las 19:00 UTC ante una asistencia de **75.000 espectadores**, fue un auténtico espectáculo de fútbol de alto nivel. El Bayern, bajo el mando de **Vincent Kompany**, mostró una intensidad táctica y un nivel de ejecución que parecía salir de una película de acción. Con una posesión del **72%** y un xG de **5.4 frente a 1.2**, el equipo de Múnich no solo controló el partido, sino que lo desgarró en cada minuto.
#
# El primer gol llegó al **19’**, tras un penalti convertido por **Harry Kane**, quien no solo marcó, sino que también se convirtió en el **jugador del partido** de esta jornada. Su presencia en el campo fue clave: en el **34’**, **Raphaël Guerreiro** anotó el segundo, y en el **38’**, **Michael Olise** puso el tercero. El gol de **Kane** en el **48’** fue el cuarto, y el **57’** fue otro de Olise, que ya había marcado dos goles en el partido. El **73’** fue el sexto, y fue otro penalti convertido por Kane, que ya había marcado tres goles en el partido. A continuación, **Kingsley Coman** (81’) y **Joshua Kimmich** (87’) sumaron el séptimo y octavo, y el **90+3’** fue el **número 9**, anotado por **Mathys Tel**, que cerró el partido con una explosión de energía.
#
# Solo dos goles fueron anotados por Dinamo Zagreb: **Bruno Petković** en el **49’** y **Takuya Ogiwara** en el **50’**, un resultado que no solo fue un fracaso táctico, sino que también fue una muestra de la inestabilidad defensiva del equipo croata.
#
# El **xG de 5.4** del Bayern es el mayor de toda la historia de la fase de grupos en la UCL, y representa una diferencia de **4.2** en valor de goles, lo que indica que el equipo no solo ganó, sino que lo hizo con una superioridad de calidad y precisión.
#
# **Harry Kane**, con **6 goles** en el partido (5 de ellos de penalti), se convirtió en el **mejor jugador del partido** y en uno de los más destacados de la historia de la Champions. Su capacidad para convertir penaltis, su presencia en el área y su capacidad para crear oportunidades en el ataque hicieron que el Bayern se convirtiera en un equipo de fútbol de alto nivel.
#
# El partido fue también un claro ejemplo de la **eficacia táctica de Kompany**, quien puso en marcha un sistema de ataque que combinó velocidad, precisión y dominio de la posesión. El Bayern no solo

# %%
#FICHA 2 | Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha2 para aficionados al fútbol que leen AS o Marca:

{ficha2}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 7 (Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 7 (Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Bayern Munich 9-2 Dinamo Zagreb: una noche de furia y dominio en la UCL**
#
# El Allianz Arena se convirtió en un escenario de descontrol el 17 de septiembre de 2024, cuando el Bayern Munich derrotó al Dinamo Zagreb 9-2 en una de las más espectaculares victorias de la fase de grupos de la UEFA Champions League. Con una posesión del 72% y un xG de 5.4 frente a apenas 1.2, el equipo alemán mostró una ofensiva desbordante, con 32 tiros y 12 corners, que no tuvieron apenas contrapartida.
#
# El partido comenzó con fuerza: apenas 19 minutos, Harry Kane convirtió un penalti para poner al Bayern en ventaja. A los 34, Raphaël Guerreiro anotó su primer gol, y a los 38, Michael Olise sumó el tercer tanto. El marcador se amplió con dos más de Kane, uno en el minuto 48 y otro en el 73, tras otro penalti. A los 81, Kingsley Coman marcó su primer gol en la competición, y a los 87, Joshua Kimmich cerró el primer tiempo con un gol de precisión. El último gol llegó en el 90+3, con Mathys Tel, que dejó al Dinamo sin opciones.
#
# El equipo de Vincent Kompany, con su fórmula ofensiva y su capacidad de generar goles, demostró que no se trata solo de tener talento, sino de convertirlo en una máquina. El xG de 5.4 refleja una eficiencia sin precedentes, mientras que el 9-2 es el mayor margen de goles en una partida de grupos de la UCL desde 2009.
#
# Dinamo Zagreb, por su parte, apenas logró dos goles: uno de Bruno Petković en el minuto 49 y otro de Takuya Ogiwara en el 50. Aunque el equipo croata mostró resistencia, su defensa se vio abrumada por la intensidad del Bayern, que no solo dominó el partido, sino que lo vivió como una exhibición de poder.
#
# Harry Kane, con cinco goles, se convirtió en el jugador del partido, y su capacidad para convertir penaltis y mantener el ritmo ofensivo fue clave. El partido fue una declaración de intenciones: el Bayern no solo quiere ganar, quiere imponer su estilo.
#
# En un escenario de grupos donde los equipos deben competir por puestos, este resultado deja claro que el Bayern Munich no solo está en la UCL, sino que está en el centro del escenario. Un partido que, por sus cifras y su intensidad, será recordado como uno de los más impactantes de la temporada.
#
# 📊 Palabras: 402

# %%
# FICHA 2 | Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha2 para aficionados que leen AS o Marca:

{ficha2}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 8 (Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 8 (Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **Bayern Munich 9-2 Dinamo Zagreb: una noche de fuego en la Allianz Arena**
#
# El Bayern Munich no solo comenzó la temporada de Champions League con un triunfo, sino que lo hizo con una explosión de goles que dejó sin palabras a los aficionados de Dinamo Zagreb. En una noche de 17 de septiembre de 2024, en la Allianz Arena, los alemanes dominaron con una fuerza descomunal: 9-2 frente a un equipo de Croacia que apenas logró reaccionar. Con una posesión del 72% y un xG de 5.4 frente a apenas 1.2, el Bayern mostró su máxima intensidad, con un despliegue táctico y ofensivo que no dejó espacio para el contragolpe.
#
# El partido comenzó con fuego: a los 19’ Harry Kane, tras un penalti convertido, puso el primer gol, y a los 34’ Raphaël Guerreiro amplió la ventaja. A los 38’ Michael Olise, con un disparo de precisión, marcó el tercer gol, y a los 48’ Kane volvió a convertir, esta vez desde un penalti. El marcador se fue abriendo: a los 57’ Olise anotó de nuevo, y a los 73’ Kane, otra vez, con un penalti que dejó al público en silencio. A los 81’ Kingsley Coman sumó su gol, y a los 87’ Joshua Kimmich cerró el primer tiempo con un gol de gran calidad. El segundo tiempo fue aún más desbordante: a los 90+3’ Mathys Tel anotó el noveno gol, un disparo que marcó el final de una noche inolvidable.
#
# Dinamo Zagreb apenas logró dos goles: Bruno Petković a los 49’ y Takuya Ogiwara a los 50’. Aunque el equipo croata mostró resistencia, su defensa fue superada por la presión constante del Bayern, que controló el partido con 32 tiros y 12 corners frente a apenas 7 y 2.
#
# Harry Kane fue el protagonista absoluto: 3 goles, 2 penaltis convertidos, y una presencia que demostró su valor en el corazón del ataque. Su desempeño fue clave para el dominio del equipo, que se mostró como el verdadero protagonista de la fase de grupos.
#
# Este partido no fue solo un triunfo: fue una declaración de intenciones. El Bayern, bajo el mando de Vincent Kompany, ha abierto la temporada con una fuerza ofensiva que pone en alerta a todos los rivales. Con un xG de 5.4, el Bayern no solo ganó, sino que lo hizo con una eficiencia que pone en duda si cualquier equipo podrá resistir en esta fase.
#
# 📊 Palabras: 400

# %% [markdown]
# CoT
# FICHA 2

# %%
# FICHA 2 | Qwen3-4b-2507 | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Bayern Munich 9-2 Dinamo Zagreb (Allianz Arena, UCL 2024/25)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern domina, 3-0 al descanso, posesión 72%, xG 5.4 vs 1.2
4. 2T: Goleada histórica con hat-trick de Kane, Dinamo marca dos seguidos (49'–50'), but sin reacción
5. JUGADOR: Harry Kane (3 goles, liderazgo, clave ofensiva)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 2 – CONFIG 9 (Qwen3-4b-2507 | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 2 – CONFIG 9 (Qwen3-4b-2507 | CoT | Sin rol | Sin restricciones)
# ================================================================================
# **BAYERN MUNICH DESBARRA A DINAMO ZAGREB EN UNA GOLADA QUE DEJA A LA HISTORIA EN EL PISO**
#
# *Allianz Arena, 2024/25 – UEFA Champions League*
#
# **¡9-2!** El Bayern Munich no solo derrotó a Dinamo Zagreb, **lo arrasó**. No fue un partido, fue una **explosión ofensiva**, una **cascada de goles** que dejó al equipo croata sin reacción, sin defensa, sin esperanza.
#
# Desde el primer minuto, el Bayern **dominó**. Con posesión que se deslizó como una ola, con tácticas que no se detuvieron, y con un ataque que no tuvo descanso. Al descanso, el marcador ya era **3-0**, con el Bayern en posesión del balón en un **72%** y un xG de **5.4** frente a apenas **1.2** de Dinamo.
#
# Pero el verdadero espectáculo fue en la segunda mitad. **Harry Kane**, el hombre que encarna el espíritu del Bayern en el ataque, **se convirtió en el héroe de la noche**. Con un **hat-trick** en el segundo tiempo, el inglés **anotó tres goles** en apenas 15 minutos: el primero a los 48', el segundo a los 49' (después de un golpe de petardo de Petković), y el tercero a los 73' por penalti.
#
# ¡No fue solo un hat-trick! Fue una **cascada de poder**, una **explosión de identidad**. El Bayern no solo marcó, **se convirtió en un fenómeno**.
#
# Y si el primer tiempo fue una victoria, el segundo fue una **goleada histórica**. A los 49 y 50, Dinamo logró dos goles consecutivos, como un intento de reacción, pero el Bayern **no se detuvo**. El partido se fue de la mano del equipo croata.
#
# **Ogiwara**, **Kimmich**, **Coman** y **Tel** completaron la goleada, con el último gol a los 90+3', un final que **dejó a Dinamo sin aliento**.
#
# **Harry Kane**, con **3 goles**, fue el **motor del ataque**, el **líder invisible** que movió al equipo. Su presencia en el campo no fue solo un dato estadístico, fue una **fuerza de gravedad**.
#
# Este partido no fue solo una victoria.
# Fue una **declaración de poder**.
# Fue una **demostración de dominio**.
# Fue el Bayern Munich, **en su mejor versión**, **desbordando** a un equipo que no tuvo respuesta.
#
# **9-2.**
# No fue un resultado.
# Fue una **cascada de gloria**.
# Y el Bayern, una vez más, **se puso al frente del escenario europeo**.
#
# *¡El Bayern no solo ganó! ¡Lo hizo con fuego, con fuerza, con un ataque que no tuvo límites!*

# %%
# FICHA 2 | Qwen3-4b-2507 | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, UCL 2024/25, Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern impone ritmo, 3-0 antes del descanso, dominio total (posesión 72%, xG 5.4 vs 1.2)
4. 2T: Dinamo anota dos seguidos (49'-50'), pero el festival bávaro continúa con hat-trick de Kane y lluvia de goles
5. JUGADOR: Harry Kane (3 goles, participación clave, líder ofensivo)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Kompany
- No inventes declaraciones ni citas textuales
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 10 (Qwen3-4b-2507 | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 2 – CONFIG 10 (Qwen3-4b-2507 | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **BAYERN MUNICH 9-2 DINAMO ZAGREB: EL FESTIVAL DE KANE DEJA A LA CHAMPIONS EN FUEGO**
#
# *Allianz Arena. 1ª jornada de la Champions 2024/25. Un partido que no se olvida. Un partido que se escribe en letras de fuego.*
#
# **1. EL RESULTADO: 9-2.**
# No fue un simple partido. Fue una explosión.
# Bayern Munich, con el ritmo de un tren de guerra, derrotó a Dinamo Zagreb 9-2.
# No se trata de un resultado. Se trata de una declaración.
# Un 9-2 no se escribe en los libros. Se graba en el corazón de los aficionados.
#
# **2. LOS GOLES: UNA LLUVIA DE FUEGO.**
# 19': Kane, penalti. El primer disparo del fuego.
# 34': Guerreiro. El primer gol de Dinamo. Un respiro.
# 38': Olise. El Bayern se pone en marcha.
# 48': Kane. El segundo gol del canario.
# 49': Petković. Dinamo responde.
# 50': Ogiwara. Un gol de reacción.
# 57': Olise. El segundo hat-trick de la noche.
# 73': Kane. Penalti. El tercer gol del canario.
# 81': Coman. El corazón del equipo.
# 87': Kimmich. El último gol de la primera mitad.
# 90+3': Tel. El último disparo. El final.
#
# **3. PRIMERA MITAD: EL RITMO DE LA MÁQUINA.**
# Bayern impone el ritmo desde el primer minuto.
# 72% de posesión. Un dominio que no se discute.
# 5.4 de xG frente a 1.2. Un desequilibrio que no se corrige.
# 3-0 antes del descanso.
# Dinamo, en su casa, no puede parar el fuego.
# El Bayern no solo juega. El Bayern *ataca*.
#
# **4. SEGUNDA MITAD: UNA REACCIÓN, UNA RESPUESTA.**
# 49'-50': Dinamo anota dos goles seguidos.
# Un momento de esperanza.
# Pero el Bayern no se detiene.
# Kane, con su tercer gol, vuelve a encender el fuego.
# El hat-trick de Kane. El festival.
# La lluvia de goles.
# El Bayern no se rinde. El Bayern *se vuelve*.
#
# **5. EL JUGADOR: HARRY KANE, EL LÍDER DE LA OFENSIVA.**
# Tres goles.
# Tres momentos clave.
# Un líder. Un motor.
# No solo anota.
# Gestiona. Organiza. Inspira.
# En el corazón del Bayern, Kane es el alma del ataque.
# Su presencia, su ritmo, su fuerza.
# El hombre que convierte el partido en una obra de arte.
#
# **Y EL PAPEL DE KOMPANY?**
# No se menciona en los goles.
# Pero su presencia, su disciplina, su liderazgo en el campo, es el eje del sistema.
# El defensor que mantiene el orden.
# El hombre que permite que el ataque explote sin miedo.
# Sin él, el Bayern no sería lo que es.
#
# **CONCLUSIÓN:**
# Este partido no es solo una victoria.
# Es una demostración.
# De poder.
# De ritmo.
# De dominio.
# Bayern Munich, en la Champions, no solo juega.
# El Bayern *gana*.
# Y Harry Kane, en su noche de fuego, se convierte en el héroe de la primera jornada.
#
# *La Champions 2024/25 comienza con fuego. Y el Bayern, con Kane al frente

# %%
# FICHA 2 | Qwen3-4b-2507 | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, UEFA Champions League 2024/25, Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern 3-0 al descanso, dominio absoluto en posesión (72%) y ritmo ofensivo; Dinamo apenas se asoma
4. 2T: Dos goles rápidos del Dinamo (49', 50') antes del festival bávaro final con seis tantos más
5. ESTADÍSTICAS: Posesión 72–28%, tiros 32–7, córners 12–2, xG 5.4–1.2
6. MVP: Harry Kane (hat-trick, líder de ataque, decisivo)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 11 (Qwen3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 11 (Qwen3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Bayern Munich 9–2 Dinamo Zagreb: una victoria de dominio absoluto en la Allianz Arena**
#
# El partido de la primera jornada de la UEFA Champions League 2024/25 en la Allianz Arena fue una muestra clara del poder ofensivo y táctico del Bayern Munich. En una jornada que comenzó con el despliegue de una plantilla en plena forma, los bávaros derrotaron al Dinamo Zagreb por 9–2, una victoria que refleja una diferencia de nivel incontestable.
#
# El partido comenzó con una clara superioridad del Bayern, que dominó el campo con 72% de posesión y un ritmo ofensivo constante. En la primera mitad, el equipo de Pep Guardiola se impuso con claridad: a los 19 minutos, Harry Kane convirtió un penalti tras una infracción en el área, abriendo el marcador. A los 34 y 38 minutos, Guerreiro y Olise anotaron respectivamente, consolidando una ventaja de 3-0 al descanso. El dominio fue absoluto: el equipo bávaro controló el juego, con poca presión defensiva y poca oportunidad para el equipo croata.
#
# En la segunda mitad, el Dinamo logró dos goles rápidos: Petković marcó a los 49 y Ogiwara a los 50, aunque fueron apenas una interrupción en una ofensiva que se desbordó. A partir de los 57 minutos, Olise volvió a marcar, y el Bayern se lanzó en una ofensiva que culminó con tres goles más en el segundo tiempo: Kane (pen., 73), Coman (81), Kimmich (87), y Tel (90+3). El total final fue de 9–2, una cifra que refleja una diferencia de calidad en el rendimiento ofensivo.
#
# Las estadísticas respaldan esta superioridad: el Bayern tuvo 32 tiros frente a los 7 del Dinamo, 12 córners contra 2, y un xG de 5.4 frente a 1.2. El rendimiento de Kane fue clave: el delantero inglés anotó tres goles, incluyendo dos penaltis, y fue el líder del ataque, con una influencia directa en los resultados.
#
# El MVP del partido fue Harry Kane, quien no solo marcó un hat-trick, sino que también fue el principal impulsor del ataque. El resultado, aunque extremo, es una muestra de la efectividad táctica y ofensiva del Bayern en esta fase de la competición.
#
# 📊 Palabras: 351

# %%
# FICHA 2 | Qwen3-4b-2507 | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, Champions League 2024/25 – Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Superioridad bávara total, 3-0 al descanso, dominio en posesión (72%) y presión alta; Dinamo rezagado
4. 2T: Dos goles croatas rápidos (49', 50'), luego recital ofensivo del Bayern con hat-trick de Kane y vendaval de ocasiones
5. ESTADÍSTICAS: Posesión 72–28%, tiros 32–7, córners 12–2, xG 5.4–1.2
6. MVP: Harry Kane (hat-trick, líder de ataque, participación decisiva)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba y usa los gentilicios 'bávaros' y 'croatas'
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias
"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 12 (Qwen3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 12 (Qwen3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **BAVAROS DESTRUYEN A LOS CROATAS EN LA ALLIANZ: 9-2 EN EL MÁXIMO DE LA CHAMPIONS**
#
# El Bayern Munich, en su primera presentación en la Champions League 2024/25, dejó sin palabras a los croatas con un despliegue ofensivo que no tuvo parangón: 9-2 frente a Dinamo Zagreb en la Allianz Arena. Un resultado que no solo marca el inicio de una nueva era bávara, sino que deja claro que el equipo de Pep Guardiola no se limita a dominar, sino que domina con una precisión que desborda.
#
# El partido comenzó con una superioridad total. A los 19 minutos, Harry Kane puso el primer punto tras penalti, y el Bayern ya se sentía dueño del partido. A los 34 y 38, Guerreiro y Olise dieron el primer impulso ofensivo, pero fue el bávaro que se encargó de consolidar el dominio. A los 48 y 49, Kane y Petković anotaron, y el marcador ya se había convertido en una declaración de intenciones. Los croatas, por su parte, apenas tuvieron ocasiones: solo 7 tiros, frente a los 32 del Bayern, con un xG de 1,2 frente a los 5,4 del equipo bávaro.
#
# La primera mitad fue una demostración de control: el Bayern dominó el balón con un 72% de posesión, y la presión fue constante. Dinamo, por su parte, se quedó rezagado, sin capacidad de reacción. A los 50, Ogiwara anotó el segundo gol croata, pero fue solo un respiro. A los 57, Olise volvió a marcar, y el bávaro ya había dejado claro que no iba a dejar espacio para el contragolpe.
#
# La segunda mitad fue un vendaval. A los 73, Kane anotó su tercer gol, y el partido ya se había convertido en un espectáculo de ataque. A los 81, Coman sumó su gol, y a los 87, Kimmich cerró el primer tiempo de goles. El último, Tel, llegó en el 90+3, tras una jugada de alta intensidad.
#
# El MVP fue Harry Kane, con un hat-trick y una participación clave en todos los aspectos ofensivos. El Bayern, con una posesión de 72% y 12 córners frente a 2, mostró una eficiencia que no tiene parangón. Los croatas, con un xG de 1,2, no pudieron responder ante una ofensiva que no se detuvo ni un segundo.
#
# El 9-2 no fue solo un resultado: fue una declaración de poder bávaro. Y, por primera vez, la Champions League comenzó con un despliegue que no se puede ignorar.
#
# 📊 Palabras: 402

# %% [markdown]
# FICHA 3
# ZERO SHOT

# %%
# FICHA 3 | Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha3 = """ID_PARTIDO: UCL_2024_J1_MIL_LIV
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1
Fecha: 17/09/2024
Hora: 21:00 CEST (19:00 UTC)
Estadio: Stadio Giuseppe Meazza (San Siro), Milán
Asistencia: 59,826 espectadores
Árbitro: Espen Eskås (Noruega)
Equipo 1: AC Milan
Equipo 2: Liverpool
Entrenador AC Milan: Paulo Fonseca
Entrenador Liverpool: Arne Slot
Alineación AC Milan:
Maignan; Calabria, Tomori, Thiaw, Theo Hernández; Fofana, Reijnders; Pulisic, Loftus-Cheek, Leão; Morata
Alineación Liverpool:
Alisson; Bradley, Konaté, Van Dijk, Robertson; Mac Allister, Gravenberch, Szoboszlai; Salah, Núñez, Gakpo
Resultado final: AC Milan 1 – 3 Liverpool
Resultado al descanso: AC Milan 1 – 2 Liverpool
Goles:
3' Pulisic (AC Milan) 1–0, asistencia de Morata
23' Konaté (Liverpool) 1–1, remate de cabeza a balón parado
41' Van Dijk (Liverpool) 1–2, cabezazo tras córner de Tsimikas
67' Szoboszlai (Liverpool) 1–3, disparo tras jugada combinada
Tarjetas amarillas AC Milan:
51' Tomori
Tarjetas amarillas Liverpool:
79' Van Dijk
Tarjetas rojas:
Ninguna
Sustituciones AC Milan:
Ingresaron Chukwueze, Musah y Terracciano en la segunda parte
Sustituciones Liverpool:
Entraron Tsimikas y jugadores de refresco para administrar la ventaja
Eventos registrados:
3' Gol de Pulisic para el Milan
23' Konaté empata de cabeza
41' Van Dijk remonta antes del descanso
67' Szoboszlai sentencia el partido
Estadísticas totales:
Posesión (%): 55 – 45
Tiros: 16 – 12
Córners: 7 – 5
Estadísticas avanzadas:
xG: 1.8 – 1.1 (a favor de Liverpool)
Jugador del partido: Szoboszlai o Van Dijk"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha3}"

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 1 (Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config3)
# Out:
# ✅ FICHA 3 – CONFIG 1 (Qwen3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# **CRÓNICA DEPARTIDO: AC MILAN 1 – 3 LIVERPOOL | Fase de Grupos UCL 2024/2025 | San Siro, 17/09/2024**
# *Por [Nombre del autor], para aficionados al fútbol que leen AS o Marca*
#
# ---
#
# **Milán, 17 de septiembre de 2024** – El San Siro, en su más clásico de los estadios, se convirtió en escenario de una de las **mejores actuaciones de Liverpool en la fase de grupos de la Champions League** desde que el equipo de Klopp se impuso en el grupo de 2019. Pero esta noche, el **Milan de Paulo Fonseca** no solo se enfrentó al Liverpool, sino que **se enfrentó a una verdadera máquina de fútbol moderno** que, en apenas 67 minutos, demostró que no se trata de un simple partido, sino de una **batalla de ideas, ritmo y precisión**.
#
# El partido comenzó con el **sabor de una victoria en casa**, al menos en el primer minuto. A los **3 minutos**, **Pulisic** puso el primer punto del partido con un gol de gran calidad: un disparo de cabeza desde fuera del área, tras una excelente asistencia de **Morata**, que se convirtió en el primer jugador del partido en marcar. El Milan, con su estilo de juego más ofensivo, se mostró decidido: **posiciones altas, presión constante y un primer gol que parecía el inicio de una noche de gloria**.
#
# Pero el **Liverpool**, con su fútbol de alto nivel y su capacidad de reacción, no se quedó quieto. A los **23 minutos**, **Konaté** se convirtió en el héroe de la noche: un **remate de cabeza a balón parado** que puso el empate. Un gol que no solo fue técnico, sino que **mostró la inteligencia defensiva y la agilidad del equipo de Arne Slot**, que se posicionó como un equipo que no solo juega, sino que **piensa en cada movimiento**.
#
# El descanso llegó con el **1-1**, pero el partido no se detuvo. A los **41 minutos**, **Virgil van Dijk** se encargó de **remontar el partido con un cabezazo de gran calidad** tras un córner de **Tsimikas**, un gol que no solo fue un punto de inflexión, sino que **demostró que el Liverpool no solo podía mantenerse, sino que podía dominar**.
#
# El segundo tiempo fue una **carrera de precisión**. A los **67 minutos**, **Szoboszlai** puso el definitivo 3-1 con un disparo de gran calidad tras una **jugada combinada de alto nivel** que incluyó a Mac Allister y a Gravenberch. El gol fue el **cierre de una noche en la que el Liverpool mostró su verdadera esencia**: **fútbol de alto nivel, ritmo, inteligencia y goles en los momentos clave**.
#
# ---
#
# ### 📊 **Estadísticas que hablan de la superioridad del Liverpool**
#
# - **Posesión**: 55% para el Milan, pero el Liverpool **dominó el juego en los momentos decisivos**.
# - **Tiros**: 16 contra 12, con un **xG de 1.8 frente a 1.1**, lo que indica que el Liverpool **creó más oportunidades reales**.
# - **Córners**: 7-5, con el Milan más activo en el ataque, pero el Liverpool **sacó más provecho de sus córners**.
# - **Goles**: 3 a 1, con **dos goles de cabeza y uno de precisión**.
#
# ---
#
# ### 🏆 **Jugador del partido: Szoboszlai o Van Dijk**
#
# Ambos son candidatos

# %%
# FICHA 3 | Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha3}""".format(ficha3=ficha3)

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 2 (Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 3 – CONFIG 2 (Qwen3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# **AC MILAN 1 – 3 LIVERPOOL | Fase de grupos, jornada 1 | San Siro, 17/09/2024**
# *Por [Tu Nombre], periodista deportivo | AS*
#
# ---
#
# **Milán, 17 de septiembre de 2024** – El San Siro, en plena temporada de fuego, se convirtió en escenario de una de las peleas más intensas de la primera jornada de la **UEFA Champions League 2024/2025**. En un partido que mezcló intensidad, táctica y un claro dominio de los *Reds*, **Liverpool** se impuso con un triunfo de 3-1 sobre **AC Milan**, en una noche en la que el fútbol no solo se jugó, sino que se encendió.
#
# El partido comenzó con el aire de una batalla de ideales: el Milan, con su estilo de juego más defensivo y centrado en el ataque de pulso, intentó imponer su ritmo. Pero Liverpool, con su fútbol de velocidad y precisión, no se quedó atrás. Y en poco tiempo, el equipo de **Arne Slot** demostró que no es solo una potencia de goles, sino una máquina de transformación.
#
# El primer gol fue el que más sorprendió: **a los 3 minutos**, **Pulisic** puso en marcha al Milan con un disparo de cabeza desde un balón parado, asistido por **Morata**. Un gol que parecía el inicio de una noche de gloria para los rojinegros, pero que no duró mucho. El equipo de **Paulo Fonseca** no se rindió, pero tampoco se convirtió en una amenaza constante.
#
# A los **23 minutos**, el partido cambió de rumbo. **Konaté**, con una gran intervención en el área, cabeceó un balón parado para empatar. Un gol que no solo fue técnico, sino que marcó el inicio de una nueva fase: el Liverpool, con su juego de presión y movilidad, comenzó a dominar el campo.
#
# El descanso fue un punto de inflexión. A los **41 minutos**, **Virgil van Dijk** se convirtió en el héroe del partido con un cabezazo de gran calidad tras un córner de **Tsimikas**. El gol fue un acto de fuerza, de inteligencia y de entrega. El Milan, que había intentado mantener el equilibrio, se vio obligado a reaccionar, pero no logró encontrar la respuesta.
#
# Y fue entonces cuando el partido se puso en marcha. A los **67 minutos**, **Szoboszlai** puso el punto final con un disparo frío y preciso tras una jugada combinada que desbordó a toda la defensa rojinegra. Un gol que no solo sentenció el partido, sino que también fue el mejor de la noche: **un gol de calidad, de ritmo y de visión**.
#
# El partido finalizó con una **posesión del 55% para Liverpool**, con **16 tiros frente a 12 del Milan**, y una ventaja clara en **xG (1.8 vs 1.1)**. Aunque el Milan mostró una buena defensa y una buena presión, el equipo de **Slot** dominó el juego desde el primer minuto y lo mantuvo hasta el final.
#
# **Tarjetas**: Tomori (51') y Van Dijk (79') fueron los únicos expulsados, pero no fue necesario. El partido fue controlado, sin incidentes graves, y con una intensidad que dejó a los aficionados sin respiración.
#
# **Sustituciones** fueron clave: el Milan ingresó a **Chukwueze, Musah y Terracciano**, intentando reforzar el ataque, pero no lograron cambiar el rumbo. Liverpool, por su parte, entró **

# %%
# FICHA 3 | Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha3}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 3 – CONFIG 3 (Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 3 (Qwen3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **AC Milan cae en San Siro: Liverpool domina con fuerza en la primera jornada de la UCL**
#
# El estadio San Siro, en pleno fuego de la temporada, albergó este jueves una de las primeras citas de la UEFA Champions League 2024/2025, con el AC Milan frente al Liverpool en una partida que marcó el tono de la fase de grupos. Con una asistencia de 59.826 espectadores, el público milanista se encontró ante una noche de intensidad y dominio del equipo inglés, que se impuso 3-1 tras una actuación clara y eficaz.
#
# El partido comenzó con el Milan en posesión, y en el minuto 3, Pulisic puso el primer gol de la noche con un disparo preciso tras una asistencia de Morata, dando una ventaja inicial que parecía alentadora. Sin embargo, el Liverpool respondió con rapidez. En el minuto 23, Konaté aprovechó un balón parado para marcar con un remate de cabeza, empatando el partido y mostrando su capacidad de reacción en el área.
#
# El descanso fue clave: el Milan, con una posesión del 55% y 16 tiros, no logró romper el equilibrio. En el minuto 41, Van Dijk encendió el fuego con un cabezazo tras un córner de Tsimikas, remontando el partido y poniendo al Liverpool en ventaja. La diferencia se amplió en el segundo tiempo, cuando en el minuto 67, Szoboszlai puso el 3-1 con un disparo fruto de una jugada combinada que dejó al Milan sin opciones. Su actuación, con un xG de 1.8 frente al 1.1 del Milan, fue clave para definir el partido.
#
# Aunque el Milan tuvo más posesión, el xG de Liverpool (1.8) fue superior, lo que refleja una superioridad en la calidad de los disparos y en la efectividad de sus jugadas. El equipo de Arne Slot mostró una defensa sólida y una ofensiva bien coordinada, con un 55% de posesión y 12 tiros, pero con una mayor precisión en los momentos clave.
#
# Las tarjetas fueron escasas, con Tomori (51') y Van Dijk (79') recibiendo una amarilla, pero sin rojas, lo que permitió al equipo mantener el ritmo. Las sustituciones, con Chukwueze, Musah y Terracciano para el Milan, y Tsimikas para Liverpool, no cambiaron el rumbo del partido.
#
# En el cierre, el partido deja claro que el Liverpool, con su juego ofensivo y su capacidad de reacción, domina la primera jornada. Szoboszlai y Van Dijk, con sus actuaciones clave, se convierten en los protagonistas del día. El Milan, aunque logró un gol, no pudo mantener el ritmo ante una selección que domina el xG y el juego en el campo. La UCL 2024/2025 ya tiene su primer capítulo escrito: Liverpool, fuerte y decidido, se impone en San Siro.
#
# 📊 Palabras: 444

# %%
# FICHA 3 | Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha3}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 4 (Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 4 (Qwen3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **AC MILAN DEPONE EN SAN SIRIO, PERO LIVERPOOL DOMINA EN EL MÁS ALTO DE LA CHAMPIONS**
#
# *San Siro, 17 de septiembre de 2024* — El estadio de San Siro, en plena noche de estrellas y gritos, se convirtió en escenario de una de las primeras entregas de la temporada 2024/2025 de la UEFA Champions League. Con 59.826 aficionados en el estadio, el encuentro entre AC Milan y Liverpool fue un claro ejemplo de la intensidad que caracteriza a esta fase de grupos. Aunque el Milan abrió el marcador con un gol de Pulisic al minuto 3, el equipo de Arne Slot no se dejó llevar por el empate inicial. En una noche de dominio táctico y goleadora, Liverpool se impuso 3-1, con una actuación que dejó claro que el xG de 1,8 frente al 1,1 de su rival no fue solo una cifra estadística, sino una realidad en el campo.
#
# El partido comenzó con el Milan en posesión, y el gol de Pulisic, tras una asistencia de Morata, fue el primer disparo de una noche que prometía ser emocionante. Pero el equipo de Klopp no se quedó quieto. Al minuto 23, Konaté se encargó de empatar con un remate de cabeza a balón parado, un gol que marcó el inicio de una ofensiva que no se detendría. A los 41, Van Dijk se encargó de remontar el partido con un cabezazo tras un córner de Tsimikas, un gol que sentenció el primer tiempo con una ventaja que no se perdería. El segundo tiempo fue aún más claro: al minuto 67, Szoboszlai puso el 3-1 con un disparo tras una jugada combinada que demostró la calidad táctica y la conexión del equipo de Liverpool.
#
# A pesar de tener más posesión (55% frente a 45%), el Milan no logró convertir sus tiros (16 frente a 12), y su xG de 1,8 fue superado por el de Liverpool, que mostró una superioridad en la creación de oportunidades. El jugador del partido, entre los dos, fue Szoboszlai, cuyo gol fue el más decisivo, pero también Van Dijk, cuyo cabezazo fue el pilar del segundo tiempo. Ambos mostraron una combinación de fuerza física y inteligencia táctica que dejó sin palabras al equipo de Paulo Fonseca.
#
# El partido no tuvo tarjetas rojas, pero el desgaste físico y la presión del equipo de Liverpool fueron evidentes. Las sustituciones, especialmente de Tsimikas, fueron clave para mantener el ritmo ofensivo. Aunque el Milan intentó reaccionar con Chukwueze, Musah y Terracciano, no fue suficiente para revertir el curso del partido.
#
# En este primer partido de grupos, Liverpool se posiciona como uno de los principales candidatos al título, mientras que el Milan, aunque logró un gol, deberá replantearse su estrategia en la lucha por los puestos. La Champions no se juega solo con goles, sino con números, con xG y con la capacidad de mantener el control. Y en esta noche, Liverpool demostró que, al menos en San Siro, el camino hacia la final está más cerca de lo que parecía.
#
# 📊 Palabras: 500

# %% [markdown]
# FICHA 3
# FEW SHOT

# %%
# FICHA 3 | Qwen3-4b-2507 | Few-shot | Sin rol | Sin restricciones
# Objetivo: forzar que Qwen NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha3}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 5 (Qwen3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 3 – CONFIG 5 (Qwen3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# AC MILAN 1–3 LIVERPOOL
# Un gol de Pulisic al inicio del partido puso al Milan al frente, pero Liverpool reaccionó con fuerza para imponerse en un partido de la primera jornada de la fase de grupos de la UEFA Champions League. El equipo de Paulo Fonseca logró abrir el marcador en el minuto 3 con un gol de Pulisic, asistido por Morata, aunque el empate se produjo apenas 20 minutos después tras un remate de cabeza de Konaté desde un balón parado.
#
# El partido cambió de rumbo en el segundo tiempo, cuando Van Dijk anotó un cabezazo tras un córner de Tsimikas, tras el cual Liverpool consolidó su ventaja. El marcador se amplió en el minuto 67 con un disparo de Szoboszlai tras una jugada combinada, que sentenció el partido.
#
# El encuentro se disputó en el Stadio Giuseppe Meazza, con una asistencia de 59.826 espectadores, y se jugó a las 21:00 CEST. El equipo de Arne Slot dominó en posesión, con un 55 por ciento frente al 45 por ciento del Milan, y también superó en número de tiros (16 a 12), así como en córners (7 a 5). Las estadísticas avanzadas indican una ventaja clara para Liverpool en xG (1,8 frente a 1,1).
#
# Durante el partido, Tomori recibió una tarjeta amarilla en el minuto 51, mientras que Van Dijk fue amonestado en el minuto 79. No se registraron tarjetas rojas.
#
# Los cambios en ambos equipos fueron clave: AC Milan incorporó a Chukwueze, Musah y Terracciano en la segunda mitad, mientras que Liverpool ingresó a Tsimikas y a jugadores de refresco para mantener la intensidad.
#
# Jugador del partido: Szoboszlai.

# %%
# FICHA 3 | Gemma | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha3 para aficionados que leen AS o Marca:
{ficha3}"""

response = client.chat.completions.create(
    model="google/gemma-3-4b",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 3 – CONFIG 6 (Gemma | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# **AC Milan 1-3 Liverpool. Goles: 3’ Pulisic (1-0), 23’ Konaté (1-1), 41’ Van Dijk (1-2), 67’ Szoboszlai (1-3)**
# *UEFA Champions League – Fase de grupos, Jornada 1 | 17/09/2024 | San Siro*
#
# El San Siro, en una noche de fuego y de emociones, se convirtió en escenario de una de las primeras grandes sorpresas de la temporada de la Champions League 2024/2025: **Liverpool se impuso 3-1 ante AC Milan**, en un partido que mezcló intensidad, errores y una actuación de élite de sus jóvenes titulares.
#
# El partido comenzó con el Milan en posesión, con Pulisic poniendo el primer punto a los 3 minutos tras una gran jugada de Morata, que desató el ataque y dejó al público en pie. Fue un gol de inicio, sí, pero no de duración. A los 23, el joven **Konaté** se encargó de empatar con un remate de cabeza a balón parado, un gol que no solo mostró su agilidad, sino también la capacidad de reaccionar ante una presión que no se detuvo.
#
# Pero el verdadero giro del partido llegó en el segundo tiempo. A los 41, **Virgil van Dijk** se convirtió en el héroe de la noche: un cabezazo tras un córner de Tsimikas, que rompió el equilibrio del Milan y puso el 2-1. Fue un gol de precisión, de una de esas actuaciones que hacen que los aficionados se levanten y griten. Y aunque el Milan intentó recuperar el ritmo, el partido ya estaba decidido.
#
# El triunfo final fue sentenciado por **Szoboszlai** a los 67, tras una combinación de juego que dejó a los defensores de Milán sin respuesta. Un disparo de calidad, un gol que no solo cerró el partido, sino que también marcó el tono de una noche en la que el Liverpool demostró que no solo es un equipo de fútbol, sino de **fútbol de alto nivel, de inteligencia táctica y de juego constante**.
#
# **Estadísticas clave**:
# Liverpool domina con **55% de posesión** y un **xG de 1.8 frente a 1.1 del Milan**, lo que refleja una superioridad en el juego de creación y en la calidad de los tiros. Aunque el Milan tuvo más tiros (16 vs 12), fue el equipo de Klopp quien logró convertir más de lo que se esperaba.
#
# **Tarjetas**:
# Tomori (51’) y Van Dijk (79’) recibieron amarillas, pero sin rojas. Un partido de tensión, pero sin sanciones que alteren el rumbo.
#
# **Sustituciones clave**:
# El Milan puso en el campo a **Chukwueze, Musah y Terracciano**, intentando reforzar el ataque, pero no lograron cambiar el curso. Liverpool, por su parte, entró **Tsimikas** y otros jugadores de refresco, lo que mostró una estrategia de control del ritmo y de mantener la presión.
#
# **Jugador del partido**:
# Entre **Szoboszlai** y **Van Dijk**, el galardonado fue el **hombre del partido**. Szoboszlai, con su capacidad de desplazamiento y su precisión en el ataque, fue el que sentenció el partido. Pero Van Dijk, con su gol y su presencia en el centro del campo, fue el que marcó el tono de la noche: un defensor que no solo se defendió, sino que también atacó.
#
# **Conclusión**:

# %%
# FICHA 3 | Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha3 para aficionados al fútbol que leen AS o Marca:

{ficha3}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 7 (Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 7 (Qwen3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **AC Milan 1-3 Liverpool. Goles: 3’ Pulisic (1-0), 23’ Konaté (1-1), 41’ Van Dijk (1-2), 67’ Szoboszlai (1-3)**
# *San Siro, 17/09/2024 – El Milan se despertó con un gol de Pulisic, pero el Liverpool, con una actuación de fuego, se impuso 3-1 en un partido de grupos de la UCL que dejó claro quién domina el balón y quién domina el juego.*
#
# El San Siro, albergó una noche de fuego en la que el Liverpool, con una intensidad y precisión que no se esperaba, derrotó al AC Milan por 3-1. Aunque el Milan abrió el marcador con un gol de Pulisic a los 3 minutos, tras una asistencia de Morata, el equipo de Arne Slot respondió con velocidad y coherencia. El gol de Konaté a los 23 minutos, tras un balón parado, fue el primer empate de una noche que se volvió inolvidable para los de Liverpool.
#
# El partido se puso en movimiento a los 41 minutos, cuando Van Dijk, con un cabezazo de gran calidad tras un córner de Tsimikas, remontó el partido y puso al Liverpool en ventaja. La diferencia se amplió en el segundo tiempo, cuando Szoboszlai, a los 67, sentenció el partido con un disparo fruto de una jugada combinada que mostró la inteligencia táctica del equipo de Slot. El xG de Liverpool (1.8) superó ampliamente el de AC Milan (1.1), reflejando una superioridad en el juego de peligro y en la creación de oportunidades.
#
# El Milan, con 55% de posesión, no logró mantener el control del partido. A pesar de tener más tiros (16-12), su capacidad para convertir fue limitada. Tomori recibió una amarilla en el minuto 51, pero no fue suficiente para frenar el avance de los de Liverpool, que también recibieron una amarilla a Van Dijk en el minuto 79.
#
# Las rotaciones fueron clave: el Milan ingresó a Chukwueze, Musah y Terracciano, pero no lograron cambiar el rumbo del partido. Liverpool, por su parte, incorporó a Tsimikas, quien fue clave en el córner que dio vida al gol de Van Dijk.
#
# En un partido que marcó el inicio de una temporada de grupos intensa, el Liverpool demostró que no solo es un equipo de calidad, sino de juego constante y eficacia. Con un xG superior y una actuación coherente, el equipo de Arne Slot se posiciona como uno de los favoritos a avanzar. El Milan, aunque logró un gol, no pudo mantener el ritmo. La victoria del Liverpool es un claro mensaje: en la UCL, el fútbol no se juega solo con el gol, sino con la inteligencia, la presión y la constancia. Y esta noche, el Liverpool lo demostró.
#
# 📊 Palabras: 437

# %%
# FICHA 3 | Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha3 para aficionados que leen AS o Marca:

{ficha3}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 8 (Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 8 (Qwen3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **AC Milan 1-3 Liverpool. Goles: 3’ Pulisic (1-0), 23’ Konaté (1-1), 41’ Van Dijk (1-2), 67’ Szoboszlai (1-3)**
# *Stadio Giuseppe Meazza, Milán – 17/09/2024*
#
# El San Siro, en una noche de fuego y de fútbol de alto nivel, se convirtió en escenario de una derrota que dejó a AC Milan con la cabeza baja y al Liverpool con el corazón en la boca. En una jornada que abrió el camino a la UCL 2024/25, los de Paulo Fonseca no pudieron contener el impulso de los de Arne Slot, que se impusieron con claridad: **1-3** en un partido marcado por el dominio de la ofensiva y una superioridad estadística que se tradujo en xG de **1.8 frente a 1.1**, en favor del equipo de Liverpool.
#
# El partido comenzó con el Milan en posesión, pero fue Pulisic quien abrió el marcador al minuto 3, un gol de precisión tras una asistencia de Morata, que dejó al público en pie. Sin embargo, el equipo de Fonseca no se mantuvo en el camino. A los 23’, Konaté, con un remate de cabeza a balón parado, empató el partido, un gol que mostró la agilidad defensiva y la capacidad de reacción del Liverpool.
#
# El verdadero giro llegó al minuto 41, cuando Van Dijk, tras un córner de Tsimikas, encendió el fuego con un cabezazo que puso al equipo de Klopp en ventaja. El partido se fue al descanso con el 1-2, y el Milan, con una presión constante, no logró encontrar el equilibrio necesario.
#
# A los 67’, Szoboszlai sentenció el partido con un disparo fruto de una jugada combinada, que dejó a los milanistas sin opciones. El gol fue el más claro ejemplo de la calidad táctica y la ejecución del equipo de Slot, que dominó el partido con una posesión del 55% y una superioridad en tiros (16-12), aunque el xG de 1.8 fue clave para justificar el resultado.
#
# Las tarjetas amarillas (Tomori y Van Dijk) no marcaron el tono, pero el rendimiento de los jugadores fue clave. Szoboszlai, con su desempeño ofensivo, fue el jugador del partido, mientras que Van Dijk, con su actuación defensiva y ofensiva, fue el alma del triunfo.
#
# El Milan, aunque logró un gol, no pudo mantener el ritmo. Liverpool, por su parte, demostró que es un equipo que sabe convertir oportunidades en goles. En una fase de grupos que aún está en sus primeros pasos, el triunfo del Liverpool es una señal de que el camino hacia la final no será fácil, pero sí posible.
#
# 📊 Palabras: 417

# %% [markdown]
# CoT
# FICHA 3

# %%
# FICHA 3 | Qwen3-4b-2507 | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: AC Milan 1-3 Liverpool (San Siro, UCL 2024/25 J1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada)
3. 1T: Milan adelanta 1-0 rápido, Liverpool remonta 1-2 antes descanso, posesión 55-45 Milan, xG 1.8-1.1 Liverpool
4. 2T: Szoboszlai sentencia, Milan reacciona con Chukwueze/Musah/Terracciano pero sin efecto, Liverpool administra con Tsimikas
5. JUGADOR: Szoboszlai o Van Dijk (clave defensiva/ofensiva Liverpool)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 3 – CONFIG 9 (Qwen3-4b-2507 | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 3 – CONFIG 9 (Qwen3-4b-2507 | CoT | Sin rol | Sin restricciones)
# ================================================================================
# **LIVERPOOL DESTRUYE AL AC MILAN EN SAN SIRIO: SZOBOSSLAI Y VAN DIJK EN EL CENTRO DEL ESCENARIO**
#
# *San Siro, 14 de septiembre de 2024 – El San Siro se convirtió en escenario de fuego: un partido de fuego, de intensidad, de reloj y de gloria. Liverpool, con el alma de una leyenda, se impuso con fuerza y precisión, alzando la bandera del fútbol moderno en una victoria que no solo cambió el marcador, sino que redefinió el rumbo de la Champions League 2024/25.*
#
# **¡1-0! El primer disparo del Milán, el primer grito del San Siro!**
# A las 3 minutos, el San Siro estalló. Pulisic, con una pista de fuego, desborda la defensa y pone el primer punto en el marcador. Morata, en el asistente, se convierte en el héroe del inicio. Un gol que parece un suspiro, pero que en realidad es el grito de una noche que ya no será olvidada. Milan, con el corazón en la boca, se pone al frente. Pero el fútbol no se rinde.
#
# **¡23’! Liverpool responde con fuerza, con cabeza, con precisión!**
# El tiempo se detiene. El balón está parado. El aire se congela. Konaté, con una cabeza que parece hecha de acero, lo despeja. Un cabezazo que no solo rompe el equilibrio, sino que despierta al público. 1-1. El equipo de Klopp, que hasta entonces parecía un sueño, se levanta. El gol no es solo un punto, es una declaración: *el fútbol no se rinde ante el tiempo*.
#
# **¡41’! Van Dijk, el hombre del corredor, el hombre del córner, el hombre del cielo!**
# El córner de Tsimikas, un disparo que parece un rayo, se convierte en el punto de inflexión. Van Dijk, con una cabeza que parece salir del suelo, lo despeja. El público se levanta. El gol no es solo un resultado, es una declaración: *el fútbol no se rinde ante el tiempo*. Liverpool, con el corazón en la boca, se pone al frente. 2-1. El partido cambia de rumbo. El Milán, que creía tener el control, se ve atrapado en una red que ya no puede escapar.
#
# **¡67’! Szoboszlai, el hombre del final, el hombre del final que no se rinde!**
# El partido se vuelve una batalla de espíritu. Szoboszlai, con una combinación que parece un sueño, pone el 3-1. Un disparo que no solo rompe el marcador, sino que rompe el alma del Milán. El público se levanta. El gol no es solo un resultado, es una declaración: *el fútbol no se rinde ante el tiempo*. Liverpool, con el corazón en la boca, se pone al frente. 3-1. El partido cambia de rumbo. El Milán, que creía tener el control, se ve atrapado en una red que ya no puede escapar.
#
# **¿Quién fue el verdadero protagonista?**
# No fue solo Szoboszlai. Fue Van Dijk. El defensor que no solo defendió, sino que construyó. El hombre que con su presencia, su postura, su inteligencia, hizo que el fútbol no fuera solo un juego, sino una obra de arte. En el centro del campo, en el corazón del partido, ambos fueron los pilares que sostuvieron a Liverpool. Un equipo que no solo ganó, sino que demostró que el fútbol moderno no se mide por

# %%
# FICHA 3 | Qwen3-4b-2507 | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: AC Milan 1–3 Liverpool (San Siro, UCL 2024/25, Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada)
3. 1T: Milan adelanta 1-0 rápido (3'), Liverpool remonta 1-2 antes descanso con dos cabezazos, posesión 55-45 Milan, xG 1.8-1.1 Liverpool
4. 2T: Szoboszlai sentencia (67'), Milan reacciona con Chukwueze/Musah/Terracciano sin efecto, Liverpool administra con Tsimikas
5. JUGADOR: Szoboszlai o Van Dijk (clave ofensiva/defensiva Liverpool, debut Slot exitoso)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Fonseca/Slot
- No inventes declaraciones ni citas textuales"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 10 (Qwen3-4b-2507 | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 3 – CONFIG 10 (Qwen3-4b-2507 | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **AC MILAN 1-3 LIVERPOOL | SAN SIRO: EL FUEGO DE LIVERPOOL EN EL MÁS GRANDE**
#
# *San Siro, 14 de septiembre de 2024 – El San Siro no fue un escenario de paz. Fue un terreno de fuego. Y el fuego, esta vez, se llamaba Liverpool.*
#
# **1. RESULTADO: AC MILAN 1–3 LIVERPOOL**
# Un 1-3 que no se escribió por casualidad. Fue una victoria que rompió el hilo de la Champions. Un triunfo que puso a Liverpool en el primer lugar del grupo, mientras AC Milan, aunque adelantado, se vio arrastrado por el viento del fútbol moderno.
#
# **2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszl, (Liv, disparo combinada)**
# El primer gol fue un *ataque de fuego*. Pulisic, con un asistente de Morata, lo puso en el campo en 3’. Un gol rápido. Un gol de esperanza.
# Pero el San Siro no duró. A los 23’, Konaté, con un cabezazo de balón parado, lo volvió a abrir. Un gol de precisión, de ritmo, de *fútbol de verdad*.
# A los 41’, Van Dijk, con un cabezazo de córner de Tsimikas, lo cerró. Un gol que no fue solo defensivo. Fue una declaración.
# Y a los 67’, Szoboszlai, con un disparo combinado, lo sentenció. Un gol que no se esperaba. Un gol que marcó el final.
#
# **3. 1T: MILAN ADELANTA, LIVERPOOL REMONTA**
# Milan, con el corazón en la boca, abrió el marcador. 3’ de juego. Un gol que parecía el inicio de una historia.
# Pero Liverpool, con el ritmo de un equipo que sabe que el fútbol no se rige por el tiempo, respondió. Dos cabezazos en 20 minutos. Un primer tiempo que fue una batalla de espíritu.
# Milan, con 55% de posesión, tuvo más posesión, pero menos *xG*. 1.8 frente a 1.1. Un número que habla de calidad, no de cantidad.
# Fonseca, en su primera jornada, mostró que su equipo no se rige por el miedo. Se rige por la reacción.
#
# **4. 2T: SZOBOSSLAI SENTENCIA, MILAN NO REACTIVA**
# El segundo tiempo fue un *canto de guerra*.
# Milan intentó reaccionar. Chukwueze, Musah, Terracciano. Golpes. Intentos. Sin efecto.
# Liverpool, con Tsimikas como maestro del córner, se mantuvo firme. Control. Punto de inflexión.
# Szoboszlai, en el 67’, fue el que lo cerró. Un disparo combinado que no fue solo un gol. Fue un *acto de guerra*.
# El equipo de Slot, en su debut, no solo ganó. Se impuso.
#
# **5. JUGADOR: SZOBOSSLAI O VAN DIJK (CLAVE DE LIVERPOOL)**
# Szoboszlai, en su primera aparición en la Champions, fue el *hilo conductor* del ataque. Un jugador que no solo ataca, sino que *organiza*.
# Van Dijk, en el córner, fue el *cristal de la defensa*. Un cabezazo que no fue solo defensivo. Fue un act

# %%
# FICHA 3 | Qwen3-4b-2507 | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: AC Milan 1–3 Liverpool (Stadio Giuseppe Meazza, UEFA Champions League 2024/25, Fase de grupos – Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liverpool, cabezazo tras acción a balón parado), 41' Van Dijk (Liverpool, cabezazo a la salida de un córner de Tsimikas), 67' Szoboszlai (Liverpool, disparo tras jugada combinada)
3. 1T: Milan se adelanta muy pronto (3') con gol de Pulisic, pero Liverpool remonta antes del descanso con dos tantos de cabeza (Konaté y Van Dijk); al descanso, 1–2 para los ingleses
4. 2T: Szoboszlai marca el 1–3 en el 67', que sentencia el partido; Milan mueve el banquillo (Chukwueze, Musah, Terracciano) en busca de reacción ofensiva y Liverpool introduce a Tsimikas y jugadores de refresco para gestionar la ventaja
5. ESTADÍSTICAS: Posesión 55–45, tiros 16–12, córners 7–5, xG 1.8–1.1 a favor de Liverpool
6. MVP: Szoboszlai o Van Dijk (determinantes en la sentencia y en el dominio aéreo del Liverpool)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 11 (Qwen3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 11 (Qwen3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **AC Milan se impone en el primer partido de grupos, pero Liverpool se lleva el triunfo en el estadio Meazza**
#
# El estadio Giuseppe Meazza, en una noche de intensa competencia, albergó el primer partido de grupos de la UEFA Champions League 2024/25, donde AC Milan y Liverpool se enfrentaron en un partido marcado por el ritmo, el dominio aéreo y la eficiencia ofensiva del equipo inglés.
#
# El partido comenzó con una rápida acción de Milan, que en el minuto 3 logró el primer gol gracias a un asistencia de Morata, quien puso en movimiento a Pulisic para marcar. El gol, aunque temprano, fue el único de la primera mitad para los rojinegros. Sin embargo, Liverpool respondió con fuerza. En el minuto 23, Konaté aprovechó un balón parado para marcar un cabezazo que puso el 1–1. A los 41, Van Dijk completó la reacción con otro cabezazo tras una jugada de córner de Tsimikas, consolidando el 2–1 para los ingleses al descanso.
#
# En el segundo tiempo, Liverpool se mantuvo firme. A los 67, Szoboszlai marcó el tercer gol tras una jugada combinada que terminó en un disparo directo, ampliando la ventaja a 3–1. Este gol sentenció el partido, que se cerró con una clara superioridad de los de Anfield en el control del juego.
#
# Las estadísticas reflejan la diferencia de calidad: Liverpool dominó con 55 por ciento de posesión frente a los 45 del Milan, con 16 tiros contra 12 del equipo italiano. En cuanto al valor esperado (xG), Liverpool se posicionó con 1.8 frente a los 1.1 del Milan, lo que indica una mayor eficiencia en las oportunidades generadas.
#
# Aunque Milan intentó reaccionar moviendo al banquillo con Chukwueze, Musah y Terracciano, el partido ya estaba decidido. Liverpool, por su parte, introdujo a Tsimikas y jugadores de refresco para gestionar el ritmo y mantener la presión.
#
# En cuanto al jugador más destacado, Szoboszl, o Van Dijk, ambos fueron clave: Szoboszlai con el gol decisivo y Van Dijk con su dominio aéreo y la reacción en el área. Ambos fueron determinantes en la sentencia del partido.
#
# El resultado final, 1–3, pone a Liverpool en una posición sólida en la tabla de grupos, mientras que AC Milan se enfrenta a una nueva fase con una derrota en casa.
#
# 📊 Palabras: 375

# %%
# FICHA 3 | Qwen3-4b-2507 | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: AC Milan 1–3 Liverpool (Stadio Giuseppe Meazza, Champions League 2024/25 – Fase de grupos, Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liverpool, cabezazo tras acción a balón parado), 41' Van Dijk (Liverpool, cabezazo a la salida de un córner de Tsimikas), 67' Szoboszlai (Liverpool, disparo tras jugada combinada)
3. 1T: Milan se adelanta muy pronto (3') con gol de Pulisic, pero el Liverpool remonta antes del descanso con dos tantos de cabeza (Konaté y Van Dijk); al descanso, 1–2 para los ingleses, con ligera ventaja de posesión para el Milan (55–45)
4. 2T: Szoboszlai firma el 1–3 en el 67' y sentencia el duelo; Milan introduce a Chukwueze, Musah y Terracciano buscando reacción ofensiva, mientras el Liverpool recurre a Tsimikas y jugadores de refresco para gestionar la ventaja
5. ESTADÍSTICAS: Posesión 55–45, tiros 16–12, córners 7–5, xG 1.8–1.1 a favor del Liverpool
6. MVP: Szoboszlai o Van Dijk (determinantes en la sentencia del marcador y en el dominio aéreo del Liverpool)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4b-2507",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 12 (Qwen3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 12 (Qwen3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **LIVERPOOL DEBUTA CON FUEGO: 3-1 EN MILAN, SZOBOSSLAI SIENTE EL FINAL**
#
# El estadio Giuseppe Meazza se convirtió en escenario de una victoria que no se esperaba: Liverpool, en su debut en la Champions League 2024/25, se impuso 3-1 ante AC Milan en una jornada que dejó claro que el equipo de Klopp no solo está listo, sino que domina el ritmo del grupo.
#
# El partido comenzó con el fuego de Pulisic, quien en el 3’ marcó el primer gol del encuentro tras una acción de Morata, que puso al Milan con una ventaja inmediata. Sin embargo, el Liverpool respondió con fuerza. En el 23’, Konaté aprovechó un balón parado para marcar con un cabezazo que puso el 1-1. Apenas cinco minutos después, el 41’, Van Dijk volvió a subir con un cabezazo a la salida de un córner de Tsimikas, consolidando el 2-1.
#
# Al descanso, el marcador era 1-2, con el Milan dominando ligeramente la posesión (55–45), pero el Liverpool mostraba superioridad en el control del juego y en la presión defensiva. En el segundo tiempo, el gol de Szoboszlai en el 67’ fue el que sentenció el partido: tras una jugada combinada, el húngaro disparó con precisión y puso el 3-1.
#
# Las estadísticas reflejan la superioridad del Liverpool: 55% de posesión, 16 tiros frente a 12 del Milan, 7 córners contra 5, y un xG de 1.8 frente a 1.1. El equipo inglés, aunque no tuvo la máxima intensidad en el primer tiempo, mostró una cohesión defensiva y ofensiva que se tradujo en un marcador final que no se discutía.
#
# En el piso de los valores, Szoboszlai y Van Dijk fueron los más determinantes: el primero con el gol decisivo, el segundo con el dominio aéreo y la presión constante en el área.
#
# Milan, aunque adelantó, no logró reaccionar. Chukwueze, Musah y Terracciano entraron para buscar una salida, pero el Liverpool, con Tsimikas y jugadores de refresco, mantuvo el control.
#
# El resultado deja claro que Liverpool no solo está en el grupo, sino que está en el camino correcto. Un triunfo que, en el contexto de la fase de grupos, puede ser clave para el futuro de la campaña.
#
# 📊 Palabras: 360

# %% [markdown]
# FICHA 4
# ZERO SHOT

# %%
# FICHA 4 | Qwen 3-4b-2507 | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha4 = """ID_PARTIDO: UCL_2024_J1_PSG_ARS
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1 (League Phase)
Fecha: 01/10/2024
Hora: 19:00 hora local (Londres)
Estadio: Emirates Stadium, Londres
Asistencia: 60,103 espectadores
Árbitro: Slavko Vinčić (Eslovenia)
Equipo 1: Arsenal
Equipo 2: Paris Saint-Germain
Entrenador Arsenal: Mikel Arteta
Entrenador Paris Saint-Germain: Luis Enrique
Alineación Arsenal:
Raya; White, Saliba, Kiwior, Zinchenko; Ødegaard, Rice, Havertz; Saka, Gabriel Jesus, Martinelli
Alineación Paris Saint-Germain:
Donnarumma; Hakimi, Marquinhos, Pacho, Nuno Mendes; Vitinha, Zaïre-Emery, Fabián Ruiz; Dembélé, Kvaratskhelia, Barcola
Resultado final: Arsenal 2 – 0 Paris Saint-Germain
Resultado al descanso: Arsenal 2 – 0 Paris Saint-Germain
Goles:
20' Havertz (Arsenal) 1–0, remate de cabeza tras centro de Trossard
35' Saka (Arsenal) 2–0, lanzamiento de falta lateral mal gestionada por Donnarumma
Tarjetas amarillas Arsenal:
No disponibles
Tarjetas amarillas Paris Saint-Germain:
No disponibles
Tarjetas rojas:
Ninguna
Sustituciones Arsenal:
64' Mikel Merino entra para reforzar el centro del campo
74' Trossard entra por Gabriel Jesus
Myles Lewis-Skelly entra por Saka en el tramo final
Sustituciones Paris Saint-Germain:
Fabián Ruiz entra en la segunda parte
Otros cambios ofensivos (como Kolo Muani) en el tramo final para buscar reacción
Eventos registrados:
Arsenal se adelanta con un cabezazo de Havertz tras centro de Trossard
Saka firma el 2–0 con una falta lateral mal defendida por Donnarumma
Debut de Mikel Merino con el Arsenal, que entra en la segunda parte para dar solidez al medio campo
Estadísticas totales:
Posesión (%): 58 – 42 a favor del Arsenal
Tiros: 14 – 11
Córners: 6 – 5
Estadísticas avanzadas:
xG: 1.4 – 1.2 a favor del Arsenal
Jugador del partido: Kai Havertz"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha4}"

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 1 (Qwen 3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 4 – CONFIG 1 (Qwen 3-4b-2507 | Zero-shot | Sin rol | Sin restricciones)
# ================================================================================
# **CRÓNICA DEPARTIDO: ARSENAL 2 – 0 PARIS SAINT-GERMAIN | UEFA CHAMPIONS LEAGUE – FASE DE GRUPOS, JORNADA 1**
# *Por [Tu Nombre], especialista en fútbol para aficionados de AS y Marca*
# **Fecha: 01 de octubre de 2024 | Estadio: Emirates Stadium, Londres | 19:00 h (hora local)**
#
# ---
#
# **Londres, 1 de octubre de 2024** – El Emirates Stadium se convirtió en escenario de una de las primeras victorias de la temporada en la **Fase de Grupos de la UEFA Champions League 2024/2025**, con **Arsenal** que se impuso con claridad ante **Paris Saint-Germain**, por **2-0**, en un partido que dejó claro que el equipo de Mikel Arteta está en plena forma y con una actitud de dominio que no se ve en los enfrentamientos de la máxima competición europea.
#
# El partido, que contó con una asistencia récord de **60.103 espectadores**, fue un claro ejemplo de cómo el fútbol de alto nivel puede ser también de alto impacto emocional. Sin embargo, en este caso, el **Arsenal** fue el que dominó el partido desde el primer minuto, y lo hizo con inteligencia, precisión y una ofensiva que no se detuvo ni ante el mejor equipo del mundo en el fútbol francés.
#
# ---
#
# ### **El inicio: un cabezazo que puso el tono**
#
# A los **20 minutos**, el partido ya tenía su rumbo. **Kai Havertz**, en una de sus mejores actuaciones de la temporada, puso el primer gol tras un centro perfecto de **Trossard**. El cabezazo fue fruto de una combinación de velocidad y precisión, y fue el primer gol de un partido que se convirtió en una demostración de la capacidad del Arsenal para crear y convertir oportunidades.
#
# El público se levantó en un silencio casi reverente. No fue solo un gol, fue un **símbolo**: el regreso de Havertz al centro del ataque, después de una temporada de dudas, y su capacidad para convertirse en un referente ofensivo. El ángulo del gol, el control del balón y la calidad del centro fueron elementos que hicieron que el público se sintiera parte de una historia que ya se había escrito en el fútbol moderno.
#
# ---
#
# ### **El segundo gol: una falta lateral que se convirtió en oro**
#
# A los **35 minutos**, el partido se puso definitivamente en el dominio del Arsenal. **Saka**, en una de sus mejores actuaciones de la temporada, aprovechó una **falta lateral mal gestionada por Donnarumma** para marcar el segundo gol. El lanzamiento fue directo, de fuera del área, y el balón fue desviado por el suelo y entró en la red. Fue un gol de **precisión y agilidad**, y un claro ejemplo de cómo el Arsenal puede convertir errores del rival en puntos.
#
# El árbitro, **Slavko Vinčić** (Eslovenia), no tomó ninguna acción, y el partido se mantuvo sin incidentes. No hubo tarjetas amarillas ni rojas, lo que refleja una **buena gestión del juego** por ambas partes, aunque el dominio del Arsenal fue evidente.
#
# ---
#
# ### **El centro del campo: Mikel Merino, el nuevo pilar**
#
# A los **64 minutos**, el Arsenal reforzó su medio campo con la entrada de **Mikel Merino**, que debutó en el equipo. El joven centrocampista, conocido por su capacidad de control y distribución, fue clave para mantener la presión en el centro del campo. Su presencia fue un claro indicio de que Arteta está trabajando en una **estructura táctica más equilibrada**, con más

# %%
# FICHA 4 | Qwen 3-4b-2507 | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha4}""".format(ficha4=ficha4)

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 2 (Qwen 3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 4 – CONFIG 2 (Qwen 3-4b-2507 | Zero-shot | CON ROL | Sin restricciones)
# ================================================================================
# **ARSenal 2-0 Paris Saint-Germain: El triunfo de los Gunners en el Emirates, una victoria que pone en marcha una nueva era en la Champions League 2024/25**
#
# *Por [Tu Nombre], periodista deportivo | AS – 01 de octubre de 2024*
#
# Londres, 1 de octubre de 2024 — El Emirates Stadium, en pleno fuego de la temporada, no solo albergó un partido de fútbol, sino una declaración de intenciones. Arsenal, con el rostro de un equipo que ha dejado de ser solo un "candidato" y se convierte en un *frente de guerra* en la UEFA Champions League, se impuso con claridad sobre Paris Saint-Germain, 2-0, en una jornada que marcó el inicio de una nueva fase en el grupo de la máxima competición europea.
#
# Este fue el primer partido de la fase de grupos de la Champions League 2024/25, y el resultado no fue solo un triunfo, fue una **declaración de poder**. Un Arsenal que, tras una temporada de transición, ha encontrado su ritmo, su identidad y, sobre todo, su **fuerza ofensiva** en el corazón del campo.
#
# ---
#
# ### **El gol de Havertz: un cabezazo que rompe el muro de París**
#
# A los 20 minutos, el partido ya tenía su rumbo. Un centro preciso de Trossard, que desbordó la defensa parisina, fue recibido por Kai Havertz, que con un cabezazo de gran precisión y potencia, puso el primer gol en el Emirates. No fue un gol de estilo, sino un gol de **fuerza, de confianza y de madurez**. Havertz, que ha sido el centro de la ofensiva del Arsenal desde que regresó al equipo, mostró una vez más que no es solo un delantero, sino un **líder en el ataque**.
#
# El público, que se levantó en un silencio casi sagrado, no solo celebró el gol, sino que lo vio como un símbolo: **el regreso del Arsenal como equipo de elite en Europa**.
#
# ---
#
# ### **Saka, el genio del lateral: un gol que no debería haberse producido**
#
# A los 35 minutos, el segundo gol fue aún más sorprendente. Saka, en una situación de falta lateral, aprovechó una **mal gestión defensiva de Donnarumma**, que se adelantó demasiado en el área y dejó la línea de defensa abierta. Saka, con una ejecución de precisión y velocidad, lanzó el balón directamente al área, y el balón fue recibido por el área, donde fue desviado por un jugador de la defensa parisina, pero **el balón cayó en el área y fue golpeado por Saka**, quien lo puso en el fondo de la portería.
#
# No fue un gol de estilo, pero fue un gol de **inteligencia táctica y de oportunidad**. Un gol que, aunque no fue un disparo directo, fue el resultado de una **mala defensa y una gran capacidad de reacción** del jugador más joven del equipo.
#
# ---
#
# ### **El Arsenal, dominante en posesión y en el control del juego**
#
# Con una posesión del 58%, el Arsenal controló el partido desde el primer minuto. Aunque no fue un partido de tanta intensidad física, fue un partido de **control, de precisión y de ritmo**. Los 14 tiros del Arsenal frente a los 11 del PSG, y un xG de 1.4 frente a 1.2, indican que el equipo no solo tuvo más oportunidades, sino que **las aprovechó con inteligencia**.
#
# El centro del campo, con la entrada de **Mikel Merino** a los 64 minutos, fue clave. El joven defensor, que debutó en el Arsenal, se conv

# %%
# FICHA 4 | Qwen 3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha4}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 4 – CONFIG 3 (Qwen 3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 3 (Qwen 3-4b-2507 | Zero-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Arsenal vence a PSG en el Emirates: un dominio técnico y un gol de Havertz que deja sin respuesta al PSG**
#
# El Emirates Stadium, en pleno corazón de Londres, se convirtió en escenario de una victoria que dejó sin respuesta al Paris Saint-Germain en la primera jornada de la fase de grupos de la UEFA Champions League 2024/2025. Arsenal, con una actuación clara y controlada, se impuso 2-0 ante los parisinos, consolidando su posición en la tabla de grupos con un primer triunfo que refleja la calidad de su juego en el fútbol europeo.
#
# El partido comenzó con el Arsenal en posesión, y desde el primer minuto mostró su superioridad táctica. A los 20 minutos, el cabezazo de Kai Havertz tras un centro de Trossard fue el primer gol del encuentro, un disparo preciso y potente que dejó a los parisinos sin opciones. El gol, que valió 1-0, fue un claro ejemplo de la efectividad del ataque arsenalista, especialmente en el área. El xG de Arsenal en ese momento ascendía a 1.4, frente a los 1.2 del PSG, lo que ya señalaba una ventaja estadística clara.
#
# A los 35 minutos, el segundo gol llegó por un error defensivo: Saka aprovechó una falta lateral mal gestionada por Donnarumma, y con un lanzamiento de fuera de juego, puso el 2-0. El gol fue un claro testimonio de la agilidad y la precisión del ataque de los Gunners, que no solo dominó el balón (58% de posesión), sino que también generó más oportunidades (14 tiros frente a 11 del PSG). El xG final de Arsenal, de 1.4, fue una muestra de que su juego era más efectivo, aunque el PSG no se rindió.
#
# Durante todo el partido, no hubo tarjetas amarillas, lo que evidencia el control del partido y la falta de tensión en el campo. El Arsenal, con una línea defensiva sólida, mantuvo la presión sin cometer errores. En el segundo tiempo, se produjeron dos sustituciones clave: Mikel Merino entró a los 64 minutos para reforzar el centro del campo, y Trossard reemplazó a Gabriel Jesus a los 74, mientras que Myles Lewis-Skelly sustituyó a Saka en el final. El PSG, por su parte, cambió a Fabián Ruiz y buscó reacción en el tramo final, aunque sin lograr cambiar el rumbo del partido.
#
# El jugador del partido fue sin duda Kai Havertz, quien no solo marcó el primer gol, sino que también fue el motor del ataque arsenalista. Su capacidad para conectar con compañeros y su precisión en el área fueron clave para el resultado.
#
# En resumen, Arsenal demostró que puede competir con los mejores del mundo, y esta victoria en el Emirates es un punto de inflexión en su campaña en la Champions. Con un xG superior y una actuación coherente, los Gunners se posicionan como uno de los principales candidatos a la fase de grupos.
#
# 📊 Palabras: 475

# %%
# FICHA 4 | Qwen 3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha4}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 4 (Qwen 3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 4 (Qwen 3-4b-2507 | Zero-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **Arsenal v Paris Saint-Germain: El triunfo de la disciplina en el Emirates**
#
# El Emirates Stadium, albergó este domingo un partido de Champions League que no olvidará fácilmente: Arsenal, con una actuación de fútbol puro y control absoluto, se impuso 2-0 ante Paris Saint-Germain en una jornada que marcó el tono de la fase de grupos. El resultado, aunque no sorprendió a los aficionados, fue una victoria de precisión, de inteligencia táctica y de una ejecución que dejó sin palabras al equipo francés.
#
# El partido comenzó con el Arsenal en posesión, y desde el primer minuto mostró su capacidad para dominar el juego. A los 20 minutos, Kai Havertz puso el primer gol con un cabezazo de cabeza tras un centro perfecto de Trossard. Fue un gol que no solo marcó el inicio del partido, sino que también sentó las bases del dominio del equipo londinense. El xG de Arsenal en ese momento fue de 1.4 frente a 1.2 del PSG, una ventaja que se mantuvo constante a lo largo del encuentro.
#
# A los 35 minutos, el segundo gol llegó por un error defensivo: Saka aprovechó una falta lateral mal gestionada por Donnarumma para marcar el 2-0. El gol fue un ejemplo de la agilidad y la capacidad de reacción del Arsenal, que no solo controló el balón, sino que también supo convertir las oportunidades. La posesión (58% a 42%) y los tiros (14 a 11) reflejaban una superioridad clara, aunque el PSG no se rindió.
#
# Durante el partido, el Arsenal no recibió tarjetas amarillas, mientras que el PSG tampoco. La ausencia de sanciones fue un reflejo de la disciplina táctica de ambos equipos, pero fue el control del juego el que decidió el resultado. En el segundo tiempo, Mikel Merino debutó en el Arsenal, entrando a los 64 minutos para reforzar el centro del campo. Su presencia fue clave para mantener la cohesión defensiva y ofensiva. A los 74 minutos, Trossard entró por Gabriel Jesus, y en el tramo final, Myles Lewis-Skelly sustituyó a Saka, aunque el partido ya había perdido su dinámica ofensiva.
#
# El jugador del partido fue sin duda Kai Havertz, cuyo desempeño fue clave tanto en el gol como en la presión constante en el área. Su capacidad para conectar con compañeros y su precisión en el área fueron el hilo conductor del partido.
#
# En un escenario donde los grandes equipos se enfrentan, este triunfo de Arsenal no fue solo un resultado, sino una declaración: el fútbol de calidad, el control y la inteligencia táctica pueden vencer incluso a los más grandes. Y en este caso, el Arsenal lo demostró con claridad.
#
# 📊 Palabras: 435

# %% [markdown]
# FEW SHOT
# Ficha 4

# %%
# FICHA 4 | Qwen 3-4b-2507 | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Qwen NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha4}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 5 (Qwen 3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 4 – CONFIG 5 (Qwen 3-4b-2507 | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ================================================================================
# Arsenal se impuso 2–0 ante Paris Saint-Germain en el Emirates Stadium, en una jornada clave de la fase de grupos de la UEFA Champions League 2024/2025. El partido, disputado el 1 de octubre de 2024 a las 19:00 hora local, fue decidido por dos goles de Arsenal, ambos en el primer tiempo. El primero llegó al minuto 20 con un cabezazo de Kai Havertz tras un centro de Trossard, mientras que el segundo fue obra de Saka, quien aprovechó una falta lateral mal gestionada por Donnarumma para convertirse en el autor del 2–0 al minuto 35.
#
# El equipo de Mikel Arteta mantuvo el control de la posesión, con un 58 por ciento frente a los 42 del Paris Saint-Germain, y dominó también en tiros (14 contra 11) y en el número de corners (6 a 5). Las estadísticas avanzadas reflejan una superioridad clara, con un xG de 1.4 frente a los 1.2 del equipo francés.
#
# Durante el partido, el Arsenal no recibió tarjetas amarillas, ni por parte de sus jugadores ni de los de Paris Saint-Germain. En el tramo final, se produjeron dos sustituciones: Mikel Merino entró en el minuto 64 para reforzar el centro del campo, debutando así con el equipo, mientras que Trossard reemplazó a Gabriel Jesus en el minuto 74. Myles Lewis-Skelly entró en el último tramo por Saka. Paris Saint-Germain también cambió en la segunda mitad, con la entrada de Fabián Ruiz, y posteriormente se incorporó Kolo Muani para buscar una reacción ofensiva.
#
# El partido se cerró con una victoria clara para los de Londres, que se mantienen en el primer puesto de la fase de grupos. Kai Havertz fue el jugador del partido por su doble actuación en el marcador.

# %%
# FICHA 4 | Qwen 3-4b-2507 | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha4 para aficionados que leen AS o Marca:
{ficha4}"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 6 (Qwen 3-4b-2507 | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 4 – CONFIG 6 (Qwen 3-4b-2507 | Few-shot | CON ROL | Sin restricciones)
# ================================================================================
# **Arsenal 2-0 Paris Saint-Germain. Goles: 20’ Havertz (1-0), 35’ Saka (2-0)**
# *UEFA Champions League – Fase de grupos, Jornada 1 | Emirates Stadium, Londres | 01/10/2024*
#
# El Arsenal se impuso con claridad en el Emirates Stadium, derrotando al Paris Saint-Germain por 2-0 en una jornada que abrió la temporada de grupos de la Champions League con un claro dominio del equipo de Mikel Arteta. Un partido sin drama, sin tarjetas ni reacciones ofensivas, pero con una clara superioridad táctica y un rendimiento que deja sin palabras al equipo francés.
#
# El primer gol llegó al minuto 20, cuando Kai Havertz aprovechó un centro preciso de Trossard para encarar a Donnarumma y dejarle sin salida con un cabezazo que dejó al público en pie. Fue un gol de precisión, de juego, de un jugador que está en su mejor momento: Havertz, con su velocidad, su inteligencia y su capacidad para convertir, se convierte en el jugador del partido, y no solo por el gol, sino por su presencia constante en el centro del campo.
#
# El segundo tanto, al minuto 35, fue aún más sorprendente: Saka, en un lanzamiento de falta lateral, aprovechó una mala gestión defensiva del portero parisino, que no logró desviar el balón. El disparo fue directo, sin defensa, y el balón entró con fuerza. Fue un gol de calidad, de juego, de un jugador que ha estado en plena forma desde que regresa al equipo tras una temporada de recuperación.
#
# El Arsenal dominó el partido con una posesión del 58%, y aunque el xG (1.4 frente a 1.2) no fue un abismo, sí fue suficiente para justificar el resultado. El equipo de Arteta controló el ritmo, mantuvo la presión y no permitió que el PSG se organice en el medio campo. Los 6 corners del Arsenal, aunque no fueron decisivos, mostraron una presión constante en el área.
#
# En el segundo tiempo, el Arsenal reforzó su centro con la entrada de Mikel Merino, que debutó en el equipo y mostró solidez en el medio campo. Trossard también entró en el tramo final, reforzando la línea de ataque. En el PSG, el cambio de Fabián Ruiz en la segunda mitad y el ingreso de Kolo Muani al final fueron intentos de reacción, pero no fueron suficientes para cambiar el rumbo del partido.
#
# No hubo tarjetas, ni rojas, ni amarillas, lo que refleja un partido controlado, sin tensión, pero con una claridad táctica que deja al PSG sin respuesta. El PSG, con su sistema de juego más ofensivo, no logró encontrar el equilibrio necesario para romper el dominio del Arsenal.
#
# **Conclusión:**
# El Arsenal se lleva el triunfo con orgullo, y el partido deja claro que el equipo de Arteta está en una fase de consolidación. Con un gol de Havertz y otro de Saka, el equipo británico demuestra que puede competir con los mejores del mundo. El PSG, por su parte, tendrá que reorganizar su juego para no caer en el mismo patrón de desgaste que vio en esta primera jornada.
#
# **Jugador del partido: Kai Havertz**
# El ariete alemán, con su capacidad de gol y su presencia en el campo, fue el motor del partido. Un jugador que no solo marcó, sino que también controló el ritmo del juego. Su desempeño es un claro ejemplo de cómo un jugador de calidad puede marcar la diferencia en un partido de grupos.
#
# *El camino de la Champions continúa… y el Arsenal ya está en el camino correcto.*
#
# — *AS / Marca*

# %%
# FICHA 4 | Qwen 3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha4 para aficionados al fútbol que leen AS o Marca:

{ficha4}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 7 (Qwen 3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 7 (Qwen 3-4b-2507 | Few-shot | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Arsenal 2-0 PSG: El triunfo que pone en marcha la campaña de Arteta**
#
# El Emirates Stadium se convirtió en escenario de una victoria que puso de manifiesto la intensidad y la precisión del Arsenal en la primera jornada de la fase de grupos de la UEFA Champions League. Con un 2-0 frente al Paris Saint-Germain, los Gunners no solo se impusieron, sino que lo hicieron con claridad, dominando el partido con una posesión del 58% y un xG de 1.4 frente al 1.2 del PSG.
#
# El primer gol, a los 20 minutos, fue un cabezazo de Kai Havertz tras un centro de Trossard. Un gol que no solo marcó el inicio del partido, sino que también mostró la eficacia del ataque arsnalista, que se movió con coherencia y velocidad. El segundo, a los 35, fue obra de Saka, quien aprovechó una falta lateral mal gestionada por Donnarumma. El lanzamiento fue directo al área, y el jugador de 21 años no dudó en convertirlo, consolidando el 2-0 y dejando al PSG sin opciones ofensivas.
#
# Aunque el PSG intentó reaccionar, especialmente en el segundo tiempo, con cambios como el ingreso de Fabián Ruiz y Kolo Muani, no lograron romper el orden defensivo del Arsenal. La defensa, liderada por Saliba y Kiwior, fue impenetrable, y el medio campo, con la entrada de Mikel Merino a los 64, ganó solidez y control. El debut de Merino fue clave para reforzar el centro del campo, y su presencia fue un factor determinante en la estabilidad del equipo.
#
# Las estadísticas hablan claro: el Arsenal tuvo más posesión, más tiros (14 frente a 11) y un xG superior, lo que refleja una superioridad técnica y táctica. El partido fue sin tarjetas, lo que evidencia la disciplina de ambos equipos, aunque el dominio fue claramente del conjunto de Mikel Arteta.
#
# En un partido que no tuvo drama, pero sí profundidad, el Arsenal demostró que puede competir con los mejores del mundo. Havertz, con su gol y su juego en el área, fue el jugador del partido, mostrando una combinación de fuerza y inteligencia que pone a los Gunners como candidatos a una buena campaña en la UCL.
#
# Este triunfo no es solo un resultado, es una declaración: el Arsenal está listo para enfrentar a los grandes, y el camino hacia la final de la Champions está más cerca de lo que parecía.
#
# 📊 Palabras: 394

# %%
# FICHA 4 | Qwen 3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha4 para aficionados que leen AS o Marca:

{ficha4}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 8 (Qwen 3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 8 (Qwen 3-4b-2507 | Few-shot | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **Arsenal 2-0 PSG: El triunfo que abre la UCL con fuerza y precisión**
#
# El Emirates Stadium se encendió con el sonido de los gritos de los aficionados, pero no fue el fuego de la batalla, sino el silencio de la superioridad técnica lo que marcó el partido. Arsenal, con una actuación clara y controlada, derrotó 2-0 al Paris Saint-Germain en la primera jornada de la fase de grupos de la UEFA Champions League, mostrando una fórmula de juego que combina velocidad, precisión y disciplina.
#
# A los 20 minutos, el partido cambió de rumbo: Kai Havertz, con un cabezazo de primera, aprovechó un centro perfecto de Trossard y puso el 1-0. El gol fue un claro ejemplo de la efectividad del ataque arsnalista, con un xG de 1.4 frente al 1.2 del PSG, que se tradujo en una ventaja clara desde el primer minuto. A los 35, Saka amplió la ventaja con un lanzamiento de falta lateral que Donnarumma mal gestionó, un error que se convirtió en el segundo gol del partido. El xG de Arsenal se mantuvo en 1.4, mientras que el PSG apenas logró 1.2, una diferencia que refleja la superioridad en oportunidades y en posesión (58% a 42%).
#
# Durante todo el partido, el Arsenal dominó el juego, con 14 tiros frente a 11 del PSG, y 6 corners contra 5. La presión constante en el área y la capacidad de generar peligro desde el centro de la cancha fueron clave. Mikel Merino, en su debut con el equipo, entró a los 64 minutos para reforzar el centro del campo, y aunque no marcó, su presencia fue un síntoma de la estrategia de Arteta: profundidad, control y coherencia.
#
# El PSG, bajo el mando de Luis Enrique, intentó reaccionar con cambios ofensivos, como el ingreso de Fabián Ruiz en la segunda mitad y el regreso de Kolo Muani al final, pero no lograron romper el orden defensivo del Arsenal. Sin tarjetas amarillas ni rojas, el partido fue técnico y controlado, sin grandes desequilibrios.
#
# En un momento clave de la UCL, Arsenal se posiciona como uno de los principales candidatos al liderato del grupo. Con un xG superior y una actuación coherente, el equipo de Arteta demuestra que el fútbol moderno no depende solo de estrellas, sino de la ejecución constante. Havertz, con su gol y su presencia en el ataque, se convierte en el jugador del partido. El triunfo no es solo un punto, es una declaración: el Arsenal, en su casa, domina con inteligencia y disciplina.
#
# 📊 Palabras: 417

# %% [markdown]
# CoT
# Ficha 4

# %%
# FICHA 4 | Qwen 3-4b-2507 | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Arsenal 2-0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25 J1)
2. GOLES: 20' Havertz (Arsenal, cabeza tras centro Trossard), 35' Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal domina con 2-0 al descanso, posesión 58-42, control total ante PSG estelar
4. 2T: Arsenal administra ventaja con entrada de Merino (debut), PSG mueve banquillo (Fabián Ruiz, Kolo Muani) sin reacción
5. JUGADOR: Kai Havertz (gol clave de cabeza, liderazgo ofensivo)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 4 – CONFIG 9 (Qwen 3-4b-2507 | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 4 – CONFIG 9 (Qwen 3-4b-2507 | CoT | Sin rol | Sin restricciones)
# ================================================================================
# **ARSenal vence a PSG en el Emirates: Havertz domina, Saka pone el punto final**
#
# **EMIRATES STADIUM – 20 DE OCTUBRE DE 2024**
# *Un triunfo que no se discute: Arsenal se impone con fuerza, claridad y precisión ante el PSG en una de las mejores actuaciones de la temporada en la Liga de Campeones.*
#
# **¡2-0!** El Emirates se convierte en escenario de una victoria que deja sin aliento al PSG. Arsenal, con una ofensiva impecable y un control absoluto del partido, se lleva el triunfo por dos goles, con el primer gol que pone el tono y el segundo que cierra el partido como una declaración de intenciones.
#
# **20' – Havertz cabecea el primer gol**
# El partido comienza con el fuego de Arsenal. Trossard pone en movimiento, el balón llega al área y **Kai Havertz**, en una posición clave, cabecea con precisión y fuerza. No es un gol de poca importancia: es un gol de liderazgo, de inteligencia táctica, de un jugador que domina el juego desde el centro del campo. El público se levanta, el equipo se mueve, y el primer gol es una señal de que el Arsenal no solo juega, sino que domina.
#
# **35' – Saka pone el punto final**
# El segundo gol llega en el segundo cuarto, en un momento clave. Saka, con una entrada de izquierda, se encuentra frente a Donnarumma, quien mal gestiona una falta lateral. El balón cae en el área y Saka, con una ejecución rápida y precisa, pone el balón en el área. El gol no es solo un resultado, es una demostración de que Arsenal domina el juego en los momentos decisivos. El público se vuelve inquieto, el partido cambia de rumbo.
#
# **Primera mitad: Arsenal domina con 58% de posesión**
# La primera mitad es una obra maestra de dominio. Arsenal controla el partido con una posesión que se sitúa en el 58%, frente a los 42% del PSG. El equipo de Mikel Arteta no solo tiene más balones, sino que los maneja con inteligencia, con ritmo y con una presión constante. El PSG, aunque estelar, no encuentra la forma de responder. Los primeros 45 minutos son una lección de cómo el control del juego puede convertirse en victoria.
#
# **Segunda mitad: Merino debut, PSG sin reacción**
# A la mitad del partido, Arsenal introduce a **Merino**, en su debut oficial, y el cambio es inmediato. El joven defensor se integra con naturalidad, ayuda a mantener la línea defensiva y a mantener el ritmo ofensivo. El PSG, por su parte, cambia al banquillo: Fabián Ruiz y Kolo Muani entran, pero no logran romper el flujo del Arsenal. El equipo francés se mueve, pero no encuentra la forma de responder. La ventaja se mantiene, y el partido se vuelve una cuestión de control, no de gol.
#
# **Havertz: el alma del partido**
# **Kai Havertz** no solo marca el gol, sino que es el corazón del ataque. Su liderazgo ofensivo, su capacidad para encontrar espacios y su precisión en el área lo convierten en el jugador clave del partido. No es solo un goleador, es un referente. Su actuación es un ejemplo de cómo un jugador puede definir el rumbo de un partido.
#
# **Conclusión: Arsenal se impone con fuerza, PSG sin respuesta**
# Arsenal vence 2-0 en el Emirates, con una actuación que demuestra su superioridad táctica, su control del juego y su capacidad para mantener la ventaja. El partido no es solo un triunfo, es una declaración: el Arsenal está en su mejor momento, y el PSG, aunque estelar

# %%
# FICHA 4 | Qwen 3-4b-2507 | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25, Jornada 1)
2. GOLES: 20' Havertz (Arsenal, cabezazo tras centro Trossard), 35' Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal domina con 2-0 al descanso, posesión 58-42, control total ante PSG estelar con Kvaratskhelia/Dembélé
4. 2T: Arsenal administra con debut Merino (64'), PSG reacciona con Fabián Ruiz/Kolo Muani sin puntería, Emirates festeja
5. JUGADOR: Kai Havertz (gol decisivo de cabeza, liderazgo ofensivo, clave en Arteta)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Arteta/Luis Enrique
- No inventes declaraciones ni citas textuales"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 10 (Qwen 3-4b-2507 | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 4 – CONFIG 10 (Qwen 3-4b-2507 | CoT | CON ROL | Sin restricciones)
# ================================================================================
# **ARSenal vence a PSG en el Emirates: el triunfo que rompe el hielo en la Champions**
#
# *Emirates Stadium, 20 de septiembre de 2024 – 2-0. Arsenal se alza con el primer paso en la Champions 2024/25.*
#
# El Emirates no fue solo un estadio. Fue un templo. Un lugar donde el fútbol se convierte en fuego. Y hoy, el fuego se encendió.
#
# **1. RESULTADO: Arsenal 2–0 Paris Saint-Germain**
# El primer partido de la Champions 2024/25 se escribió en fuego y fuego. Arsenal, con el corazón en la garganta, derrotó a Paris Saint-Germain por 2-0. No fue un simple triunfo. Fue una declaración. Una victoria que pone al Arsenal en el centro del escenario europeo.
#
# **2. GOLES: Havertz (20'), Saka (35')**
# A los 20 minutos, el mundo se detuvo. Havertz, con un cabezazo que partió de un centro perfecto de Trossard, puso el primer punto. Un gol de fuego, de precisión, de fuerza. Luego, a los 35, Saka. Una falta lateral mal gestionada por Donnarumma. Un error. Un momento. Y un gol que encendió el alma del equipo.
#
# **3. 1T: Arsenal domina con 2-0 al descanso**
# Al descanso, el Arsenal ya no era un equipo. Era una fuerza. Con 58 por ciento de posesión, dominó todo. Controló el ritmo, el espacio, el juego. Ante un PSG estelar, con Kvaratskhelia y Dembélé en plena forma, el Arsenal no se rindió. Fue claro, fue rápido, fue imparable.
#
# **4. 2T: Arsenal administra, PSG reacciona, pero no llega**
# La segunda mitad fue más clara. Arsenal, con el debut de Merino a los 64, se mantuvo firme. PSG intentó reaccionar. Fabián Ruiz y Kolo Muani se movieron, pero sin puntería. Sin claridad. Sin peligro. El Emirates, con el público en pie, celebró. No fue una reacción. Fue una demostración de madurez.
#
# **5. JUGADOR: Kai Havertz – el alma del ataque**
# Havertz no solo marcó. Fue el corazón del ataque. Líder. Decisivo. Con su cabeza, su fuerza, su presencia, el Arsenal se convirtió en un equipo que no se rinde. Arteta, con su táctica, su disciplina, su visión, puso al Arsenal en el camino correcto. Y Luis Enrique, en el otro lado, tuvo que enfrentar un equipo que no se dejó llevar.
#
# **Conclusión:**
# Este partido no fue solo un triunfo. Fue un acto de valentía. De liderazgo. De fútbol puro. Arsenal no solo ganó. Ganó con estilo. Con fuerza. Con el alma de un equipo que sabe que la Champions no es un torneo. Es una batalla. Y hoy, el Arsenal la ganó.
#
# El camino continúa. Pero ya no es solo un camino. Es una historia. Y el Emirates, hoy, es el primer capítulo.
#
# *Por AS*

# %%
# FICHA 4 | Qwen 3-4b-2507 | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, UEFA Champions League 2024/25, Fase de grupos – Jornada 1)
2. GOLES: 20' Havertz (Arsenal, remate de cabeza tras centro de Trossard), 35' Saka (Arsenal, lanzamiento de falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal se adelanta con gol de Havertz (20') y Saka amplía la ventaja (35') antes del descanso con dos tantos efectivos
4. 2T: Arsenal administra el 2-0 con entrada de Mikel Merino (64', debut), PSG mueve banquillo con Fabián Ruiz y Kolo Muani sin generar peligro real
5. ESTADÍSTICAS: Posesión 58–42, tiros 14–11, córners 6–5, xG 1.4–1.2 a favor del Arsenal
6. MVP: Kai Havertz (gol clave de cabeza, liderazgo ofensivo determinante)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 11 (Qwen 3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 11 (Qwen 3-4b-2507 | CoT | Sin rol | CON RESTRICCIONES)
# ================================================================================
# **Arsenal vence a Paris Saint-Germain 2-0 en el Emirates: victoria clave en la fase de grupos**
#
# El Emirates Stadium se convirtió en escenario de una victoria clara para Arsenal en la primera jornada de la fase de grupos de la UEFA Champions League 2024/25, al derrotar al Paris Saint-Germain por 2-0. La victoria, que se consolidó en el primer tiempo, fue clave para el equipo de Mikel Arteta en su camino hacia una buena posición en la tabla.
#
# El partido comenzó con una intensidad ofensiva del Arsenal, que logró abrir el marcador a los 20 minutos. Kai Havertz marcó con un remate de cabeza tras un centro de Gabriel Trossard, un gol que se produjo en un momento de dominio táctico y control de ritmo. A los 35 minutos, el equipo de Arteta amplió la ventaja con un gol de Saka, que aprovechó un lanzamiento de falta lateral mal gestionado por Donnarumma, quien no logró desviar el balón de forma efectiva. Ambos goles fueron efectivos y se registraron antes del descanso, consolidando una ventaja que el equipo no permitió que se redujera.
#
# En el segundo tiempo, Arsenal mantuvo el control del partido. A los 64 minutos, Mikel Merino, en su debut en la competición, entró en el campo y ayudó a reforzar la línea defensiva y ofensiva. PSG intentó reaccionar con cambios, incorporando a Fabián Ruiz y Kolo Muani, pero no lograron generar amenazas reales. El equipo parisino no logró superar el control de posesión y la presión constante del Arsenal.
#
# Las estadísticas reflejan la superioridad del equipo de Londres: el Arsenal dominó el partido con 58 por ciento de posesión frente a los 42 por ciento del PSG. En términos de tiros, el Arsenal logró 14 contra 11 del rival, y en córners, 6 a 5. El valor esperado (xG) también favoreció al Arsenal, con 1.4 frente a 1.2 del equipo francés, lo que indica una mayor eficiencia en la generación de oportunidades.
#
# Kai Havertz fue el jugador más destacado del partido, con un gol clave de cabeza y un liderazgo ofensivo constante. Su actuación fue fundamental para el resultado, y fue reconocido como el MVP del partido.
#
# El triunfo de Arsenal no solo refleja su capacidad de generar goles, sino también su capacidad de mantener el control en un partido clave de la fase de grupos.
#
# 📊 Palabras: 388

# %%
# FICHA 4 | Qwen 3-4b-2507 | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, Champions League 2024/25 – Fase de grupos, Jornada 1)
2. GOLES: 20' Havertz (Arsenal, remate de cabeza tras centro de Trossard), 35' Saka (Arsenal, lanzamiento de falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal se adelanta con gol de Havertz (20') y Saka amplía la ventaja (35') antes del descanso; posesión 58–42 a favor de los gunners
4. 2T: Arsenal administra con entrada de Mikel Merino (64', debut), PSG introduce Fabián Ruiz y Kolo Muani sin generar ocasiones claras
5. ESTADÍSTICAS: Posesión 58–42, tiros 14–11, córners 6–5, xG 1.4–1.2 a favor del Arsenal
6. MVP: Kai Havertz (gol decisivo de cabeza, liderazgo ofensivo, clave en la victoria de Arteta)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="Qwen/Qwen3-4B-2507",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 12 (Qwen 3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 12 (Qwen 3-4b-2507 | CoT | CON ROL | CON RESTRICCIONES)
# ================================================================================
# **ARSenal vence a PSG 2-0 en el Emirates: Havertz y Saka marcan el camino en fase de grupos**
#
# El Emirates Stadium se convirtió en escenario de una victoria que pone a Arsenal en una posición clave en la Champions League 2024/25. En una jornada de grupos que deja al equipo de Arteta con una ventaja clara, los gunners derrotaron 2-0 al Paris Saint-Germain, en un partido marcado por la eficiencia ofensiva y el dominio de posesión.
#
# El primer gol llegó a los 20 minutos: Kai Havertz cabeceó tras un centro de Trossard, aprovechando un espacio en el área. Fue un gol de precisión, sin exageraciones, que puso al Arsenal adelantado. A los 35, Saka amplió la ventaja tras un lanzamiento de falta lateral mal gestionado por Donnarumma, que se desvió y fue recibido por el delantero, que no tuvo que esperar mucho para colocar el balón en el área. El partido, por entonces, ya estaba decidido.
#
# En la primera mitad, Arsenal dominó con claridad: 58 por ciento de posesión frente a los 42 del PSG. Aunque el equipo francés intentó reaccionar, sus intentos de creación no llegaron a convertirse en ocasiones claras. Los datos hablan claro: 14 tiros frente a 11, 6 córners a 5, y un xG de 1.4 frente a 1.2. El rendimiento ofensivo fue clave, y el liderazgo de Havertz fue fundamental.
#
# En la segunda mitad, el equipo de Arteta se mantuvo firme. Mikel Merino debutó a los 64 minutos, aunque no generó impacto directo. PSG, con la entrada de Fabián Ruiz y Kolo Muani, intentó presionar, pero no logró romper el orden defensivo de los gunners. La presión se mantuvo en el área, pero sin oportunidades de gol.
#
# El MVP del partido fue Kai Havertz: gol de cabeza decisivo, liderazgo en el ataque y una actuación que marcó el tono del partido. Su desempeño fue clave para que Arsenal se mantuviera en el liderato de la fase de grupos.
#
# Con este triunfo, Arsenal se sitúa en una posición sólida, con una victoria que refleja su capacidad de dominar el partido y convertir oportunidades. El camino sigue abierto, pero el primer paso ya está marcado.
#
# 📊 Palabras: 358
