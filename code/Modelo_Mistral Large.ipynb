# %%
CONFIGURACIÓN MISTRAL

# %%
from openai import OpenAI
import os

# ← PEGA AQUÍ TU API KEY de console.mistral.ai
os.environ["MISTRAL_API_KEY"] = "C73JlWCGKkc5gr6K0RULdiisiEhmy2lW"

client = OpenAI(
    api_key=os.environ["MISTRAL_API_KEY"],
    base_url="https://api.mistral.ai/v1"
)

print("✅ Cliente Mistral-large listo")
print(f"   → API Key configurada: {'*' * 20}...")
# Out:
# ✅ Cliente Mistral-large listo
#    → API Key configurada: ********************...

# %%
response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": "¡Hola! ¿Listo para crónicas UCL Arsenal-PSG?"}],
    temperature=0.0
)
print("✅ Test OK:", response.choices[0].message.content[:150] + "...")
# Out:
# ✅ Test OK: ¡**¡Hola, crack!** 🔥 Estoy **más que listo** para desmenuzar el **Arsenal vs. PSG** de la **Champions League**, un partido que promete **fuego, drama ...

# %%
FICHA 1
ZERO SHOT

# %%
# FICHA 1 | Mistral-large | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha1 = """ID_PARTIDO: UCL_2024_FINAL
Competición: UEFA Champions League
Temporada: 2023/2024
Fase: Final
Fecha: 01/06/2024
Hora: 20:00 (UTC+1)
Estadio: Wembley Stadium, Londres
Asistencia: 86,212
Árbitro: Slavko Vinčić
Equipo 1: Borussia Dortmund
Equipo 2: Real Madrid
Entrenador Borussia Dortmund: Edin Terzić
Entrenador Real Madrid: Carlo Ancelotti
Alineación Borussia Dortmund:
Kobel; Ryerson, Hummels, Schlotterbeck, Maatsen; Can, Brandt, Sabitzer; Adeyemi, Füllkrug, Sancho
Alineación Real Madrid:
Courtois; Carvajal, Rüdiger, Nacho; Mendy; Camavinga, Valverde, Kroos; Bellingham; Rodrygo, Vinícius Júnior
Resultado final: Borussia Dortmund 0 – 2 Real Madrid
Resultado al descanso: 0 – 0
Goles:
74' Dani Carvajal (Real Madrid), gol
83' Vinícius Júnior (Real Madrid), gol
Tarjetas amarillas Borussia Dortmund:
40' Nico Schlotterbeck
43' Marcel Sabitzer
79' Mats Hummels
Tarjetas amarillas Real Madrid:
35' Vinícius Júnior
Sustituciones Borussia Dortmund:
72' Marco Reus por Karim Adeyemi
80' Donyell Malen por Emre Can
80' Sébastien Haller por Julian Brandt
87' Jamie Bynoe-Gittens por Jadon Sancho
Sustituciones Real Madrid:
85' Luka Modrić por Toni Kroos
85' Joselu por Jude Bellingham
90' Éder Militão por Rodrygo
90+4' Lucas Vázquez por Vinícius Júnior
Eventos registrados:
21' Ocasión de gol Borussia Dortmund: remate de Karim Adeyemi bloqueado
23' Remate de Niclas Füllkrug al poste
Final del partido: gol de Borussia Dortmund anulado por fuera de juego
Estadísticas totales:
Posesión (%): 46 – 54
Tiros: 13 – 13
Tiros a puerta: 3 – 6
Córners: 9 – 8
Faltas: 12 – 8
Fueras de juego: 1 – 0
Estadísticas por partes:
Primera parte: posesión 40 – 60, tiros 8 – 2, córners 5 – 1
Segunda parte: posesión 54 – 46, tiros 5 – 11, córners 4 – 7
Estadísticas avanzadas:
xG: 1.86 – 1.15
Jugador del partido: Dani Carvajal"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha1}"

response = client.chat.completions.create(
    model="mistral-large-latest",  
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 1 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)
# ...
# **WEMBLEY VIBRÓ CON EL MADRID: CARVAJAL Y VINI LE DAN LA DECIMOPRIMERA A ANCELOTTI**
#
# *Londres, 1 de junio de 2024* — El Santiago Bernabéu tendrá que esperar para celebrar, pero el fútbol ya tiene un nuevo rey en Europa. El Real Madrid alzó su **decimoquinta Copa de Europa** en un Wembley que, una vez más, se rindió ante la *galáctica* leyenda de los blancos. **Dani Carvajal (74') y Vinícius Júnior (83')** firmaron los goles que coronaron a un equipo que, pese a no ser el más brillante de la temporada, volvió a demostrar por qué es el club más ganador de la historia. El Borussia Dortmund, valiente y con el corazón en la garganta, se quedó a las puertas de un sueño que rozó con los dedos de **Füllkrug (23')** —el poste le dijo que no— y con el alma de **Marco Reus (72')**, que entró para despedirse de la Champions como merecía: luchando hasta el final.
#
# ---
#
# ...

# %%
# FICHA 1 | Mistral-large | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha1}""".format(ficha1=ficha1)

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 1 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)
# ...
# **Wembley se tiñe de blanco: el Real Madrid conquista su decimoquinta Champions con un Carvajal de leyenda**
#
# *Londres, 1 de junio de 2024* — **¡Campeones!** El Real Madrid alzó su **decimoquinta Copa de Europa** en un Wembley que vibró, sufrió y, al final, se rindió ante la grandeza de un equipo que escribe su nombre en la historia con letras de oro. **0-2 al Borussia Dortmund**, con goles de **Dani Carvajal (74')** y **Vinícius Júnior (83')**, en una final que el Madrid resolvió con la frialdad de los grandes y la épica de los que nunca se rinden. **Carlo Ancelotti**, con este título, se convierte en el primer técnico en ganar **cinco Champions**, y el Madrid, en el rey absoluto de Europa.
#
# ---
#
# ### **Un primer tiempo de dominio estéril**
# ...

# %%
# FICHA 1 | Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha1}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config3}],  # ← Corregido: prompt_config3
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)  # ← Corregido: cronica_config3
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)
# ...
# **Wembley se rinde al Madrid: Carvajal y Vinícius firman la Decimoquinta**
#
# *Londres, 1 de junio de 2024* — El Santiago Bernabéu viajó a Wembley. El Real Madrid, con la frialdad de los grandes, doblegó al Borussia Dortmund (0-2) en una final de Champions que, aunque ajustada en el marcador, tuvo dueño desde el primer minuto. Dani Carvajal, con un zurdazo impecable, y Vinícius Júnior, letal en el contraataque, escribieron sus nombres en la historia de la *Orejonas* con goles en los minutos 74 y 83. La Decimoquinta ya es una realidad, y Carlo Ancelotti, el primer técnico en ganar cuatro Champions, volvió a demostrar que su Madrid no entiende de épica barata: gana con autoridad, incluso cuando el rival merece más.
#
# ### **Un primer acto de dominio estéril**
# ...

# %%
# FICHA 1 | Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES
# AUDIENCIA: Aficionados AS/Marca

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha1}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos, xG, Jugador del partido"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)
# ...
# **El Madrid de Ancelotti escribe su leyenda en Wembley: la Decimoquinta es realidad**
#
# *Londres, 1 de junio de 2024.* El Real Madrid no necesita épica para ser eterno, pero la noche de Wembley le regaló un broche de oro a su temporada perfecta. Dos goles en nueve minutos —Carvajal y Vinícius— bastaron para doblegar a un Borussia Dortmund valiente, pero condenado por su propia ansiedad y la frialdad blanca. La *Decimoquinta* ya es historia, y Carlo Ancelotti, el primer técnico en ganar cuatro Champions, se erige como el arquitecto de un imperio que no conoce límites.
#
# ### **El partido que el Dortmund soñó… hasta que despertó**
# ...

# %% [markdown]
# FICHA 1
# FEW SHOT

# %%
# FICHA 1 | Mistral-large | Few-shot | Sin rol | Sin restricciones
# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha1}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 1 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ...
# **REAL MADRID 2–0 BORUSSIA DORTMUND**
#
# Wembley vivió una final de Champions League sin goles en la primera mitad, pero con un Real Madrid que, como en tantas otras noches europeas, terminó imponiendo su jerarquía. Dani Carvajal abrió la lata en el minuto 74 con un remate certero tras una jugada colectiva, y Vinícius Júnior sentenció en el 83 con un disparo cruzado que dejó sin opciones a Kobel. El Dortmund, valiente pero impreciso, rozó el gol en los primeros compases con un remate de Adeyemi bloqueado y otro de Füllkrug al poste, pero el Madrid respondió con más contundencia en los metros finales.
#
# ...

# %%
# FICHA 1 | Mistral-large | Few-shot SIMPLE | CON ROL | Sin restricciones
# Objetivo: forzar que Mistral NO copie la ficha y sí genere una crónica evaluable con rol periodístico.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot2 = f"""
Eres periodista deportivo de AS/Marca.

EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha1}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_fewshot2}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot2 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot2)
# Out:
# ✅ FICHA 1 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)
# ...
# **REAL MADRID 2–0 BORUSSIA DORTMUND**
# *El Madrid alza su decimoquinta Champions con un triunfo en Wembley gracias a los goles de Carvajal y Vinícius*
#
# Wembley vivió una final de infarto hasta que el Real Madrid desató su jerarquía en el tramo decisivo. El Borussia Dortmund, valiente y ordenado, rozó el sueño en la primera mitad, pero la experiencia blanca terminó imponiéndose con dos zarpazos en el último cuarto de hora. Dani Carvajal, autor del primer gol y elegido mejor jugador del partido, y Vinícius Júnior, que sentenció con un remate cruzado, escribieron sus nombres en la historia de la *Orejona*.
#
# ...

# %%
# FICHA 1 | Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES
# Objetivo: generar crónica estructurada (400–500 palabras) sin copiar la ficha, pero respetando los datos clave.

# --- Prompt (few-shot real + restricciones) ---
ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha1 para aficionados al fútbol que leen AS o Marca:

{ficha1}

RESTRICCIONES:
• 500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)
# ...
# **El Madrid corona su leyenda en Wembley: Carvajal y Vinícius apagan al Dortmund en una final de infarto**
#
# *Londres, 1 de junio de 2024* — El Santiago Bernabéu viajó a Wembley. El Real Madrid, una vez más, escribió su nombre en la historia con letras de oro, esta vez con la firma de dos guerreros: **Dani Carvajal** (74’) y **Vinícius Júnior** (83’). Dos goles en nueve minutos bastaron para doblegar a un **Borussia Dortmund** valiente, que rozó el milagro pero se topó con la frialdad de un equipo acostumbrado a ganar cuando más duele. **2-0 final**, **decimoquinta Champions** para el club blanco, y una noche en la que el fútbol volvió a rendirse ante la grandeza de un equipo que no entiende de épica, sino de **leyenda viva**.
#
# ---
#
# ### **Cronología de un duelo de nervios y oportunidades**
#
# **Minuto 0-20: El Dortmund asusta, el Madrid respira**
# ...

# %%
# FICHA 1 | Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES
# Objetivo: crónica periodística estructurada (400–500 palabras) con tono de profesional deportivo.

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha1 para aficionados que leen AS o Marca:

{ficha1}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos, sus minutos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)
# ...
# **El Madrid corona su leyenda en Wembley: Carvajal y Vinícius escriben su nombre en la Champions**
#
# *Londres, 1 de junio de 2024* — El Real Madrid no solo ganó su decimoquinta *Orejonas*, sino que lo hizo con la elegancia de un equipo que domina el arte de sufrir y vencer. En un Wembley vibrante, teñido de blanco y amarillo, los de Ancelotti doblegaron al Borussia Dortmund (0-2) con dos golpes certeros en el tramo final, cuando el partido parecía condenado al alargue. Carvajal, el eterno lateral derecho, y Vinícius, el mago brasileño, firmaron los goles que sellaron una final épica, donde el Madrid volvió a demostrar por qué es el rey de Europa.
#
# ### **Cronología de un título anunciado**
# ...

# %% [markdown]
# CoT
# FICHA 1

# %%
# FICHA 1 | Mistral-large | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley, UCL 2023/24, Final)
2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)
3. 1T: Dortmund domina, genera más peligro y Füllkrug estrella un balón en el poste; xG 1.86 – 1.15 a favor del Dortmund
4. 2T: El Madrid reacciona, Carvajal abre el marcador en el 74' y Vinícius sentencia en el 83'; Courtois decisivo en la primera parte
5. JUGADOR: Dani Carvajal (defensa goleador y referente del triunfo)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 1 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)
# ...
# **¡EL MADRID ES REY DE EUROPA!**
# **Carvajal y Vinícius firman el 15º título en Wembley con un 2-0 épico ante el Dortmund**
#
# *Londres (Wembley) – 1 de junio de 2024*
#
# **El fútbol, ese juego de detalles, de instantes que lo cambian todo.** Y en Wembley, bajo el manto sagrado de la Champions, el Real Madrid volvió a demostrar por qué es el club más grande de la historia. No fue un paseo —el Borussia Dortmund lo puso contra las cuerdas—, pero cuando la noche amenazaba con volverse negra, aparecieron *los de siempre*: Carvajal, el defensa que juega como delantero, y Vinícius, el brasileño que baila con la gloria. **2-0 final, 15ª Orejona y un título que sabe a venganza, a redención, a leyenda.**
#
# ---
#
# ### **PRIMERA PARTE: EL DORTMUND ASUSTA, COURTOIS SALVA Y EL POSTE DICE "NO"**
# ...

# %%
# FICHA 1 | Mistral-large | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley, UCL 2023/24, Final)
2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)
3. 1T: Dortmund domina, más ocasiones claras y Füllkrug al poste; Courtois sostiene al Madrid con tres intervenciones clave.
4. 2T: Madrid cambia el rumbo, Kroos lanza el córner del 1–0, Bellingham asiste en el 2–0, eficacia total. 
5. JUGADOR: Dani Carvajal (líder, goleador y pieza decisiva en la final).

ESCRIBE crónica paso a paso siguiendo estos cinco puntos:
- Usa tono periodístico español (propio de AS/Marca)
- Mantén ritmo ágil y frases breves
- Menciona contexto 
- No inventes citas ni declaraciones textuales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 1 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)
# ...
# **Wembley se tiñe de blanco: el Madrid conquista su Decimoquinta con Carvajal como héroe**
#
# *Londres, 1 de junio de 2024* — El Santiago Bernabéu viajó a Wembley. Y volvió a casa con la *Orejona*. El Real Madrid sumó su **Decimoquinta Copa de Europa** (15ª, récord absoluto) tras doblegar al Borussia Dortmund (2-0) en una final que, como tantas otras en su leyenda, tuvo de todo: sufrimiento, genio y un broche de oro firmado por quien menos lo esperaba. **Dani Carvajal**, el capitán eterno, el lateral que lo ha visto todo, se convirtió en el protagonista inesperado de una noche que el Madrid escribirá con letras de oro en su historia.
#
# ---
#
# ### **1. El Dortmund asusta, Courtois salva al Madrid (1T: 0-0)**
# ...

# %%
# FICHA 1 | Mistral-large | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley Stadium, UEFA Champions League 2023/24 – Final)
2. GOLES: 74' Carvajal (Real Madrid, córner de Kroos), 83' Vinícius Júnior (Real Madrid, asistencia de Bellingham)
3. 1T: Dortmund domina el primer tiempo (posesión 60–40), genera más peligro (xG 1.86 vs 1.15), Füllkrug al poste, Courtois sostiene al Madrid.
4. 2T: El Real Madrid reacciona tras el descanso; Carvajal anota el 1–0 en el 74' y Vinícius sentencia el 2–0 en el 83'. 
5. ESTADÍSTICAS CLAVE: Posesión 54–46, tiros 13–13, córners 9–8, xG 1.86–1.15 Dortmund–Madrid.
6. MVP: Dani Carvajal (gol decisivo y actuación defensiva sobresaliente).

ESCRIBE una crónica para AS/Marca siguiendo estas pautas:
• Extensión: 400-500 palabras
• Estructura: Entrada + Desarrollo cronológico + Cierre analítico
• Menciona TODOS los datos proporcionados
• No uses metáforas poéticas ni exageraciones irreales
• No inventes citas ni declaraciones
• Mantén tono deportivo e informativo con ritmo narrativo"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content
print("✅ FICHA 1 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)
# ...
# **El Real Madrid conquista su decimoquinta Champions con autoridad ante el Borussia Dortmund**
#
# *Wembley, 1 de junio de 2024* — El Real Madrid alzó su decimoquinta Copa de Europa tras imponerse al Borussia Dortmund por 2-0 en una final que, como es tradición en el club blanco, tuvo dos caras bien distintas. Los alemanes dominaron el primer tiempo con solvencia, pero la eficacia y la experiencia del Madrid en los momentos decisivos acabaron decantando el partido a su favor. Dani Carvajal, autor del primer gol y clave en defensa, fue elegido mejor jugador del encuentro.
#
# ### **Un primer tiempo de dominio alemán**
# ...

# %%
# FICHA 1 | Mistral-large | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Real Madrid 2–0 Borussia Dortmund (Wembley Stadium, Champions League 2023/24 – Final)
2. GOLES: 74' Dani Carvajal (Real Madrid, remate tras córner de Toni Kroos), 83' Vinícius Júnior (Real Madrid, definido tras asistencia de Jude Bellingham)
3. 1T: Borussia Dortmund domina el primer tiempo, genera más peligro, Füllkrug remata al poste y Courtois sostiene al Madrid; xG 1.86–1.15 a favor de los alemanes.
4. 2T: El Real Madrid ajusta, gana metros y efectividad; Carvajal abre el marcador en el 74' y Vinícius sentencia el 2–0 en el 83', con Ancelotti gestionando los cambios finales.
5. ESTADÍSTICAS CLAVE: Posesión 54–46, tiros 13–13, córners 9–8, xG 1.86–1.15.
6. MVP: Dani Carvajal (gol decisivo, peso defensivo y simbólico en la final).

ESCRIBE una crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos de los puntos 1–6
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 1 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 1 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)
# ...
# **El Madrid de Ancelotti corona su leyenda en Wembley: Carvajal y Vinícius apagan al Dortmund en una final de dos tiempos**
#
# *Londres (Wembley) –* La Champions League volvió a sonreír al Real Madrid. En un partido de dos caras, el equipo de Carlo Ancelotti superó al Borussia Dortmund (2-0) con goles de Dani Carvajal (74') y Vinícius Júnior (83') para levantar su decimoquinta *Orejonas* en una final que, como tantas otras en su historia, tuvo de todo: dominio alemán en la primera mitad, reacción blanca en la segunda y un cierre perfecto para escribir otro capítulo dorado.
#
# ### **Cronología: Del susto al éxtasis**
# ...

# %% [markdown]
# FICHA 2
# ZERO SHOT

# %%
# FICHA 2 | Mistral-large | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha2 = """ID_PARTIDO: UCL_2024_J1_BAY_DIN
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1
Fecha: 17/09/2024
Hora: 19:00 UTC
Estadio: Allianz Arena (Múnich)
Asistencia: 75 000
Árbitro: Juan Martínez Munuera (España)

Equipo 1: Bayern Munich
Equipo 2: Dinamo Zagreb

Entrenador Bayern Munich: Vincent Kompany
Entrenador Dinamo Zagreb: Sergej Jakirović

Alineación Bayern Munich:
Neuer; Kimmich, Upamecano, De Ligt, Davies; Goretzka, Pavlović; Olise, Musiala, Sané; Kane

Alineación Dinamo Zagreb:
Livaković; Ristovski, Théophile-Catherine, Mmaee, Smolcic; Mišić, Perić; Pjaca, Baturina, Hoxha; Petković

Resultado final: Bayern Munich 9 – 2 Dinamo Zagreb
Resultado al descanso: 3–0

Goles:
19' Harry Kane (Bayern Munich), gol de penalti
34' Raphaël Guerreiro (Bayern Munich), gol
38' Michael Olise (Bayern Munich), gol
48' Harry Kane (Bayern Munich), gol
57' Michael Olise (Bayern Munich), gol
73' Harry Kane (Bayern Munich), gol de penalti
81' Kingsley Coman (Bayern Munich), gol
87' Joshua Kimmich (Bayern Munich), gol
90+3' Mathys Tel (Bayern Munich), gol

Goles Dinamo Zagreb:
49' Bruno Petković, gol
50' Takuya Ogiwara, gol

Tarjetas amarillas Bayern Munich: N/D
Tarjetas amarillas Dinamo Zagreb: 77' Ristovski
Tarjetas rojas: N/D

Sustituciones Bayern Munich: N/D
Sustituciones Dinamo Zagreb: N/D

Eventos registrados:
19' Penalti a favor del Bayern Munich convertido por Harry Kane
73' Segundo penalti a favor del Bayern Munich convertido por Harry Kane

Estadísticas totales:
Posesión (%): 72 – 28
Tiros: 32 – 7
Córners: 12 – 2

Estadísticas avanzadas:
xG: 5.4 – 1.2

Jugador del partido: Harry Kane"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha2}"

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 2 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)
# ...
# **¡BAYERN DESTRUYE AL DINAMO ZAGREB CON UN 9-2 ÉPICO! KANE HACE HISTORIA EN LA CHAMPIONS**
#
# *Múnich, 17 de septiembre de 2024* — El Allianz Arena rugió como en los viejos tiempos. El Bayern de Múnich, con Vincent Kompany al mando, no solo ganó, sino que **humilló** al Dinamo Zagreb en la primera jornada de la Champions League 2024/25. **9-2**. Una goleada para enmarcar, un recital ofensivo y, sobre todo, **un Harry Kane desatado** que firmó un *hat-trick* (con dos penaltis) y se convirtió en el protagonista absoluto de la noche. Si esto es un aviso, Europa tiembla.
#
# ---
#
# ### **PRIMER ACTO: EL BAYERN ARRANCA CON AUTORIDAD**
# ...

# %%
# FICHA 2 | Mistral-large | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha2}""".format(ficha2=ficha2)

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=1500
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 2 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)
# ...
# **¡El Bayern de Kompany arrasa al Dinamo Zagreb con un 9-2 de escándalo!**
# *Kane brilla con un hat-trick y el Allianz Arena vibra con una exhibición histórica*
#
# **Múnich, 17 de septiembre de 2024** — El Bayern Múnich inauguró su camino en la **Champions League 2024/25** con una **demostración de poderío ofensivo** que dejó al Dinamo Zagreb —y a media Europa— con la boca abierta. **Nueve goles a favor, dos en contra**, un **hat-trick de Harry Kane** y una **fiesta de fútbol vertical** firmada por Vincent Kompany en su debut como técnico en la máxima competición continental. Si esto es un aviso, el resto de rivales del Grupo B harán bien en abrocharse los cinturones.
#
# ### **Primer tiempo: El Bayern marca el ritmo (3-0)**
# ...

# %%
# FICHA 2 | Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha2}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 2 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)
# ...
# **El Bayern Munich destroza al Dinamo Zagreb con un recital ofensivo en la Champions**
#
# *Múnich, 17 de septiembre de 2024* — El Allianz Arena rugió esta noche como en los mejores tiempos de los *Rekordmeister*. El Bayern Munich, bajo el mando de Vincent Kompany, firmó una exhibición de poderío ofensivo para aplastar al Dinamo Zagreb (9-2) en la primera jornada de la fase de grupos de la Champions League. Un partido que quedará en la memoria por la contundencia *bávara*, pero también por la fragilidad defensiva de un rival que sufrió como nunca ante el ritmo demoledor de los locales.
#
# ### **Un primer tiempo para sentenciar**
# ...

# %%
# FICHA 2 | Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha2}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)
# ...
# **El Bayern Munich humilla al Dinamo Zagreb con un recital de fútbol ofensivo**
#
# *Múnich, 17 de septiembre de 2024* — El Allianz Arena rugió como en los viejos tiempos. Nueve goles, un hat-trick de Harry Kane, un festival de fútbol vertical y una exhibición de poderío que dejó al Dinamo Zagreb sin aliento. El Bayern Munich no solo ganó su primer partido de la Champions League 2024/25: lo hizo con una contundencia que recordó a sus mejores noches europeas. Nueve a dos. Cifras de escándalo, números que duelen, pero sobre todo, un mensaje claro: bajo el mando de Vincent Kompany, los bávaros han vuelto a ser una máquina de triturar rivales.
#
# ### **El show comenzó antes del descanso**
# ...

# %% [markdown]
# FEW SHOT
# FICHA 2

# %%
# FICHA 2 | Mistral-large | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Mistral NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha2}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 2 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ...
# **BAYERN MÚNICH 9–2 DINAMO ZAGREB**
# Un recital ofensivo del Bayern de Kompany dejó al Dinamo Zagreb sin respuesta en la primera jornada de la Champions. Harry Kane, con un *hat-trick* y dos penaltis, lideró la exhibición bávara en el Allianz Arena.
#
# El conjunto local no tardó en imponerse. Kane abrió el marcador desde los once metros en el minuto 19, tras una falta sobre Sané. Guerreiro y Olise ampliaron antes del descanso, dejando un 3–0 que anticipaba la goleada. El Dinamo reaccionó con dos goles seguidos al inicio de la segunda parte (Petković y Ogiwara), pero el Bayern cerró cualquier atisbo de sorpresa con seis dianas más. Olise, Kane (de nuevo desde el punto de penalti), Coman, Kimmich y Tel sellaron un marcador histórico.
#
# ...

# %%
# FICHA 2 | Mistral-large | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha2 para aficionados que leen AS o Marca:
{ficha2}"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 2 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)
# ...
# **Bayern Munich 9-2 Dinamo Zagreb: El Bayern destroza al Dinamo con un recital de gol y espectáculo en el Allianz Arena**
#
# **Múnich (Enviado especial) – 17/09/2024** – *El Bayern Munich no tuvo piedad.* En la primera jornada de la fase de grupos de la **Champions League 2024/25**, el equipo de **Vincent Kompany** aplastó al **Dinamo Zagreb** con un **9-2** que dejó al Allianz Arena en éxtasis y a los croatas con la moral por los suelos. **Harry Kane**, en su mejor versión, firmó un **hat-trick** (dos de penalti) y fue la gran estrella de una noche en la que el Bayern exhibió su poderío ofensivo sin contemplaciones.
#
# ### **Un primer tiempo para el recuerdo**
# ...

# %%
# FICHA 2 | Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha2 para aficionados al fútbol que leen AS o Marca:

{ficha2}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)
# ...
# **Bayern Munich 9-2 Dinamo Zagreb: El festival ofensivo de Kompany que dejó al Dinamo en ruinas**
#
# *Múnich, 17 de septiembre de 2024* — El Allianz Arena rugió como en los viejos tiempos. El Bayern Munich, con un despliegue de fútbol vertical y letal, destrozó al Dinamo Zagreb (9-2) en la primera jornada de la Champions League, en un partido que más que un encuentro de fase de grupos pareció un entrenamiento de ataque contra defensa. Con un *xG* estratosférico (5.4-1.2), los de Vincent Kompany no solo ganaron, sino que exhibieron una máquina de goles que recordó a los mejores momentos de Guardiola o Heynckes. El Dinamo, por su parte, se llevó un baño de realidad: en el fútbol de élite, los errores se pagan con goleadas históricas.
#
# ### **Cronología de un festival**
# ...

# %%
# FICHA 2 | Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha2 para aficionados que leen AS o Marca:

{ficha2}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)
# ...
# **Bayern Munich 9-2 Dinamo Zagreb: El festival de goles que humilló al Dinamo en el Allianz Arena**
#
# *Múnich, 17 de septiembre de 2024* — El Bayern Munich no tuvo piedad. En una noche de exhibición ofensiva, los de Vincent Kompany destrozaron al Dinamo Zagreb (9-2) en la primera jornada de la Champions League, dejando un marcador que recordó a los mejores días de Guardiola en el Allianz Arena. Nueve goles, dos penaltis convertidos por Harry Kane y un festival de fútbol vertical que dejó al Dinamo Zagreb —y a Europa— con la boca abierta. El xG (5.4-1.2) no engaña: el Bayern fue letal, y el Dinamo, un convidado de piedra en su propia pesadilla.
#
# ### **Cronología de un recital**
# ...

# %% [markdown]
# CoT
# FICHA 2

# %%
# FICHA 2 | Mistral-large | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Bayern Munich 9-2 Dinamo Zagreb (Allianz Arena, UCL 2024/25)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern domina, 3-0 al descanso, posesión 72%, xG 5.4 vs 1.2
4. 2T: Goleada histórica con hat-trick de Kane, Dinamo marca dos seguidos (49'–50'), but sin reacción
5. JUGADOR: Harry Kane (3 goles, liderazgo, clave ofensiva)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 2 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 2 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)
# ...
# **¡BAYERN DESTRUYE AL DINAMO!**
# **Kane hace historia con un *hat-trick* y el Bayern Munich humilla al Dinamo Zagreb (9-2) en una noche de locura en la Allianz Arena**
#
# *Múnich (Alemania), 25 de septiembre de 2024* — La Champions League no perdona. Y menos cuando el Bayern Munich decide despertar de su letargo con una exhibición de poderío ofensivo que dejó al Dinamo Zagreb —y al mundo— con la boca abierta. Nueve goles, tres de Harry Kane, dos penaltis, un *hat-trick* en 24 minutos y una goleada que pasará a los anales de la competición. La Allianz Arena vibró, el Dinamo se deshizo y el Bayern, por fin, recordó que sigue siendo un monstruo.
#
# ### **PRIMER ACTO: EL BAYERN DESPIERTA Y NO PERDONA**
# ...

# %%
# FICHA 2 | Mistral-large | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, UCL 2024/25, Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern impone ritmo, 3-0 antes del descanso, dominio total (posesión 72%, xG 5.4 vs 1.2)
4. 2T: Dinamo anota dos seguidos (49'-50'), pero el festival bávaro continúa con hat-trick de Kane y lluvia de goles
5. JUGADOR: Harry Kane (3 goles, participación clave, líder ofensivo)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Kompany
- No inventes declaraciones ni citas textuales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 2 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)
# ...
# **¡El Bayern arrasa al Dinamo Zagreb con un 9-2 de escándalo! Kane hace historia y Kompany debuta con un recital en la Champions**
#
# *Múnich (Allianz Arena) – Jornada 1 de la Champions 2024/25*
#
# **1. El Bayern no perdona: 3-0 en media hora y el Dinamo se ahoga**
# ...

# %%
# FICHA 2 | Mistral-large | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, UEFA Champions League 2024/25, Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Bayern 3-0 al descanso, dominio absoluto en posesión (72%) y ritmo ofensivo; Dinamo apenas se asoma
4. 2T: Dos goles rápidos del Dinamo (49', 50') antes del festival bávaro final con seis tantos más
5. ESTADÍSTICAS: Posesión 72–28%, tiros 32–7, córners 12–2, xG 5.4–1.2
6. MVP: Harry Kane (hat-trick, líder de ataque, decisivo)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)
# ...
# **Bayern Múnich aplasta al Dinamo Zagreb con un 9-2 histórico en la Champions**
#
# *Múnich (Allianz Arena) –* El Bayern Múnich inauguró su participación en la Champions League 2024/25 con una exhibición demoledora ante el Dinamo Zagreb. Los bávaros, bajo el mando de Thomas Tuchel en su última temporada al frente, firmaron un 9-2 que quedará en los registros como una de las mayores goleadas en la historia reciente del torneo. Harry Kane, con un hat-trick, lideró un festival ofensivo que dejó al equipo croata sin respuesta.
#
# ---
#
# ### **Cronología: Un partido de dos velocidades**
#
# ...

# %%
# FICHA 2 | Mistral-large | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Bayern Munich 9–2 Dinamo Zagreb (Allianz Arena, Champions League 2024/25 – Jornada 1)
2. GOLES: 19' Kane (pen.), 34' Guerreiro, 38' Olise, 48' Kane, 49' Petković, 50' Ogiwara, 57' Olise, 73' Kane (pen.), 81' Coman, 87' Kimmich, 90+3' Tel
3. 1T: Superioridad bávara total, 3-0 al descanso, dominio en posesión (72%) y presión alta; Dinamo rezagado
4. 2T: Dos goles croatas rápidos (49', 50'), luego recital ofensivo del Bayern con hat-trick de Kane y vendaval de ocasiones
5. ESTADÍSTICAS: Posesión 72–28%, tiros 32–7, córners 12–2, xG 5.4–1.2
6. MVP: Harry Kane (hat-trick, líder de ataque, participación decisiva)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba y usa los gentilicios 'bávaros' y 'croatas'
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 2 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 2 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)
# ...
# **¡El Bayern aplasta al Dinamo Zagreb con un 9-2 de escándalo en la Champions!**
# *Kane hace historia con un hat-trick y los bávaros desfilan en el Allianz Arena*
#
# **Múnich, 18 de septiembre de 2024** — La Champions League 2024/25 arrancó con un recital ofensivo en Baviera. El Bayern de Múnich no solo ganó: humilló. Un 9-2 al Dinamo Zagreb que quedará en los anales del torneo por su contundencia, su ritmo endiablado y la exhibición de Harry Kane, autor de tres goles y dueño absoluto del área. Los croatas, superados en todos los aspectos, sufrieron el vendaval bávaro desde el primer minuto y solo pudieron arañar dos goles de consolación en un partido que, tras el descanso, se convirtió en un entrenamiento de lujo para los locales.
#
# ---
#
# ### **Cronología de un festival**
# ...

# %% [markdown]
# FICHA 3
# ZERO SHOT

# %%
# FICHA 3 | Mistral-large | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha3 = """ID_PARTIDO: UCL_2024_J1_MIL_LIV
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1
Fecha: 17/09/2024
Hora: 21:00 CEST (19:00 UTC)
Estadio: Stadio Giuseppe Meazza (San Siro), Milán
Asistencia: 59,826 espectadores
Árbitro: Espen Eskås (Noruega)
Equipo 1: AC Milan
Equipo 2: Liverpool
Entrenador AC Milan: Paulo Fonseca
Entrenador Liverpool: Arne Slot
Alineación AC Milan:
Maignan; Calabria, Tomori, Thiaw, Theo Hernández; Fofana, Reijnders; Pulisic, Loftus-Cheek, Leão; Morata
Alineación Liverpool:
Alisson; Bradley, Konaté, Van Dijk, Robertson; Mac Allister, Gravenberch, Szoboszlai; Salah, Núñez, Gakpo
Resultado final: AC Milan 1 – 3 Liverpool
Resultado al descanso: AC Milan 1 – 2 Liverpool
Goles:
3' Pulisic (AC Milan) 1–0, asistencia de Morata
23' Konaté (Liverpool) 1–1, remate de cabeza a balón parado
41' Van Dijk (Liverpool) 1–2, cabezazo tras córner de Tsimikas
67' Szoboszlai (Liverpool) 1–3, disparo tras jugada combinada
Tarjetas amarillas AC Milan:
51' Tomori
Tarjetas amarillas Liverpool:
79' Van Dijk
Tarjetas rojas:
Ninguna
Sustituciones AC Milan:
Ingresaron Chukwueze, Musah y Terracciano en la segunda parte
Sustituciones Liverpool:
Entraron Tsimikas y jugadores de refresco para administrar la ventaja
Eventos registrados:
3' Gol de Pulisic para el Milan
23' Konaté empata de cabeza
41' Van Dijk remonta antes del descanso
67' Szoboszlai sentencia el partido
Estadísticas totales:
Posesión (%): 55 – 45
Tiros: 16 – 12
Córners: 7 – 5
Estadísticas avanzadas:
xG: 1.8 – 1.1 (a favor de Liverpool)
Jugador del partido: Szoboszlai o Van Dijk"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha3}"

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 3 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)
# ...
# **¡El Liverpool humilla al Milan en San Siro!**
# *Un golazo de Pulisic ilusionó, pero la solidez defensiva y el acierto de los 'Reds' sentenciaron la noche en la Champions*
#
# **MILÁN (San Siro) – 17/09/2024** – *Por [Tu Nombre]*
#
# El **AC Milan** soñó durante tres minutos. El **Liverpool**, en cambio, hizo realidad lo que muchos temían: una exhibición de jerarquía en la **Champions League** que dejó al equipo de **Paulo Fonseca** con la moral por los suelos y a los *rossoneri* preguntándose qué salió mal. **1-3** en el marcador final, pero la sensación es que la diferencia pudo ser mayor. **Virgil van Dijk** y **Dominik Szoboszlai** lideraron una noche para enmarcar, mientras que el Milan, pese a su dominio inicial, se desvaneció como un azucarillo en la segunda parte.
#
# ---
#
# ### **Primer acto: El Milan ilusiona, el Liverpool responde con contundencia**
# ...

# %%
# FICHA 3 | Mistral-large | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha3}""".format(ficha3=ficha3)

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 3 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)
# ...
# **¡El Liverpool humilla al Milan en San Siro!**
# *Un golazo de Pulisic ilusionó, pero la solidez defensiva y el acierto de los 'Reds' sentenciaron la noche en la Champions*
#
# **MILÁN (San Siro) – 17/09/2024** – *Por [Tu nombre], enviado especial de AS/Marca*
#
# ...

# %%
# FICHA 3 | Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha3}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 3 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)
# ...
# **San Siro tiembla: el Liverpool de Slot humilla al Milan de Fonseca en una noche de pesadilla**
#
# *Milán, 17 de septiembre de 2024* — El **Stadio Giuseppe Meazza** rugió en los primeros minutos, pero terminó en silencio. El **AC Milan**, con un gol de **Pulisic** en el 3’ que hizo soñar a su afición, se desvaneció ante un **Liverpool** frío, letal y con una defensa de acero. **3-1** final que deja a los *rossoneri* con dudas y a los *reds* como favoritos en el Grupo B de la **Champions League 2024/25**. Una noche para olvidar en San Siro, donde el fútbol inglés volvió a demostrar por qué es el rey de Europa.
#
# ---
#
# ### **El sueño efímero de Pulisic y el despertar brutal**
# ...

# %%
# FICHA 3 | Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha3}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)
# ...
# **San Siro se tiñe de rojo: Liverpool humilla al Milan con un recital de autoridad**
#
# *Milán (San Siro) – 17 de septiembre de 2024*
#
# El fútbol es cruel, y el AC Milan lo descubrió esta noche en su propia casa. Ante 59.826 almas en San Siro, el Liverpool de Arne Slot no solo ganó (1-3), sino que desnudó las carencias de un Milan que soñaba con resucitar su leyenda en la Champions. Tres goles en 41 minutos, un dominio físico abrumador y una exhibición de jerarquía en cada pelota parada. Así se escribe el primer capítulo de la *Orejonera* en la 2024/25: con los *Reds* como verdugos y el Milan como víctima de su propia inconsistencia.
#
# ### **El sueño efímero de Pulisic y la pesadilla de Maignan**
# ...

# %%
FEW SHOT
FICHA 3

# %%
# FICHA 3 | Mistral-large | Few-shot | Sin rol | Sin restricciones
# Objetivo: forzar que Mistral NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha3}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 3 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ...
# **AC MILAN 1–3 LIVERPOOL**
# El Liverpool remontó en San Siro con dos goles de cabeza en la primera mitad y sentenció con un disparo lejano de Szoboszlai en la segunda.
#
# El Milan salió con intensidad y se adelantó pronto, cuando Pulisic aprovechó un pase de Morata para abrir el marcador en el minuto 3. Sin embargo, el Liverpool reaccionó con contundencia: Konaté igualó de cabeza tras un balón parado en el 23, y Van Dijk dio la vuelta al marcador antes del descanso con otro remate aéreo, esta vez tras un córner.
#
# En la segunda parte, el Milan intentó presionar, pero Szoboszlai cerró el partido con un disparo desde fuera del área en el 67. El Liverpool administró la ventaja con cambios tácticos, mientras el Milan, con amarilla para Tomori, no encontró el ritmo para recortar distancias.

# %%
# FICHA 3 | Mistral-large | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha3 para aficionados que leen AS o Marca:
{ficha3}"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 3 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)
# ...
# **AC Milan 1-3 Liverpool: El Liverpool se impone en San Siro con un recital de fútbol vertical y eficacia letal**
#
# *San Siro, Milán. 17 de septiembre de 2024.* El Liverpool de Arne Slot dejó claro desde el primer minuto que ha llegado a la Champions para pelear por todo. Con un fútbol directo, presión alta y una efectividad demoledora, los *Reds* doblegaron al Milan de Paulo Fonseca en un partido que, pese al dominio local en posesión, se decidió por la contundencia de los visitantes. Tres goles en la primera mitad —dos de ellos de cabeza— y un Szoboszlai inspirado sentenciaron un choque que deja al Milan con la obligación de reaccionar en la próxima jornada.
#
# ### **Un inicio fulgurante… y un Liverpool que responde con frialdad**
# ...

# %%
# FICHA 3 | Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha3 para aficionados al fútbol que leen AS o Marca:

{ficha3}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)
# ...
# **"El Liverpool de Slot humilla al Milan en San Siro: un 1-3 que sabe a advertencia"**
#
# *Milán, 17 de septiembre de 2024* — El fútbol es cruel, y el AC Milan lo descubrió esta noche en su propia casa. Ante un Liverpool renovado bajo el mando de Arne Slot, los *rossoneri* soñaron con un inicio ilusionante en la Champions, pero se toparon con una realidad incómoda: los *Reds* no perdonan. Tres goles en 67 minutos —dos de ellos en la primera parte— bastaron para que el equipo de Van Dijk y Szoboszlai dejara claro que, pese a los cambios de ciclo, siguen siendo un hueso duro de roer. El 1-3 final no solo duele por el marcador, sino por cómo se gestó: con un Milan desdibujado en defensa, un Liverpool letal en las transiciones y un Szoboszlai que, con su gol de zurda en el 67', firmó su pasaporte a la leyenda de Anfield.
#
# ### **Cronología de un golpe frío**
# ...

# %%
# FICHA 3 | Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha3 para aficionados que leen AS o Marca:

{ficha3}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)
# ...
# **El Liverpool humilla al Milan en San Siro: Szoboszlai y Van Dijk firman un recital de autoridad**
#
# *San Siro rugió, pero solo para ver cómo el Liverpool lo callaba a golpes.* El equipo de Arne Slot, con una exhibición de poderío físico y precisión táctica, doblegó al Milan (1-3) en la primera jornada de la Champions League. Los *Reds* no solo ganaron, sino que lo hicieron con la contundencia de quien sabe que es favorito: en 41 minutos ya habían dado la vuelta al marcador, y en la segunda parte, Szoboszlai sentenció con un zurdazo que dejó sin aliento a los 59.826 espectadores. El Milan, con Fonseca en el banquillo, soñó con un inicio ilusionante, pero se topó con un Liverpool que, pese a su xG ajustado (1.1), fue letal cuando tocó.
#
# ### **Cronología de un vendaval rojo**
# ...

# %%
CoT 
FICHA 3

# %%
# FICHA 3 | Mistral-large | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: AC Milan 1-3 Liverpool (San Siro, UCL 2024/25 J1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada)
3. 1T: Milan adelanta 1-0 rápido, Liverpool remonta 1-2 antes descanso, posesión 55-45 Milan, xG 1.8-1.1 Liverpool
4. 2T: Szoboszlai sentencia, Milan reacciona con Chukwueze/Musah/Terracciano pero sin efecto, Liverpool administra con Tsimikas
5. JUGADOR: Szoboszlai o Van Dijk (clave defensiva/ofensiva Liverpool)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 3 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 3 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)
# ...
# **¡EL LIVERPOOL DESTRONA AL MILAN EN SAN SIRO CON UN GOLAZO DE SZOBOSZLAI!**
# *Los 'Reds' remontan un 0-1 inicial y aplastan al AC Milan (1-3) en la primera jornada de la Champions*
#
# **MILÁN —** El San Siro rugió, pero no fue para celebrar a su equipo. El Liverpool, con una exhibición de poderío físico, inteligencia táctica y un *golazo* de Dominik Szoboszlai, dejó claro desde el primer minuto de la Champions 2024/25 que viene a por todo. Los de Jürgen Klopp —perdón, los de Arne Slot— no solo ganaron: humillaron a un Milan que soñó con dar la campanada, pero terminó ahogado en su propia presión y en la contundencia de un rival que, una vez más, demostró por qué es el rey de Europa.
#
# ---
#
# ### **¡PULISIC ABRE LA CAJA DE LOS TRUENOS!**
# ...

# %%
# FICHA 3 | Mistral-large | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: AC Milan 1–3 Liverpool (San Siro, UCL 2024/25, Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liv, cabeza balón parado), 41' Van Dijk (Liv, cabeza córner Tsimikas), 67' Szoboszlai (Liv, disparo combinada)
3. 1T: Milan adelanta 1-0 rápido (3'), Liverpool remonta 1-2 antes descanso con dos cabezazos, posesión 55-45 Milan, xG 1.8-1.1 Liverpool
4. 2T: Szoboszlai sentencia (67'), Milan reacciona con Chukwueze/Musah/Terracciano sin efecto, Liverpool administra con Tsimikas
5. JUGADOR: Szoboszlai o Van Dijk (clave ofensiva/defensiva Liverpool, debut Slot exitoso)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Fonseca/Slot
- No inventes declaraciones ni citas textuales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 3 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)
# ...
# **¡El Liverpool aplasta al Milan en San Siro y Slot debuta con un golpe de autoridad!**
#
# *San Siro rugió, pero el Liverpool respondió con un fútbol de otro planeta. Tres goles, dominio absoluto y un debut soñado para Arne Slot, que ya sueña en grande en la Champions.*
#
# ---
#
# ### **1. El susto inicial: Pulisic abre la lata en un abrir y cerrar de ojos**
# ¡Tres minutos! Eso fue lo que necesitó el Milan para poner a temblar a San Siro. Morata, con esa elegancia que le caracteriza, filtró un pase milimétrico a Pulisic, que definió con frialdad ante Alisson. **1-0 y el fantasma de la remontada milanista asomaba.** Pero el Liverpool no es un equipo cualquiera. Y menos con Slot en el banquillo.
#
# ---
#
# ### **2. La respuesta de los gigantes: Konaté y Van Dijk dan la vuelta al marcador**
# ...

# %%
# FICHA 3 | Mistral-large | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: AC Milan 1–3 Liverpool (Stadio Giuseppe Meazza, UEFA Champions League 2024/25, Fase de grupos – Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liverpool, cabezazo tras acción a balón parado), 41' Van Dijk (Liverpool, cabezazo a la salida de un córner de Tsimikas), 67' Szoboszlai (Liverpool, disparo tras jugada combinada)
3. 1T: Milan se adelanta muy pronto (3') con gol de Pulisic, pero Liverpool remonta antes del descanso con dos tantos de cabeza (Konaté y Van Dijk); al descanso, 1–2 para los ingleses
4. 2T: Szoboszlai marca el 1–3 en el 67', que sentencia el partido; Milan mueve el banquillo (Chukwueze, Musah, Terracciano) en busca de reacción ofensiva y Liverpool introduce a Tsimikas y jugadores de refresco para gestionar la ventaja
5. ESTADÍSTICAS: Posesión 55–45, tiros 16–12, córners 7–5, xG 1.8–1.1 a favor de Liverpool
6. MVP: Szoboszlai o Van Dijk (determinantes en la sentencia y en el dominio aéreo del Liverpool)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)
# ...
# **Liverpool humilla al Milan en San Siro con un contundente 1-3**
# *El equipo de Slot domina desde el inicio y sentencia con autoridad en la primera jornada de la Champions*
#
# **Entrada**
# El Liverpool comenzó su andadura en la Champions League 2024/25 con una exhibición de solidez y eficacia en el Stadio Giuseppe Meazza. Frente a un Milan que soñaba con dar la sorpresa en casa, los *Reds* respondieron con un juego directo, dominio aéreo y una remontada fulminante en la primera mitad. Los goles de Konaté, Van Dijk y Szoboszlai dejaron sin opciones a los locales, que solo pudieron anotar por medio de Pulisic en los primeros minutos. Con un 1-3 final, el Liverpool se lleva los tres puntos en un partido donde las estadísticas —especialmente el xG— reflejaron su superioridad.
#
# ---
#
# **Cronología**
# ...

# %%
# FICHA 3 | Mistral-large | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: AC Milan 1–3 Liverpool (Stadio Giuseppe Meazza, Champions League 2024/25 – Fase de grupos, Jornada 1)
2. GOLES: 3' Pulisic (Milan, as. Morata), 23' Konaté (Liverpool, cabezazo tras acción a balón parado), 41' Van Dijk (Liverpool, cabezazo a la salida de un córner de Tsimikas), 67' Szoboszlai (Liverpool, disparo tras jugada combinada)
3. 1T: Milan se adelanta muy pronto (3') con gol de Pulisic, pero el Liverpool remonta antes del descanso con dos tantos de cabeza (Konaté y Van Dijk); al descanso, 1–2 para los ingleses, con ligera ventaja de posesión para el Milan (55–45)
4. 2T: Szoboszlai firma el 1–3 en el 67' y sentencia el duelo; Milan introduce a Chukwueze, Musah y Terracciano buscando reacción ofensiva, mientras el Liverpool recurre a Tsimikas y jugadores de refresco para gestionar la ventaja
5. ESTADÍSTICAS: Posesión 55–45, tiros 16–12, córners 7–5, xG 1.8–1.1 a favor del Liverpool
6. MVP: Szoboszlai o Van Dijk (determinantes en la sentencia del marcador y en el dominio aéreo del Liverpool)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 3 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 3 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)
# ...
# **¡El Liverpool humilla al Milan en San Siro con un recital de fútbol vertical y poderío aéreo!**
#
# *El Liverpool dejó claro desde el primer minuto que no había venido a Milán a conformarse. Un gol tempranero de Pulisic ilusionó a la afición *rossonera*, pero la respuesta inglesa fue demoledora: dos cabezazos letales antes del descanso y un zurdazo de Szoboszlai en la segunda parte sentenciaron un 1-3 que sabe a advertencia en la Champions League.*
#
# ---
#
# ### **CRONOLOGÍA: DEL SUEÑO MILANISTA AL CASTIGO INGLÉS**
#
# **3' | ¡Gol de Pulisic!** El Milan arrancó como un vendaval. Morata robó un balón en mediocampo, filtró un pase milimétrico a Pulisic y el estadounidense definió con frialdad ante Alisson. San Siro enloqueció: el plan de Pioli parecía funcionar. Pero el Liverpool, curtido en batallas europeas, no se inmutó.
#
# ...

# %% [markdown]
# FICHA 4
# ZERO SHOT

# %%
# FICHA 4 | Mistral-large | Zero-shot | Sin rol | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

ficha4 = """ID_PARTIDO: UCL_2024_J1_PSG_ARS
Competición: UEFA Champions League
Temporada: 2024/2025
Fase: Fase de grupos – Jornada 1 (League Phase)
Fecha: 01/10/2024
Hora: 19:00 hora local (Londres)
Estadio: Emirates Stadium, Londres
Asistencia: 60,103 espectadores
Árbitro: Slavko Vinčić (Eslovenia)
Equipo 1: Arsenal
Equipo 2: Paris Saint-Germain
Entrenador Arsenal: Mikel Arteta
Entrenador Paris Saint-Germain: Luis Enrique
Alineación Arsenal:
Raya; White, Saliba, Kiwior, Zinchenko; Ødegaard, Rice, Havertz; Saka, Gabriel Jesus, Martinelli
Alineación Paris Saint-Germain:
Donnarumma; Hakimi, Marquinhos, Pacho, Nuno Mendes; Vitinha, Zaïre-Emery, Fabián Ruiz; Dembélé, Kvaratskhelia, Barcola
Resultado final: Arsenal 2 – 0 Paris Saint-Germain
Resultado al descanso: Arsenal 2 – 0 Paris Saint-Germain
Goles:
20' Havertz (Arsenal) 1–0, remate de cabeza tras centro de Trossard
35' Saka (Arsenal) 2–0, lanzamiento de falta lateral mal gestionada por Donnarumma
Tarjetas amarillas Arsenal:
No disponibles
Tarjetas amarillas Paris Saint-Germain:
No disponibles
Tarjetas rojas:
Ninguna
Sustituciones Arsenal:
64' Mikel Merino entra para reforzar el centro del campo
74' Trossard entra por Gabriel Jesus
Myles Lewis-Skelly entra por Saka en el tramo final
Sustituciones Paris Saint-Germain:
Fabián Ruiz entra en la segunda parte
Otros cambios ofensivos (como Kolo Muani) en el tramo final para buscar reacción
Eventos registrados:
Arsenal se adelanta con un cabezazo de Havertz tras centro de Trossard
Saka firma el 2–0 con una falta lateral mal defendida por Donnarumma
Debut de Mikel Merino con el Arsenal, que entra en la segunda parte para dar solidez al medio campo
Estadísticas totales:
Posesión (%): 58 – 42 a favor del Arsenal
Tiros: 14 – 11
Córners: 6 – 5
Estadísticas avanzadas:
xG: 1.4 – 1.2 a favor del Arsenal
Jugador del partido: Kai Havertz"""

prompt_config1 = f"Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: {ficha4}"

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config1}],
    temperature=0.0,
    max_tokens=900
)

cronica_config1 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_config1)
# Out:
# ✅ FICHA 4 – CONFIG 1 (Mistral-large | Zero-shot | Sin rol | Sin restricciones)
# ...
# **¡El Arsenal aplasta al PSG en el Emirates y da el primer golpe en la Champions!**
# *Kai Havertz y Bukayo Saka firman una noche de gala en Londres*
#
# **Londres, 1 de octubre de 2024** — El Emirates Stadium rugió como en los viejos tiempos. El Arsenal, con un fútbol de alto voltaje y una solidez defensiva que dejó sin oxígeno al PSG, se impuso por **2-0** en la primera jornada de la *League Phase* de la Champions League. Kai Havertz, elegido mejor jugador del partido, y Bukayo Saka —con un golazo de falta— firmaron una exhibición que deja a Mikel Arteta con la sonrisa de quien sabe que su equipo está para grandes cosas en Europa. Mientras, el PSG de Luis Enrique se marchó de Londres con más dudas que certezas, incapaz de reaccionar ante la presión *gunner*.
#
# ---
#
# ### **Primer tiempo: Dominio absoluto y dos golpes letales**
# ...

# %%
# FICHA 4 | Mistral-large | Zero-shot | CON ROL | Sin restricciones
# AUDIENCIA: Aficionados AS/Marca

prompt_config2 = """Eres periodista deportivo de AS o Marca. 
Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca: 

{ficha4}""".format(ficha4=ficha4)

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config2}],
    temperature=0.0,
    max_tokens=900
)

cronica_config2 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config2)
# Out:
# ✅ FICHA 4 – CONFIG 2 (Mistral-large | Zero-shot | CON ROL | Sin restricciones)
# ...
# **¡El Arsenal humilla al PSG en el Emirates! Havertz y Saka sentencian a Luis Enrique en la Champions**
#
# *Londres, 1 de octubre de 2024* — **¡Qué noche para el Arsenal!** Los *Gunners* debutaron en la *League Phase* de la Champions League con una exhibición de autoridad ante un PSG que, pese a su cartel, salió vapuleado del Emirates (2-0). Kai Havertz, con un cabezazo letal, y Bukayo Saka, con un zurdazo desde la frontal, firmaron una victoria que sabe a declaración de intenciones. Mientras, Luis Enrique se llevó una lección de fútbol de Mikel Arteta, cuyo equipo dominó de principio a fin con un juego asociativo y vertical que dejó en evidencia a los parisinos.
#
# ---
#
# ### **Havertz abre la lata con clase**
# ...

# %%
# FICHA 4 | Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES (ligeras)

prompt_config3 = f"""Escribe una crónica deportiva sobre este partido para aficionados al fútbol que leen AS o Marca:

{ficha4}

RESTRICCIONES:
• 400-500 palabras
• Estructura clara: entrada + desarrollo + cierre
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config3}],
    temperature=0.0,
    max_tokens=900
)

cronica_config3 = response.choices[0].message.content
print("✅ FICHA 4 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config3)
print(f"\n📊 Palabras: {len(cronica_config3.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 3 (Mistral-large | Zero-shot | Sin rol | CON RESTRICCIONES)
# ...
# **Arsenal humilla al PSG en el Emirates con un recital de fútbol vertical**
#
# *Londres, 1 de octubre de 2024* — El Arsenal de Mikel Arteta dejó claro desde el primer minuto que no está dispuesto a ser un convidado de piedra en esta Champions. Con un fútbol intenso, presión alta y dos goles en la primera mitad, los *Gunners* doblegaron al PSG de Luis Enrique (2-0) en un partido que, más que un choque de estrellas, fue un manual de cómo ejecutar un plan táctico. Kai Havertz, autor del primer gol y elegido mejor jugador, y Bukayo Saka, con un zurdazo desde la frontal, firmaron una noche redonda para los locales, que se colocan líderes de su grupo con tres puntos de oro.
#
# ### **Dominio desde el primer silbato**
# ...

# %%
# FICHA 4 | Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES

prompt_config4 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia en Champions.

Escribe una crónica sobre este partido para aficionados que leen AS o Marca:

{ficha4}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Desarrollo cronológico 3) Cierre reflexivo
• Menciona: goles exactos , xG, Jugador del partido"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config4}],
    temperature=0.0,
    max_tokens=1000
)

cronica_config4 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config4)
print(f"\n📊 Palabras: {len(cronica_config4.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 4 (Mistral-large | Zero-shot | CON ROL | CON RESTRICCIONES)
# ...
# **El Arsenal humilla al PSG en un Emirates que vibró como en los viejos tiempos**
#
# *Londres, 1 de octubre de 2024* — El Emirates Stadium rugió como en los días de Henry y Bergkamp. El Arsenal, con una exhibición de solidez y eficacia, doblegó al Paris Saint-Germain (2-0) en la primera jornada de la *League Phase* de la Champions, dejando claro que este equipo de Arteta no ha venido a hacer turismo en Europa. Dos goles en la primera media hora —un cabezazo de Havertz y una falta lateral de Saka que Donnarumma no supo leer— bastaron para sentenciar un partido en el que el PSG, pese a su talento, nunca encontró el ritmo. Los números no mienten: 1.4 de *xG* para los *Gunners* por 1.2 de los parisinos, pero con una diferencia abismal en la ejecución.
#
# ### **Havertz abre la lata con autoridad**
# ...

# %% [markdown]
# FEW SHOT
# FICHA 4

# %%
# FICHA 4 | Mistral-large | Few-shot  | Sin rol | Sin restricciones
# Objetivo: forzar que Mistral NO copie la ficha y sí genere una crónica evaluable.

# --- Prompt (few-shot real + reglas anti-copia) ---
prompt_fewshot1 = f"""
EJEMPLO (crónica breve correcta):

REAL MADRID 2–1 BARCELONA
Un gol de Benzema antes del descanso y otro de Vinicius en el tramo final decidieron un clásico equilibrado.
El Madrid golpeó primero y supo resistir la reacción azulgrana tras el empate.
Jugador del partido: Benzema.

REGLAS:
- Usa SOLO la información de la ficha.
- No uses la información del ejemplo
- NO muestres la ficha ni sus campos.
- NO listes datos como en una tabla.
- Escribe en lenguaje periodístico narrativo (prosa continua).
- Si un dato no existe, simplemente no lo menciones.
- No inventes jugadas, contexto, frases de ambiente, ni estadísticas que no estén en la ficha.

AHORA FICHA REAL:
{ficha4}

ESCRIBE LA CRÓNICA:
"""

# --- Llamada al modelo ---
response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_fewshot1}],
    temperature=0.0,
    max_tokens=900
)

# --- Output ---
cronica_fewshot1 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_fewshot1)
# Out:
# ✅ FICHA 4 – CONFIG 5 (Mistral-large | Few-shot SIMPLE mejorado | Sin rol | Sin restricciones)
# ...
# **ARSENAL 2–0 PARIS SAINT-GERMAIN**
# El Emirates Stadium vivió un inicio de Champions contundente. Kai Havertz y Bukayo Saka sentenciaron el partido antes del descanso con dos goles que dejaron al PSG sin reacción.
#
# El Arsenal salió con autoridad y abrió el marcador en el minuto 20, cuando Havertz conectó de cabeza un centro de Leandro Trossard. Quince minutos después, Saka amplió la ventaja con un lanzamiento de falta lateral que Donnarumma no pudo detener. El conjunto de Mikel Arteta controló el ritmo con un 58% de posesión y cerró la primera mitad con un 2–0 que ya parecía definitivo.
#
# ...

# %%
# FICHA 4 | Mistral-large | Few-shot | CON ROL | Sin restricciones

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config6 = f"""Eres periodista deportivo de AS/Marca.

EJEMPLO de crónica AS/Marca: {ejemplo_fewshot}

Ahora escribe una crónica deportiva sobre el partido de la ficha4 para aficionados que leen AS o Marca:
{ficha4}"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config6}],
    temperature=0.0,
    max_tokens=900
)

cronica_config6 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_config6)
# Out:
# ✅ FICHA 4 – CONFIG 6 (Mistral-large | Few-shot | CON ROL | Sin restricciones)
# ...
# **Arsenal 2-0 PSG: Los Gunners empiezan con autoridad en la Champions**
#
# *Londres, 1 de octubre de 2024* – El Arsenal de Mikel Arteta arrancó la *League Phase* de la Champions League con una victoria contundente ante un PSG que, pese a su potencial, no logró descifrar el juego de los locales. Kai Havertz y Bukayo Saka firmaron los goles que dejaron a los franceses con la obligación de reaccionar en las próximas jornadas.
#
# ### **Un primer tiempo de dominio local**
# Desde el pitido inicial, el Arsenal mostró su ambición. Con una posesión del 58% y un juego asociativo por bandas, los de Arteta generaron peligro desde el minuto uno. La primera gran ocasión llegó en el minuto 20: un centro medido de Leandro Trossard desde la izquierda encontró a Havertz, que, libre de marca, cabeceó con precisión para batir a Donnarumma. El Emirates estalló.
#
# ...

# %%
# FICHA 4 | Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config7 = f"""EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica deportiva sobre el partido de la ficha4 para aficionados al fútbol que leen AS o Marca:

{ficha4}

RESTRICCIONES:
• 400-500 palabras
• Estructura: entrada impactante + cronología + cierre reflexivo
• Menciona goles exactos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config7}],
    temperature=0.0,
    max_tokens=900
)

cronica_config7 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config7)
print(f"\n📊 Palabras: {len(cronica_config7.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 7 (Mistral-large | Few-shot | Sin rol | CON RESTRICCIONES)
# ...
# **El Emirates rugió: Arsenal humilla al PSG con un recital de fútbol vertical**
#
# Londres, 1 de octubre de 2024. El Emirates Stadium se vistió de gala para recibir al Paris Saint-Germain en la primera jornada de la *League Phase* de la Champions, pero lo que presenciaron los 60.103 espectadores fue un espectáculo de contundencia y precisión. El Arsenal, con un fútbol directo y letal, doblegó al equipo de Luis Enrique (2-0) con goles de Havertz y Saka, dejando al PSG —repleto de estrellas— sin respuestas. Los *Gunners* no solo ganaron: exhibieron una superioridad táctica que los consolida como candidatos al título.
#
# ### **Cronología de un vendaval**
# ...

# %%
# FICHA 4 | Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES

ejemplo_fewshot = """EJEMPLO: Escribe crónica del Real Madrid 3-0 Bayern (UCL semis):

Real Madrid 3-0 Bayern. Goles: 1-0 Mbappé 23', 2-0 Vinicius 67', 3-0 Rodrygo 89'.
El Madrid dominó con posesión 62% y xG 2.1-0.8. Ancelotti perfecto en rotaciones."""

prompt_config8 = f"""Eres periodista deportivo de AS/Marca con 20 años de experiencia.

EJEMPLO de crónica AS/Marca (400 palabras): {ejemplo_fewshot}

Escribe una crónica sobre el partido de la ficha4 para aficionados que leen AS o Marca:

{ficha4}

RESTRICCIONES OBLIGATORIAS:
• 400-500 palabras
• Estructura: 1) Entrada impactante 2) Cronología 3) Cierre reflexivo
• Menciona goles exactos y sus minutos y xG"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_config8}],
    temperature=0.0,
    max_tokens=900
)

cronica_config8 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_config8)
print(f"\n📊 Palabras: {len(cronica_config8.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 8 (Mistral-large | Few-shot | CON ROL | CON RESTRICCIONES)
# ...
# **El Arsenal humilla al PSG en el Emirates: Havertz y Saka firman un recital de autoridad**
#
# *Londres, 1 de octubre de 2024* — El Emirates Stadium rugió como en los mejores tiempos de Wenger. El Arsenal no solo venció al PSG, sino que lo desarmó con una exhibición de fútbol vertical, inteligencia táctica y una frialdad letal en los momentos clave. Dos goles en la primera mitad —uno de cabeza de Havertz y otro de falta directa de Saka— bastaron para sentenciar un partido que el conjunto de Arteta dominó de principio a fin, dejando al equipo de Luis Enrique sin respuestas y con la sensación de que, en la *League Phase* de esta Champions, el nivel exigido será aún mayor.
#
# ### **Cronología de un espectáculo precoz**
# ...

# %% [markdown]
# CoT
# FICHA 4

# %%
# FICHA 4 | Mistral-large | Chain-of-Thought | Sin rol | Sin restricciones

prompt_cot1 = f"""1. RESULTADO: Arsenal 2-0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25 J1)
2. GOLES: 20' Havertz (Arsenal, cabeza tras centro Trossard), 35' Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal domina con 2-0 al descanso, posesión 58-42, control total ante PSG estelar
4. 2T: Arsenal administra ventaja con entrada de Merino (debut), PSG mueve banquillo (Fabián Ruiz, Kolo Muani) sin reacción
5. JUGADOR: Kai Havertz (gol clave de cabeza, liderazgo ofensivo)

ESCRIBE crónica AS/Marca usando estos 5 puntos:
- Tono periodístico español (crónica deportiva)
- Estilo dinámico, enfático, propio de diario deportivo
- Usa titulares, ritmo narrativo y expresividad
- No inventes diálogos ni citas literales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot1}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot1 = response.choices[0].message.content
print("✅ FICHA 4 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)")
print("=" * 80)
print(cronica_cot1)
# Out:
# ✅ FICHA 4 – CONFIG 9 (Mistral-large | CoT | Sin rol | Sin restricciones)
# ...
# **¡El Arsenal aplasta al PSG con autoridad y se lleva los tres puntos en el Emirates!**
# *Havertz y Saka firman un recital de eficiencia ante un París Saint-Germain irreconocible*
#
# **LONDRES** — El Emirates Stadium rugió. Y no era para menos. El Arsenal, con una exhibición de solidez y contundencia, doblegó (2-0) a un París Saint-Germain que llegó a Londres con estrellas, pero se marchó con la sensación de haber sido víctima de un equipo superior en todos los aspectos. Kai Havertz, con un cabezazo letal, y Bukayo Saka, aprovechando un error garrafal de Donnarumma, firmaron los goles que dejaron al conjunto francés al borde del abismo en la primera jornada de la Champions League 2024/25.
#
# ---
#
# ### **Primer tiempo: El Arsenal humilla al PSG con un fútbol de manual**
# ...

# %%
# FICHA 4 | Mistral-large | Chain-of-Thought | CON ROL | Sin restricciones

prompt_cot2 = f"""Eres periodista de AS o Marca. RAZONA PASO A PASO:

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, UCL 2024/25, Jornada 1)
2. GOLES: 20' Havertz (Arsenal, cabezazo tras centro Trossard), 35' Saka (Arsenal, falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal domina con 2-0 al descanso, posesión 58-42, control total ante PSG estelar con Kvaratskhelia/Dembélé
4. 2T: Arsenal administra con debut Merino (64'), PSG reacciona con Fabián Ruiz/Kolo Muani sin puntería, Emirates festeja
5. JUGADOR: Kai Havertz (gol decisivo de cabeza, liderazgo ofensivo, clave en Arteta)

ESCRIBE crónica siguiendo tus 5 pasos:
- Estilo AS/Marca (español peninsular, dinámico y expresivo)
- Usa tono épico y ritmos cortos de frase
- Menciona contexto de Champions y papel de Arteta/Luis Enrique
- No inventes declaraciones ni citas textuales"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot2}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot2 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)")
print("=" * 80)
print(cronica_cot2)
# Out:
# ✅ FICHA 4 – CONFIG 10 (Mistral-large | CoT | CON ROL | Sin restricciones)
# ...
# **¡El Arsenal aplasta al PSG y siembra el terror en la Champions!**
# *Kai Havertz y Saka humillan a Donnarumma en un Emirates convertido en fortaleza*
#
# **LONDRES —** La Champions 2024/25 arrancó con un *boom*. Y el epicentro fue el Emirates, donde el Arsenal de Mikel Arteta dejó al PSG de Luis Enrique —y a su constelación de estrellas— con la sensación de haber sido arrollados por un *bulldozer* inglés. **2-0** que supo a **10-0**, posesión robada (58-42) y un recital de fútbol vertical que dejó a Mbappé (ausente por lesión) preguntándose qué hacía su equipo en el banquillo. **Havertz, Saka y un Arteta que ya mira a octavos como mínimo.**
#
# ---
#
# ### **1. EL GOL QUE LO CAMBIÓ TODO: HAVERTZ, CABEZA Y CORAZÓN**
# ...

# %%
# FICHA 4 | Mistral-large | Chain-of-Thought | Sin rol | CON RESTRICCIONES

prompt_cot3 = f"""RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, UEFA Champions League 2024/25, Fase de grupos – Jornada 1)
2. GOLES: 20' Havertz (Arsenal, remate de cabeza tras centro de Trossard), 35' Saka (Arsenal, lanzamiento de falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal se adelanta con gol de Havertz (20') y Saka amplía la ventaja (35') antes del descanso con dos tantos efectivos
4. 2T: Arsenal administra el 2-0 con entrada de Mikel Merino (64', debut), PSG mueve banquillo con Fabián Ruiz y Kolo Muani sin generar peligro real
5. ESTADÍSTICAS: Posesión 58–42, tiros 14–11, córners 6–5, xG 1.4–1.2 a favor del Arsenal
6. MVP: Kai Havertz (gol clave de cabeza, liderazgo ofensivo determinante)

ESCRIBE crónica AS/Marca con:
• Estructura: Entrada + Cronología + Análisis xG + Cierre
• Menciona TODOS los datos arriba
• Evita exageraciones irreales o metáforas poéticas
• No inventes citas ni declaraciones
• Mantén tono informativo con ritmo narrativo deportivo"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot3}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot3 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot3)
print(f"\n📊 Palabras: {len(cronica_cot3.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 11 (Mistral-large | CoT | Sin rol | CON RESTRICCIONES)
# ...
# **Arsenal domina al PSG en Emirates con doblete tempranero y solidez defensiva**
#
# *Londres (Emirates Stadium) – El Arsenal inició su camino en la Champions League 2024/25 con una victoria clara (2-0) ante el Paris Saint-Germain, un rival que, pese a su potencial, no logró descifrar el esquema de Mikel Arteta. Dos goles en la primera mitad —de Kai Havertz y Bukayo Saka— bastaron para sentenciar un partido en el que los *Gunners* exhibieron mayor eficacia y control, especialmente en los momentos clave.*
#
# ---
#
# ### **Cronología: Dos errores defensivos deciden el partido**
# ...

# %%
# FICHA 4 | Mistral-large | Chain-of-Thought | CON ROL | CON RESTRICCIONES

prompt_cot4 = f"""Eres periodista de AS o Marca con 20 años de experiencia cubriendo la Champions League.

RAZONA PASO A PASO (400-500 palabras):

1. RESULTADO: Arsenal 2–0 Paris Saint-Germain (Emirates Stadium, Champions League 2024/25 – Fase de grupos, Jornada 1)
2. GOLES: 20' Havertz (Arsenal, remate de cabeza tras centro de Trossard), 35' Saka (Arsenal, lanzamiento de falta lateral mal gestionada por Donnarumma)
3. 1T: Arsenal se adelanta con gol de Havertz (20') y Saka amplía la ventaja (35') antes del descanso; posesión 58–42 a favor de los gunners
4. 2T: Arsenal administra con entrada de Mikel Merino (64', debut), PSG introduce Fabián Ruiz y Kolo Muani sin generar ocasiones claras
5. ESTADÍSTICAS: Posesión 58–42, tiros 14–11, córners 6–5, xG 1.4–1.2 a favor del Arsenal
6. MVP: Kai Havertz (gol decisivo de cabeza, liderazgo ofensivo, clave en la victoria de Arteta)

ESCRIBE crónica con:
• Estructura: Titular impactante + Cronología + Análisis xG + Cierre épico
• Menciona TODOS los datos arriba
• Mantén tono ágil y enfático, propio de la prensa deportiva española
• No inventes citas ni expresiones literarias exageradas
• Controla el ritmo narrativo, evita repeticiones y metáforas innecesarias"""

response = client.chat.completions.create(
    model="mistral-large-latest",
    messages=[{"role": "user", "content": prompt_cot4}],
    temperature=0.0,
    max_tokens=900
)

cronica_cot4 = response.choices[0].message.content

print("✅ FICHA 4 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)")
print("=" * 80)
print(cronica_cot4)
print(f"\n📊 Palabras: {len(cronica_cot4.split())}")
# Out:
# ✅ FICHA 4 – CONFIG 12 (Mistral-large | CoT | CON ROL | CON RESTRICCIONES)
# ...
# **¡El Arsenal aplasta al PSG con autoridad y deja claro quién manda en el Grupo B!**
#
# **Londres, Emirates Stadium** — El Arsenal de Mikel Arteta no solo ganó, sino que humilló al PSG en la primera jornada de la Champions League. Dos goles en la primera mitad (Havertz de cabeza y Saka de falta lateral) bastaron para que los *Gunners* exhibieran su solidez ante un rival que, con Mbappé en el banquillo, nunca encontró el ritmo. El 2-0 final refleja una superioridad clara, con un Havertz imperial y un equipo que administró el partido como un veterano.
#
# ---
#
# ### **Cronología: El Arsenal marca territorio desde el minuto 1**
#
# ...
